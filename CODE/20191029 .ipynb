# %% [raw]
# """"problem talib need install wheel
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
# import talib
# """

# %%
try:
    import xml.etree.cElementTree as ET
except ImportError:
    import xml.etree.ElementTree as ET

# %%
# basic
import numpy as np
import pandas as pd
import pymongo
# visual
import matplotlib.pyplot as plt
# %matplotlib inline
#time
import datetime 

#talib
import talib
from talib import abstract

#gui
import tkinter as tk
from  tkinter import ttk  
from tkinter import messagebox
import requests
import re

# %%
import io
import requests
import datetime


def crawl_price(stock_id):
    now = int(datetime.datetime.now().timestamp())+86400
    url = "https://query1.finance.yahoo.com/v7/finance/download/" + stock_id + "?period1=0&period2=" + str(now) + "&interval=1d&events=history&crumb=hP2rOschxO0"

    response = requests.post(url)
    
    f = io.StringIO(response.text)
    df = pd.read_csv(f, index_col='Date', parse_dates=['Date'] )
    return df

# %%
from suds.client import Client
from suds.xsd.doctor import Import, ImportDoctor
url="http://61.220.30.176/WebOrder/GVETransacs.asmx?WSDL"
imp=Import('http://www.w3.org/2001/XMLSchema',location='http://www.w3.org/2001/XMLSchema.xsd')
imp.filter.add('http://tempuri.org/')
client = Client(url, doctor=ImportDoctor(imp))
print(client)
# Out:
# Suds ( https://github.com/cackharot/suds-py3 )  version: 1.3.3.0 IN  build: 20170311
#
# Service ( GVETransacs ) tns="http://tempuri.org/"
#    Prefixes (1)
#       ns0 = "http://tempuri.org/"
#    Ports (2):
#       (GVETransacsSoap)
#          Methods (248):
#             AdjustOrder(xs:string UserName, xs:string GameCode, xs:string CompCode, xs:string Price, xs:string Volume, xs:string BSAction, xs:string OrderType, xs:string ExpireDate, xs:string OrgVolume, xs:string OrderSource, xs:string CombineNo, )
#             CancelOrder(xs:string OrderID, )
#             CancelOrderStr_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:string comment, )
#             ChangeOrder(xs:string OrderID, xs:double Volume, )
#             ChangeOrderPrice(xs:int gmrid, xs:string orderno, xs:string ordertype, xs:string ordernote, xs:float price, xs:string Lang, )
#             ChangeOrder_NS(xs:string TokenString, xs:string OrderID, xs:double Volume, )
#             ChangeOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:double Volume, xs:string comment, )
#             CheckAndUpdateAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             CheckAndUpdateFuturAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             ClearPosition(xs:string AssetCode, )
#             DeleteSMSWaitingMultiRecord(xs:string SMSID, xs:string message, )
#             DeleteSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             FollowOrderAddSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FollowOrderDeleteSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FuturesFinalSettle()
#             GMRIDToStr(xs:int GMRID, )
#             GMRStrToInt(xs:string GMRIDStr, )
#             GetTradableAsset(xs:string AssetCode, )
#             GetTradableAssetList()
#             GetTradableAssetListXML()
#             MarkupQuoteItemDataXML(xs:string AssetCodeList, xs:string QuoteItemLine, xs:string Language, )
#             NewFollowOrderSubscribe(xs:string GMRID, xs:string SubscribeID, xs:int dailylimit, )
#             NewSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             OptionFinalSettle()
#             PutBatchOrder(GVEWSOrderList sGVEWSOrderList, )
#             PutCombineOrder(xs:string GMRID, xs:string CompCode1, xs:string BSAction1, xs:int Volume1, xs:string CompCode2, xs:string BSAction2, xs:int Volume2, xs:string OrderType, xs:float PriceDiff, xs:string OptiNote, xs:string OptiCombinNo, xs:string lang, )
#             PutOrder(GVEWSOrder Order, )
#             PutOrderXML(xs:int GMRID, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML1(xs:string GMRIDStr, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML2(xs:string GMRIDStr, xs:string AssetCode, xs:int PFLAssetID, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML3(xs:string GMRIDStr, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string str_ip, )
#             PutOrderXML3_STWS(xs:int GMRID, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             PutOrderXML3_STWS_2(xs:int GMRID, xs:string CompCode, xs:string username, xs:string gamecode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string expiredate, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             QueryAllSectorList(xs:int ExchID, )
#             QueryAllSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryAllWarrantsSectorList(xs:int ExchID, )
#             QueryAllWarrantsSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryCataIDByGmridAssetClass(xs:string GMRID, xs:string AssetClass, xs:string Lang, )
#             QueryCompanyData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryCountryCode(xs:string Lang, )
#             QueryDayRangeTFXML(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDayRangeTFXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLog()
#             QueryDealLogBusinessTransactionSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogBy2(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2DiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, )
#             QueryDealLogBy2DiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, xs:string comment, )
#             QueryDealLogBy2XML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2XML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, xs:string Language, )
#             QueryDealLogByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogByGMRDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByGMRDayRangeXML(xs:int GMRID, xs:string StartDate, xs:string EndDate, )
#             QueryDealLogByGMRDayRangeXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByOrderID(xs:string OrderID, )
#             QueryDealLogByOrderIDXML(xs:string OrderID, )
#             QueryDealLogByOrderIDXML_NS(xs:string OrderID, xs:string TokenString, xs:string Language, )
#             QueryDealLogCheckSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogCheckSheetByBSActionCompType(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDealLogCheckSheet_STWS(xs:string Comptype, xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogFundTrading(xs:string GMRID, xs:string Lang, )
#             QueryDealLogGVE3ByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogMarginRateSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogWriteOff(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDividendData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryDividendInfoByCompCode(xs:string CompCode, )
#             QueryDividendInfoByCompCode_NS(xs:string CompCode, xs:string Language, )
#             QueryDividendInfoByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDividendInfoByDayRange_NS(xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryDividendInfoByExchDayRange(xs:string ExchID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryExchRate(xs:string HomeFX, xs:string ForeignFx, xs:int amount, )
#             QueryFXCrossRate(xs:string Lang, xs:string Fx, )
#             QueryFameHistoryByGMRID(xs:string GMRIDStr, )
#             QueryFameList(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGMRFameDateXml_NS(xs:string GMRIDStr, xs:dateTime FameDay, )
#             QueryFameListByGameCode(xs:string GameCode, )
#             QueryFameListByGameCodeFameDate(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGameCodeUsername(xs:string GameCode, xs:string Username, )
#             QueryFameListTop10ByGameCode_xml(xs:string GameCode, )
#             QueryFollowOrderApprovedHistoryByWeek_xml(xs:string GMRID, xs:int Year, xs:int Week, )
#             QueryFollowOrderBasicDataByGMRID(xs:string GMRID, )
#             QueryFollowOrderCreditUsedDetail_XML(xs:string GMRID, xs:int followid, )
#             QueryFollowOrderFollowerByGMRID(xs:string GMRIDStr, )
#             QueryFollowOrderMyFansApproved_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansSentSummary_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansWaitForApprove_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolAllList_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolList_XML(xs:string GMRID, )
#             QueryFollowOrderSubScribedByGMRID(xs:string GMRIDStr, )
#             QueryFundDividendInfoByDayRange(xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryFutureSeriesByFutureClass(xs:string FutuClass, )
#             QueryFuturesListMobileXML_NS(xs:int gmrid, xs:string AssetCatalog, xs:string Lang, )
#             QueryFuturesMarginXml(xs:string ExchID, )
#             QueryFuturesPriceByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryFuturesPriceCountByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, )
#             QueryFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string Language, )
#             QueryFuturesQuotePrice(xs:string ExchID, )
#             QueryFuturesQuotePriceXML(xs:string ExchID, )
#             QueryFuturesQuotePriceXML_NS(xs:string ExchID, xs:string Language, )
#             QueryFuturesQuotePrice_NS(xs:string ExchID, xs:string Language, )
#             QueryFxCurrenctAccountListByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryFxQuotePrice(xs:string Lang, )
#             QueryFxQuotePrice_DS(xs:string Lang, )
#             QueryGMRHisFame(xs:int GMRID, )
#             QueryGameDailyReportXML(xs:string gamecode, xs:string itemname, xs:string daydate, )
#             QueryGameRuleRealtimeChecking(xs:int gmrid, )
#             QueryHistoricalFame()
#             QueryHistoricalQuoteData(xs:string AssetCode, xs:int DWM, xs:int Len, )
#             QueryIndexDataByDate(xs:string IndexName, xs:string daydate, xs:string flied, )
#             QueryLatestFameListByGMRID(xs:string GMRID, )
#             QueryLatestFameListByGMRID2(xs:string GMRID, )
#             QueryLatestFameListByGameCodeCountXML(xs:string GameCode, )
#             QueryLatestFameListByGameCodeNewXML(xs:string GameCode, xs:string day, xs:int PageNum, xs:int PageSize, xs:string Lang, )
#             QueryMarketSnap(xs:string CompCode1, xs:string CompCode2, )
#             QueryMarketSnap2(xs:string compcodelist, xs:string lang, )
#             QueryNewsDetailByRptID(xs:long RptID, )
#             QueryNewsTitleByRptIDDate_xml(xs:long RptID, xs:dateTime Daydate, )
#             QueryNewsTop10Title()
#             QueryOddlotWaitingOrderListXML_NS(xs:int SearchTarget, xs:string Language, )
#             QueryOptionATMPriceByOptionClass(xs:string optionclass, )
#             QueryOptionClassByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryOptionClassXML(xs:string ExchID, )
#             QueryOptionSerial(xs:string OptionClass, )
#             QueryOptionUnderlyingPrice(xs:string OptiClass, )
#             QueryOptionUnderlyingPriceXML(xs:string OptiClass, )
#             QueryOptionsBasePrice(xs:string OptiClass, xs:string Lang, )
#             QueryOptionsListMobileXML(xs:string Opticlass, xs:string CPType, xs:string Lang, )
#             QueryOptionsMarginXml(xs:string OptiClass, xs:string CPType, xs:dateTime Maturiy, )
#             QueryOptionsQuotePrice(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOptionsQuotePriceXML(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOrderList()
#             QueryOrderListByDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML2(xs:string GMRIDStr, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryOrderListByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListByDiff2XML_NS(xs:string GMRIDStr, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, xs:string comment, )
#             QueryOrderListGVE3ByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListXML()
#             QueryOrderMaxVolume(xs:string GMRID, xs:string Compcode, xs:string BASction, )
#             QueryOrderStatus(xs:string OrderID, )
#             QueryPortfolioXML()
#             QueryPortfolioXML_NS(xs:string TokenString, )
#             QueryProverb()
#             QueryQuote5Price(xs:string CompCode, )
#             QueryQuotePrice(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2XML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePriceAndAllowOrder(xs:string Compcode, xs:string Gamecode, xs:string Language, )
#             QueryQuotePriceByAssetCatalog(xs:string AssetCatalog, xs:string Target, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingUDP(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingVol(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorID(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDCompTypeCount(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompTypeNew_DS(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int PageNum, xs:int Pagesize, xs:string Language, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompType_DS_NS(xs:string SectorID, xs:string CompType, xs:string Language, )
#             QueryQuotePriceBySectorIDOrderingUDP(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDOrderingVol(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDXML(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDXML_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_DS_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS2(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceXML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice_NS(xs:string AssetCodeList, xs:string Language, )
#             QueryReportClosePositionByGMRDayRange(xs:int gmrid, xs:string startdate, xs:string enddate, xs:string comptypes, xs:string Lang, )
#             QueryReportFutureTradingPerformace(xs:int gmrid, xs:string startdate, xs:string enddate, )
#             QuerySHGYIDX(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySHGYStockData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string Lang, )
#             QuerySelfQuoteListByGMRID(xs:string GMRIDStr, )
#             QuerySelfQuoteListByGMRID_NS(xs:string GMRIDStr, )
#             QueryStockFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string catagory, xs:string Language, )
#             QuerySubscribeNewIssueByGMRID(xs:string GMRID, xs:string Lang, )
#             QuerySystemCompanyChecksumXml_NS(xs:string market, )
#             QueryTodayDealStatisticFutureandOption(xs:string GMRID, xs:string Daydate, )
#             QueryTodayDealStatisticStock(xs:string GMRID, xs:string Daydate, )
#             QueryTodayOpenNAV()
#             QueryTodayOpenNAV_NS(xs:string TokenString, )
#             QueryTodayPositionByCompType(xs:string GMRID, xs:string CompTypeList, xs:string Lang, )
#             QueryTodayPositionByCurrency(xs:string GMRID, xs:string CurrencyList, xs:string Lang, )
#             QueryTodayPositionFund(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundDetailByCompCode(xs:string GMRID, xs:string CompCode, xs:string Lang, )
#             QueryTodayPositionFundXinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionGve3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryTodayPositionNotSettled(xs:string GMRID, xs:string Lang, )
#             QueryTodayTFXML()
#             QueryTodayTFXML_NS(xs:string TokenString, )
#             QueryTotalTFXML()
#             QueryTotalTFXML_NS(xs:string TokenString, )
#             QueryTradeLogSimpleByGMRID(xs:string GMRID, xs:string Language, )
#             QueryTransferAccountListByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListFXByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListGVE3ByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferRecordListGVE3ByGMRIDXML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryTroubleTeamRecordByGMRID(xs:string GMRIDStr, )
#             QueryUserCash(xs:string GMRID, xs:string Lang, )
#             QueryUserCashBriefByGMRID(xs:string GMRID, )
#             QueryUserCashByGMRAccountCurrencyXML_NS(xs:int gmrid, xs:string TradeAccount, xs:string Currency, xs:string Lang, )
#             QueryUserCashGVE3ByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserCashGroupByAccountByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserDetailByGMRID(xs:string GMRIDStr, )
#             QueryUserDetailByUsername(xs:string Username, )
#             QueryUserExchIDByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserProfileByGMRID(xs:string GMRIDStr, )
#             QueryVexchOrderStatisticFutureandOptionAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOption(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOptionByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticStock(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticStockByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserFutureOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserFutureOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserOptionOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserOptionOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserStockOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserStockOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryWaitingOrderList()
#             QueryWaitingOrderListGVE3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingOrderListXML()
#             QueryWaitingOrderListXML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingSMSList()
#             QueryWaitingSMSListGroupByEmail(xs:string Lang, )
#             QueryWarrantsData(xs:string CompCode, xs:string Lang, xs:string AssetClass, xs:string StartDate, xs:string EndDate, xs:string Issuer, )
#             ResetGameInitCash(xs:string GameCode, xs:string InitHold, xs:string AssetCode, )
#             SMSSendComplete(xs:int SMSID, xs:string message, )
#             SetLanguage(xs:string sLanguage, )
#             SignUpStatis(xs:string Gamecode, )
#             TransferCash(xs:string FromAccount, xs:string ToAccount, xs:double Amount, )
#             TransferCash_NS(xs:string GMRID, xs:string FromAccount, xs:string FromCurrency, xs:string ToAccount, xs:string ToCurrency, xs:double Amount, )
#             UpdateFollowOrderDailyLimit(xs:string GMRID, xs:int followed, xs:int dailylimit, )
#             UpdateFollowOrderSubscribeStatus(xs:string followorderids, xs:string GMRID, xs:int toStatus, )
#             UpdateSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, xs:string colname, xs:string Data, )
#             UpdateSelfQuoteDefault(xs:string GMRID, xs:string QuoteID, )
#             UpdateSelfQuoteNameByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string SelfQuoteName, )
#             UpdateSubscribeNewIssue(xs:string GMRID, xs:int sysid, xs:float subscribe, )
#          Types (101):
#             ArrayOfAnyType
#             ArrayOfString
#             AssetOrderType
#             BSActionType
#             xs:ENTITIES
#             xs:ENTITY
#             GVEWSOrder
#             GVEWSOrderList
#             GVEWSPortfolio
#             GVEWSResult
#             GVEWSUserLogList
#             xs:ID
#             xs:IDREF
#             xs:IDREFS
#             xs:NCName
#             xs:NMTOKEN
#             xs:NMTOKENS
#             xs:NOTATION
#             xs:Name
#             OrderStatusCatalog
#             xs:QName
#             ResultCode
#             xs:all
#             xs:allNNI
#             xs:annotated
#             xs:anyType
#             xs:anyURI
#             xs:attribute
#             xs:attributeGroup
#             xs:attributeGroupRef
#             xs:base64Binary
#             xs:blockSet
#             xs:boolean
#             xs:byte
#             xs:complexRestrictionType
#             xs:complexType
#             xs:date
#             xs:dateTime
#             xs:decimal
#             xs:derivationControl
#             xs:derivationSet
#             xs:double
#             xs:duration
#             xs:element
#             xs:explicitGroup
#             xs:extensionType
#             xs:facet
#             xs:float
#             xs:formChoice
#             xs:fullDerivationSet
#             xs:gDay
#             xs:gMonth
#             xs:gMonthDay
#             xs:gYear
#             xs:gYearMonth
#             xs:group
#             xs:groupRef
#             xs:hexBinary
#             xs:int
#             xs:integer
#             xs:keybase
#             xs:language
#             xs:localComplexType
#             xs:localElement
#             xs:localSimpleType
#             xs:long
#             xs:namedAttributeGroup
#             xs:namedGroup
#             xs:namespaceList
#             xs:narrowMaxMin
#             xs:negativeInteger
#             xs:noFixedFacet
#             xs:nonNegativeInteger
#             xs:nonPositiveInteger
#             xs:normalizedString
#             xs:numFacet
#             xs:openAttrs
#             xs:positiveInteger
#             xs:public
#             xs:realGroup
#             xs:reducedDerivationControl
#             xs:restrictionType
#             xs:short
#             xs:simpleDerivationSet
#             xs:simpleExplicitGroup
#             xs:simpleExtensionType
#             xs:simpleRestrictionType
#             xs:simpleType
#             xs:string
#             xs:time
#             xs:token
#             xs:topLevelAttribute
#             xs:topLevelComplexType
#             xs:topLevelElement
#             xs:topLevelSimpleType
#             xs:typeDerivationControl
#             xs:unsignedByte
#             xs:unsignedInt
#             xs:unsignedLong
#             xs:unsignedShort
#             xs:wildcard
#       (GVETransacsSoap12)
#          Methods (248):
#             AdjustOrder(xs:string UserName, xs:string GameCode, xs:string CompCode, xs:string Price, xs:string Volume, xs:string BSAction, xs:string OrderType, xs:string ExpireDate, xs:string OrgVolume, xs:string OrderSource, xs:string CombineNo, )
#             CancelOrder(xs:string OrderID, )
#             CancelOrderStr_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:string comment, )
#             ChangeOrder(xs:string OrderID, xs:double Volume, )
#             ChangeOrderPrice(xs:int gmrid, xs:string orderno, xs:string ordertype, xs:string ordernote, xs:float price, xs:string Lang, )
#             ChangeOrder_NS(xs:string TokenString, xs:string OrderID, xs:double Volume, )
#             ChangeOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:double Volume, xs:string comment, )
#             CheckAndUpdateAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             CheckAndUpdateFuturAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             ClearPosition(xs:string AssetCode, )
#             DeleteSMSWaitingMultiRecord(xs:string SMSID, xs:string message, )
#             DeleteSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             FollowOrderAddSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FollowOrderDeleteSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FuturesFinalSettle()
#             GMRIDToStr(xs:int GMRID, )
#             GMRStrToInt(xs:string GMRIDStr, )
#             GetTradableAsset(xs:string AssetCode, )
#             GetTradableAssetList()
#             GetTradableAssetListXML()
#             MarkupQuoteItemDataXML(xs:string AssetCodeList, xs:string QuoteItemLine, xs:string Language, )
#             NewFollowOrderSubscribe(xs:string GMRID, xs:string SubscribeID, xs:int dailylimit, )
#             NewSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             OptionFinalSettle()
#             PutBatchOrder(GVEWSOrderList sGVEWSOrderList, )
#             PutCombineOrder(xs:string GMRID, xs:string CompCode1, xs:string BSAction1, xs:int Volume1, xs:string CompCode2, xs:string BSAction2, xs:int Volume2, xs:string OrderType, xs:float PriceDiff, xs:string OptiNote, xs:string OptiCombinNo, xs:string lang, )
#             PutOrder(GVEWSOrder Order, )
#             PutOrderXML(xs:int GMRID, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML1(xs:string GMRIDStr, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML2(xs:string GMRIDStr, xs:string AssetCode, xs:int PFLAssetID, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML3(xs:string GMRIDStr, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string str_ip, )
#             PutOrderXML3_STWS(xs:int GMRID, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             PutOrderXML3_STWS_2(xs:int GMRID, xs:string CompCode, xs:string username, xs:string gamecode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string expiredate, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             QueryAllSectorList(xs:int ExchID, )
#             QueryAllSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryAllWarrantsSectorList(xs:int ExchID, )
#             QueryAllWarrantsSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryCataIDByGmridAssetClass(xs:string GMRID, xs:string AssetClass, xs:string Lang, )
#             QueryCompanyData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryCountryCode(xs:string Lang, )
#             QueryDayRangeTFXML(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDayRangeTFXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLog()
#             QueryDealLogBusinessTransactionSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogBy2(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2DiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, )
#             QueryDealLogBy2DiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, xs:string comment, )
#             QueryDealLogBy2XML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2XML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, xs:string Language, )
#             QueryDealLogByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogByGMRDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByGMRDayRangeXML(xs:int GMRID, xs:string StartDate, xs:string EndDate, )
#             QueryDealLogByGMRDayRangeXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByOrderID(xs:string OrderID, )
#             QueryDealLogByOrderIDXML(xs:string OrderID, )
#             QueryDealLogByOrderIDXML_NS(xs:string OrderID, xs:string TokenString, xs:string Language, )
#             QueryDealLogCheckSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogCheckSheetByBSActionCompType(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDealLogCheckSheet_STWS(xs:string Comptype, xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogFundTrading(xs:string GMRID, xs:string Lang, )
#             QueryDealLogGVE3ByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogMarginRateSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogWriteOff(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDividendData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryDividendInfoByCompCode(xs:string CompCode, )
#             QueryDividendInfoByCompCode_NS(xs:string CompCode, xs:string Language, )
#             QueryDividendInfoByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDividendInfoByDayRange_NS(xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryDividendInfoByExchDayRange(xs:string ExchID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryExchRate(xs:string HomeFX, xs:string ForeignFx, xs:int amount, )
#             QueryFXCrossRate(xs:string Lang, xs:string Fx, )
#             QueryFameHistoryByGMRID(xs:string GMRIDStr, )
#             QueryFameList(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGMRFameDateXml_NS(xs:string GMRIDStr, xs:dateTime FameDay, )
#             QueryFameListByGameCode(xs:string GameCode, )
#             QueryFameListByGameCodeFameDate(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGameCodeUsername(xs:string GameCode, xs:string Username, )
#             QueryFameListTop10ByGameCode_xml(xs:string GameCode, )
#             QueryFollowOrderApprovedHistoryByWeek_xml(xs:string GMRID, xs:int Year, xs:int Week, )
#             QueryFollowOrderBasicDataByGMRID(xs:string GMRID, )
#             QueryFollowOrderCreditUsedDetail_XML(xs:string GMRID, xs:int followid, )
#             QueryFollowOrderFollowerByGMRID(xs:string GMRIDStr, )
#             QueryFollowOrderMyFansApproved_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansSentSummary_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansWaitForApprove_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolAllList_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolList_XML(xs:string GMRID, )
#             QueryFollowOrderSubScribedByGMRID(xs:string GMRIDStr, )
#             QueryFundDividendInfoByDayRange(xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryFutureSeriesByFutureClass(xs:string FutuClass, )
#             QueryFuturesListMobileXML_NS(xs:int gmrid, xs:string AssetCatalog, xs:string Lang, )
#             QueryFuturesMarginXml(xs:string ExchID, )
#             QueryFuturesPriceByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryFuturesPriceCountByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, )
#             QueryFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string Language, )
#             QueryFuturesQuotePrice(xs:string ExchID, )
#             QueryFuturesQuotePriceXML(xs:string ExchID, )
#             QueryFuturesQuotePriceXML_NS(xs:string ExchID, xs:string Language, )
#             QueryFuturesQuotePrice_NS(xs:string ExchID, xs:string Language, )
#             QueryFxCurrenctAccountListByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryFxQuotePrice(xs:string Lang, )
#             QueryFxQuotePrice_DS(xs:string Lang, )
#             QueryGMRHisFame(xs:int GMRID, )
#             QueryGameDailyReportXML(xs:string gamecode, xs:string itemname, xs:string daydate, )
#             QueryGameRuleRealtimeChecking(xs:int gmrid, )
#             QueryHistoricalFame()
#             QueryHistoricalQuoteData(xs:string AssetCode, xs:int DWM, xs:int Len, )
#             QueryIndexDataByDate(xs:string IndexName, xs:string daydate, xs:string flied, )
#             QueryLatestFameListByGMRID(xs:string GMRID, )
#             QueryLatestFameListByGMRID2(xs:string GMRID, )
#             QueryLatestFameListByGameCodeCountXML(xs:string GameCode, )
#             QueryLatestFameListByGameCodeNewXML(xs:string GameCode, xs:string day, xs:int PageNum, xs:int PageSize, xs:string Lang, )
#             QueryMarketSnap(xs:string CompCode1, xs:string CompCode2, )
#             QueryMarketSnap2(xs:string compcodelist, xs:string lang, )
#             QueryNewsDetailByRptID(xs:long RptID, )
#             QueryNewsTitleByRptIDDate_xml(xs:long RptID, xs:dateTime Daydate, )
#             QueryNewsTop10Title()
#             QueryOddlotWaitingOrderListXML_NS(xs:int SearchTarget, xs:string Language, )
#             QueryOptionATMPriceByOptionClass(xs:string optionclass, )
#             QueryOptionClassByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryOptionClassXML(xs:string ExchID, )
#             QueryOptionSerial(xs:string OptionClass, )
#             QueryOptionUnderlyingPrice(xs:string OptiClass, )
#             QueryOptionUnderlyingPriceXML(xs:string OptiClass, )
#             QueryOptionsBasePrice(xs:string OptiClass, xs:string Lang, )
#             QueryOptionsListMobileXML(xs:string Opticlass, xs:string CPType, xs:string Lang, )
#             QueryOptionsMarginXml(xs:string OptiClass, xs:string CPType, xs:dateTime Maturiy, )
#             QueryOptionsQuotePrice(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOptionsQuotePriceXML(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOrderList()
#             QueryOrderListByDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML2(xs:string GMRIDStr, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryOrderListByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListByDiff2XML_NS(xs:string GMRIDStr, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, xs:string comment, )
#             QueryOrderListGVE3ByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListXML()
#             QueryOrderMaxVolume(xs:string GMRID, xs:string Compcode, xs:string BASction, )
#             QueryOrderStatus(xs:string OrderID, )
#             QueryPortfolioXML()
#             QueryPortfolioXML_NS(xs:string TokenString, )
#             QueryProverb()
#             QueryQuote5Price(xs:string CompCode, )
#             QueryQuotePrice(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2XML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePriceAndAllowOrder(xs:string Compcode, xs:string Gamecode, xs:string Language, )
#             QueryQuotePriceByAssetCatalog(xs:string AssetCatalog, xs:string Target, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingUDP(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingVol(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorID(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDCompTypeCount(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompTypeNew_DS(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int PageNum, xs:int Pagesize, xs:string Language, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompType_DS_NS(xs:string SectorID, xs:string CompType, xs:string Language, )
#             QueryQuotePriceBySectorIDOrderingUDP(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDOrderingVol(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDXML(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDXML_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_DS_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS2(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceXML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice_NS(xs:string AssetCodeList, xs:string Language, )
#             QueryReportClosePositionByGMRDayRange(xs:int gmrid, xs:string startdate, xs:string enddate, xs:string comptypes, xs:string Lang, )
#             QueryReportFutureTradingPerformace(xs:int gmrid, xs:string startdate, xs:string enddate, )
#             QuerySHGYIDX(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySHGYStockData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string Lang, )
#             QuerySelfQuoteListByGMRID(xs:string GMRIDStr, )
#             QuerySelfQuoteListByGMRID_NS(xs:string GMRIDStr, )
#             QueryStockFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string catagory, xs:string Language, )
#             QuerySubscribeNewIssueByGMRID(xs:string GMRID, xs:string Lang, )
#             QuerySystemCompanyChecksumXml_NS(xs:string market, )
#             QueryTodayDealStatisticFutureandOption(xs:string GMRID, xs:string Daydate, )
#             QueryTodayDealStatisticStock(xs:string GMRID, xs:string Daydate, )
#             QueryTodayOpenNAV()
#             QueryTodayOpenNAV_NS(xs:string TokenString, )
#             QueryTodayPositionByCompType(xs:string GMRID, xs:string CompTypeList, xs:string Lang, )
#             QueryTodayPositionByCurrency(xs:string GMRID, xs:string CurrencyList, xs:string Lang, )
#             QueryTodayPositionFund(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundDetailByCompCode(xs:string GMRID, xs:string CompCode, xs:string Lang, )
#             QueryTodayPositionFundXinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionGve3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryTodayPositionNotSettled(xs:string GMRID, xs:string Lang, )
#             QueryTodayTFXML()
#             QueryTodayTFXML_NS(xs:string TokenString, )
#             QueryTotalTFXML()
#             QueryTotalTFXML_NS(xs:string TokenString, )
#             QueryTradeLogSimpleByGMRID(xs:string GMRID, xs:string Language, )
#             QueryTransferAccountListByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListFXByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListGVE3ByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferRecordListGVE3ByGMRIDXML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryTroubleTeamRecordByGMRID(xs:string GMRIDStr, )
#             QueryUserCash(xs:string GMRID, xs:string Lang, )
#             QueryUserCashBriefByGMRID(xs:string GMRID, )
#             QueryUserCashByGMRAccountCurrencyXML_NS(xs:int gmrid, xs:string TradeAccount, xs:string Currency, xs:string Lang, )
#             QueryUserCashGVE3ByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserCashGroupByAccountByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserDetailByGMRID(xs:string GMRIDStr, )
#             QueryUserDetailByUsername(xs:string Username, )
#             QueryUserExchIDByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserProfileByGMRID(xs:string GMRIDStr, )
#             QueryVexchOrderStatisticFutureandOptionAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOption(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOptionByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticStock(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticStockByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserFutureOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserFutureOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserOptionOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserOptionOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserStockOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserStockOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryWaitingOrderList()
#             QueryWaitingOrderListGVE3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingOrderListXML()
#             QueryWaitingOrderListXML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingSMSList()
#             QueryWaitingSMSListGroupByEmail(xs:string Lang, )
#             QueryWarrantsData(xs:string CompCode, xs:string Lang, xs:string AssetClass, xs:string StartDate, xs:string EndDate, xs:string Issuer, )
#             ResetGameInitCash(xs:string GameCode, xs:string InitHold, xs:string AssetCode, )
#             SMSSendComplete(xs:int SMSID, xs:string message, )
#             SetLanguage(xs:string sLanguage, )
#             SignUpStatis(xs:string Gamecode, )
#             TransferCash(xs:string FromAccount, xs:string ToAccount, xs:double Amount, )
#             TransferCash_NS(xs:string GMRID, xs:string FromAccount, xs:string FromCurrency, xs:string ToAccount, xs:string ToCurrency, xs:double Amount, )
#             UpdateFollowOrderDailyLimit(xs:string GMRID, xs:int followed, xs:int dailylimit, )
#             UpdateFollowOrderSubscribeStatus(xs:string followorderids, xs:string GMRID, xs:int toStatus, )
#             UpdateSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, xs:string colname, xs:string Data, )
#             UpdateSelfQuoteDefault(xs:string GMRID, xs:string QuoteID, )
#             UpdateSelfQuoteNameByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string SelfQuoteName, )
#             UpdateSubscribeNewIssue(xs:string GMRID, xs:int sysid, xs:float subscribe, )
#          Types (101):
#             ArrayOfAnyType
#             ArrayOfString
#             AssetOrderType
#             BSActionType
#             xs:ENTITIES
#             xs:ENTITY
#             GVEWSOrder
#             GVEWSOrderList
#             GVEWSPortfolio
#             GVEWSResult
#             GVEWSUserLogList
#             xs:ID
#             xs:IDREF
#             xs:IDREFS
#             xs:NCName
#             xs:NMTOKEN
#             xs:NMTOKENS
#             xs:NOTATION
#             xs:Name
#             OrderStatusCatalog
#             xs:QName
#             ResultCode
#             xs:all
#             xs:allNNI
#             xs:annotated
#             xs:anyType
#             xs:anyURI
#             xs:attribute
#             xs:attributeGroup
#             xs:attributeGroupRef
#             xs:base64Binary
#             xs:blockSet
#             xs:boolean
#             xs:byte
#             xs:complexRestrictionType
#             xs:complexType
#             xs:date
#             xs:dateTime
#             xs:decimal
#             xs:derivationControl
#             xs:derivationSet
#             xs:double
#             xs:duration
#             xs:element
#             xs:explicitGroup
#             xs:extensionType
#             xs:facet
#             xs:float
#             xs:formChoice
#             xs:fullDerivationSet
#             xs:gDay
#             xs:gMonth
#             xs:gMonthDay
#             xs:gYear
#             xs:gYearMonth
#             xs:group
#             xs:groupRef
#             xs:hexBinary
#             xs:int
#             xs:integer
#             xs:keybase
#             xs:language
#             xs:localComplexType
#             xs:localElement
#             xs:localSimpleType
#             xs:long
#             xs:namedAttributeGroup
#             xs:namedGroup
#             xs:namespaceList
#             xs:narrowMaxMin
#             xs:negativeInteger
#             xs:noFixedFacet
#             xs:nonNegativeInteger
#             xs:nonPositiveInteger
#             xs:normalizedString
#             xs:numFacet
#             xs:openAttrs
#             xs:positiveInteger
#             xs:public
#             xs:realGroup
#             xs:reducedDerivationControl
#             xs:restrictionType
#             xs:short
#             xs:simpleDerivationSet
#             xs:simpleExplicitGroup
#             xs:simpleExtensionType
#             xs:simpleRestrictionType
#             xs:simpleType
#             xs:string
#             xs:time
#             xs:token
#             xs:topLevelAttribute
#             xs:topLevelComplexType
#             xs:topLevelElement
#             xs:topLevelSimpleType
#             xs:typeDerivationControl
#             xs:unsignedByte
#             xs:unsignedInt
#             xs:unsignedLong
#             xs:unsignedShort
#             xs:wildcard
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 第一種

# %%
#9日 K值低於 20% 買進，高於 80% 賣出
def testKD92080set(start_money,close,data):
    K = data.iloc[0:,1] #取 K 值
    #D = data.iloc[0:,2] #取 D 值
    #DIF = data2.iloc[0:,0] #取 DIF 值
    #DEA = data2.iloc[0:,1] #取 DEA 值
    #MACD = data2.iloc[0:,2] #取 MACD 值
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    principal = float(start_money)
    stock_count = 0 #股票張數
    bought_money = 0 #剩餘金額
    final_money = 0 #最終金額
    profit = 0 #獲利
    rateOfReturn = 0.0 #報酬率
    record = [] #存取購買股票時的股價
    lastROP = [] #存取報酬率

    print("1",start_money)
    for i in range(len(K)):
        print(date[i])
        print(i)
        print(close[i])
        if(stock_count==0):
            if(float(start_money)>=close[i]*1000):
                if(K[i]<20):
                    print('K值為:',K[i])
                    print("買了一張股票，股價為:",close[i])
                    stock_count = stock_count + 1
                    start_money = float(start_money) - close[i]*1000
                    record.append(close[i]) #將買的股價放入recorde陣列裡
                    print(record)
                    print('剩餘資金為:',start_money)
                    print('擁有'+str(stock_count)+ '張股票')
                    table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                    #"買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額" 
                else:
                    print("尚未達到買點")
                    #continue
            else:
                print("錢不購買")
                #continue
        else:
            if(close[i] >= record[-1]+5): #現在的股價 >= 停利條件
                print('現在的股價=',close[i])
                print('條件: 現股>=最後一次購買股價+10 = ') # recode[-1]為最後一次交易的股價
                print('最後一次購買股價',record[-1])
                print('最後一次購買股價+5',record[-1]+5)
                print('已達停利標準')
                final_money = start_money + stock_count*close[i]*1000
                print('賣出'+str(stock_count)+'張股票')
                record[:] = []
                stock_count = 0
                print("股價為:",close[i])
                print("擁有資金:",final_money)
                profit = final_money - principal
                rateOfReturn = profit/principal*100
                print("獲利:" , profit)
                print("報酬率:" , rateOfReturn)
                table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                lastROP.append(rateOfReturn)
                start_money = final_money #將初始金額改為賣出後的總金額
                #continue
            elif(close[i] <= record[-1]-5):
                print('現在的股價=',close[i]) 
                print('條件: 現股<=最後一次購買股價-5 = ')
                print('最後一次購買股價',record[-1])
                print('最後一次購買股價-5',record[-1]-5)
                print('已達停損標準')
                final_money = start_money + stock_count*close[i]*1000
                print('賣出'+str(stock_count)+'張股票')
                record[:] = []
                stock_count = 0
                print("股價為:",close[i])
                print("i:",i)
                print("擁有資金:",final_money)
                profit = final_money - principal
                rateOfReturn = profit/principal*100
                print("獲利:" , profit)
                print("報酬率:" , rateOfReturn)
                table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                lastROP.append(rateOfReturn)
                start_money = final_money #將初始金額改為賣出後的總金額
                #continue
            elif(K[i]<20):
                if(float(start_money)>=close[i]*1000):
                    print('K值為:',K[i])
                    print("買了一張股票，股價為:",close[i])
                    stock_count = stock_count + 1
                    start_money = float(start_money) - close[i]*1000
                    record.append(close[i]) #將買的股價放入recorde陣列裡
                    print(record)
                    print('剩餘資金為:',start_money)
                    print('擁有'+str(stock_count)+ '張股票')
                    table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                    #"買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額" 
                else:
                    print("錢不夠再買一張股票")
                    #continue
            elif(K[i]>80):
                print('K值為:',K[i])
                print("手上有"+str(stock_count)+"張股票可賣")
                final_money = start_money + stock_count*close[i]*1000
                print('賣出'+str(stock_count)+'張股票')
                record[:] = []
                stock_count = 0
                print("股價為:",close[i])
                print("i:",i)
                print("擁有資金:",final_money)
                profit = final_money - principal
                rateOfReturn = profit/principal*100
                print("獲利:" , profit)
                print("報酬率:" , rateOfReturn)
                table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                lastROP.append(rateOfReturn)
                start_money = final_money
            else:
                print("尚未達到買賣點")
                #continue
    print("\n")        
    print('總報酬率',lastROP[-1])
    #textPanel.insert("end", rateOfReturn)
    textPanel1.insert("end", lastROP[-1])
    return lastROP[-1]

# %% [markdown]
# ## 第二種

# %%
#K值連續三天低於20後反彈(買進)，K值連續三天高於80後反彈(賣出)
def testKDcontSet(start_money,sell,buy,sProfit,sLoss,close,data):
    K = data.iloc[0:,1] #取 K 值
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    principal = float(start_money)
    stock_count = 0 #股票張數
    #bought_money = 0 #剩餘金額
    final_money = 0 #最終金額
    profit = 0 #獲利
    rateOfReturn = 0.0 #報酬率
    record = [] #存取購買股票時的股價
    lastROP = [] #存取報酬率
    print("2",start_money)
    
    for i in range(len(K)):
        if stock_count == 0:
            if float(start_money)>=close[i]*1000:
                if K[i]<int(buy) and K[i+1]<int(buy) and K[i+2]<int(buy): 
                    if K[i+3]>int(buy): # K值連續 3 天小於 20 後上升
                        stock_count = stock_count + 1 #買一張股票
                        start_money = float(start_money) - (float(close[i+3])*1000) #剩餘資金 = 初始資金 - 當日股價
                        print(date[i],'K值為:',K[i])
                        print(date[i+1],'K值為:',K[i+1])
                        print(date[i+2],'K值為:',K[i+2])
                        print(date[i+3],'K值為:',K[i+3])
                        print("買了一張股票，股價為:",close[i+3])
                        record.append(close[i+3]) #將買的股價放入record陣列裡
                        print(record)
                        print('剩餘資金為:',start_money)
                        print('擁有'+str(stock_count)+ '張股票')
                        table.insert("","end",values=("BUY",date[i+3],close[i+3],str(stock_count),start_money))
                else:
                    print("未達買點")
                    continue
            else:
                print("資金不足")
                continue
                
        else:
            if(close[i+3] >= record[-1]+5): #現在的股價 >= 停利條件
                    print(date[i+3])
                    print('現在的股價=',close[i+3]) 
                    print('條件: 現股>=最後一次購買股價+5 = ') # recode[-1]為最後一次交易的股價
                    print('最後一次購買股價',record[-1])
                    print('最後一次購買股價+5',record[-1]+5)
                    print('已達停利標準')
                    final_money = start_money + stock_count*close[i+3]*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:] = []
                    stock_count = 0
                    print("股價為:",close[i+3])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    lastROP.append(rateOfReturn)
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    table.insert("","end",values=("SELL",date[i+3],close[i+3],str(stock_count),final_money,profit)) 

                    #lastROP.append(rateOfReturn)
                    start_money = final_money #將初始金額改為賣出後的總金額
                    continue
            elif(close[i+3] <= record[-1]-5): #現在的股價 <= 停利條件
                    print(date[i+3])
                    print('現在的股價=',close[i+3]) 
                    print('條件: 現股<=最後一次購買股價-5 = ')
                    print('最後一次購買股價',record[-1])
                    print('最後一次購買股價-5',record[-1]-5)
                    print('已達停損標準')
                    final_money = start_money + stock_count*close[i+3]*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:] = []
                    stock_count = 0
                    print("股價為:",close[i+3])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    lastROP.append(rateOfReturn)
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    table.insert("","end",values=("SELL",date[i+3],close[i+3],str(stock_count),final_money,profit)) 

                    #lastROP.append(rateOfReturn)
                    start_money = final_money #將初始金額改為賣出後的總金額
                    continue
            
            elif K[i]<int(buy) and K[i+1]<int(buy) and K[i+2]<int(buy):
                if K[i+3]>int(buy):
                    if float(start_money)>=close[i]*1000:
                        stock_count = stock_count + 1 #買一張股票
                        start_money = float(start_money) - (float(close[i+3])*1000) #剩餘資金 = 初始資金 - 當日股價
                        print(date[i],'K值為:',K[i])
                        print(date[i+1],'K值為:',K[i+1])
                        print(date[i+2],'K值為:',K[i+2])
                        print(date[i+3],'K值為:',K[i+3])
                        print("買了一張股票，股價為:",close[i+3])
                        record.append(close[i+3]) #將買的股價放入record陣列裡
                        print(record)
                        print('剩餘資金為:',start_money)
                        print('擁有'+str(stock_count)+ '張股票')
                        table.insert("","end",values=("BUY",date[i+3],close[i+3],str(stock_count),start_money))
                    else:
                        print("資金不足")
            elif K[i]>int(sell) and K[i+1]>int(sell) and K[i+2]>int(sell):
                if K[i+3]<int(sell):
                    print(date[i],'K值為:',K[i])
                    print(date[i+1],'K值為:',K[i+1])
                    print(date[i+2],'K值為:',K[i+2])
                    print(date[i+3],'K值為:',K[i+3])
                    print("手上有"+str(stock_count)+"張股票可賣")
                    final_money = start_money + stock_count*float(close[i+3])*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:]=[]
                    stock_count = 0
                    print("股價為:",close[i+3])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    lastROP.append(rateOfReturn)
                    print("獲利:" , profit)
                    print("報酬率:" , )
                    table.insert("","end",values=("SELL",date[i+3],close[i+3],str(stock_count),final_money,profit))
                    #lastROP.append(rateOfReturn)
                    start_money = final_money
            else:
                print(date[i])
                print("未達買賣點")
    print("\n")        
    #textPanel.insert("end", lastROP[-1])
    textPanel2.insert("end", lastROP[-1])
    print('總報酬率',lastROP[-1])
    return lastROP[-1]

# %% [markdown]
# ## 第三種

# %%
## K值向上突破D值 (黃金交叉)，K值向下突破 D值 (死亡交叉)
def testKDcrossSet(start_money,close,data):
    K = data.iloc[0:,1] #取 K 值
    D = data.iloc[0:,2] #取 D 值
    principal = float(start_money)
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    stock_count = 0 #股票張數
    bought_money = 0.0 #剩餘金額
    final_money = 0.0 #最終金額
    profit = 0.0 #獲利
    rateOfReturn = 0.0 #報酬率
    lastROP = []  
    record = []

    for i in range(1,len(K)):
        #print(date[i])
        print(date[i])
        print(i)
        print(close[i])
        if(len(record)==0): #手上沒股票
            if(float(start_money)>=close[i-1]*1000): #身上錢夠
                if (K[i-1]<D[i-1] and K[i]>D[i]): #黃金交叉，買股票
                        stock_count = stock_count + 1
                        start_money = float(start_money) - (float(close[i-1])*1000)
                        record.append(close[i-1])
                        print("record:",record)
                        print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                        print("買了一張股票，股價為:",close[i-1])
                        print('剩餘資金為:',start_money)
                        print('擁有'+str(stock_count)+ '張股票')
                        table.insert("","end",values=("BUY",date[i-1],close[i-1],str(stock_count),start_money))
                else: #不是黃金交叉，直接進入下個迴圈
                    continue
            else: #錢不夠，進入下個迴圈
                continue
        elif(len(record)!=0): #身上有股票，判斷是否符合停利/停損，是->賣掉，否->判斷為黃金交叉(買)/死亡交叉(賣)/都不是(繼續)
                if close[i-1] >= record[-1]+5 :#停利，賣股票
                    print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                    print("手上有"+str(stock_count)+"張股票可賣")
                    final_money = start_money + stock_count*float(close[i-1])*1000
                    print('賣出'+str(stock_count)+'張股票')
                    stock_count = 0
                    record[:]=[]
                    print("股價為:",close[i-1])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    lastROP.append(rateOfReturn)
                    table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                    start_money = final_money
                elif close[i-1] <= record[-1]-5 :
                    print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                    print("手上有"+str(stock_count)+"張股票可賣")
                    final_money = start_money + stock_count*float(close[i-1])*1000
                    print('賣出'+str(stock_count)+'張股票')
                    stock_count = 0
                    record[:]=[]
                    print("股價為:",close[i-1])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    lastROP.append(rateOfReturn)
                    table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                    start_money = final_money
                elif (K[i-1]<D[i-1] and K[i]>D[i]):#買
                        if float(start_money)>=close[i]*1000:
                            stock_count = stock_count + 1 #買一張股票
                            bought_money = start_money - (float(close[i-1])*1000) #剩餘資金 = 上一次交易剩餘資金 - 當日股價
                            record.append(close[i])
                            print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                            print("買了一張股票，股價為:",close[i-1])
                            print('剩餘資金為:',bought_money)
                            print('擁有'+str(stock_count)+ '張股票')
                            table.insert("","end",values=("BUY",date[i-1],close[i-1],str(stock_count),bought_money))
                            start_money = bought_money
                        else:
                            continue
                elif (K[i-1]>D[i-1] and K[i]<D[i]):
                    print(date[i],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                    print("手上有"+str(stock_count)+"張股票可賣")
                    final_money = start_money + stock_count*float(close[i-1])*1000
                    print('賣出'+str(stock_count)+'張股票')
                    stock_count = 0
                    record[:]=[]
                    print("股價為:",close[i-1])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    lastROP.append(rateOfReturn)
                    table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                    start_money = final_money
                else:
                    continue
    textPanel3.insert("end",lastROP[-1])
    return lastROP[-1]

# %%
def first():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    #buy = buy_entry.get()
    #sell = sell_entry.get()
    #sProfit = sProfit_entry.get()
    #sLoss = sLoss_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;

    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
    #data.plot()
    data.reset_index(inplace=True)
    
    #testKD92080set(start_money,buy,sell,sProfit,sLoss,close,data)
    return  testKD92080set(start_money,close2,data)

# %%
def second():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    buy = buy_entry.get()
    sell = sell_entry.get()
    sProfit = sProfit_entry.get()
    sLoss = sLoss_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;

    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
    #data.plot()
    data.reset_index(inplace=True)
    #print(data)
    
    #testKDcontSet(start_money,sell,buy,sProfit,sLoss,close,data)
    
    return testKDcontSet(start_money,sell,buy,sProfit,sLoss,close2,data)

# %%
def third():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    #buy = buy_entry.get()
    #sell = sell_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    #sProfit = sProfit_entry.get()
    #sLoss = sLoss_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    print(close)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    #callTable()
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;

    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
    #data.plot()
    data.reset_index(inplace=True)
    #print(data)
    
    #testKDcrossSet(start_money,close,sProfit,sLoss,data)
    
    return testKDcrossSet(start_money,close2,data)

# %%
def callfunc():
    ans = v.get()
    if(ans=="K值小於設定值進場，大於設定值出場"):
        first()
        #table=ttk.Treeview(frm_r)#表格
    elif(ans=="K值連續3天小於設定值後反彈進場"):
        second()
    elif(ans=="黃金交叉與死亡交叉"):
        third()
def Run3():
    #first()
    #second()
    #third()
    a = int(first())
    b = int(second())
    c = int(third())
    if a>b:
        if b>c:
            print("第一個策略獲利最多")
            bestanswer = "第一個策略獲利最多"
        else:
            if a>c:
                print('第一個策略獲利最多')
                bestanswer = "第一個策略獲利最多"

            else:
                print('第三個策略獲利最多')
                bestanswer = "第三個策略獲利最多"
    elif a<b:
        if b<c:
            print('第三個策略獲利最多')
            bestanswer = "第三個策略獲利最多"
        else:
            if c>a:
                print('第二個策略獲利最多')
                bestanswer = "第二個策略獲利最多"
            else:
                print('第二個策略獲利最多')
                bestanswer = "第二個策略獲利最多"
    answer2 = tk.Label(frm_l, text= bestanswer)
    answer2.grid(row =18, column = 1,sticky='W')
def deletetable():
    x = table.get_children()
    for item in x: 
        table.delete(item) 
    textPanel.delete('1.0','end') 
    textPanel1.delete('1.0','end') 
    textPanel2.delete('1.0','end') 
    textPanel3.delete('1.0','end')

# %%
def order():
    win.destroy()
    order = tk.Tk()
    order.title('下單')
    order.geometry("1300x800")
    frame = tk.Frame(order)
    frame.grid(row = 0)
    frame_l = tk.Frame(frame, ) #左視窗
    frame_r = tk.Frame(frame) #右視窗
    frame_c = tk.Frame(frame,)
    frame_l.grid(row = 1,column = 0)
    frame_r.grid(row = 1,column = 2)
    frame_c.grid(row = 1,column = 1)
    #textPanel = tk.Text(frame_r,height=30, width=65)
    #textPanel.grid()
    
    
    
    
    def getOrderRecorde(): #委託紀錄id(

        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("委託時間","委託單ID","股票代碼","公司名稱","委託價格","委託數量","買賣類型","掛單類型")
        #表示列,不显示
        table.column("委託時間",width=160)
        table.column("委託單ID",width=100)
        table.column("股票代碼",width=80)
        table.column("公司名稱",width=80)
        table.column("委託價格",width=80)
        table.column("委託數量",width=80)
        table.column("買賣類型",width=80)
        table.column("掛單類型",width=80)

        #显示表头
        table.heading("委託時間",text="委託時間")
        table.heading("委託單ID",text="委託單ID")
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("委託價格",text="委託價格")
        table.heading("委託數量",text="委託數量")
        table.heading("買賣類型",text="買賣類型")
        table.heading("掛單類型",text="掛單類型")
        
        table.grid(row = 0, column = 0)
        order = client.service.QueryWaitingOrderListGVE3XML_NS("", "TC", )
        root2 = ET.fromstring(order)
        i = 1
        for country in root2.findall('Order'):
            print("第",i,"筆委託紀錄")
            OrderTime = country.get('OrderTime')
            OrderID = country.get('OrderID')
            AssetID = country.get('AssetID')
            CompName = country.get('CompName')
            Price = country.get('Price')
            Volume = country.get('Volume')
            BSAction = country.get('BSAction')
            OrderType = country.get('OrderType')

            print(OrderTime, OrderID, AssetID, CompName, Price, Volume, BSAction, OrderType)
            i+=1
            table.insert("","end",values=(OrderTime,OrderID,AssetID,CompName,Price,Volume,BSAction,OrderType))
            
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        #textPanel.insert("end", order)
    def getInstock(): #庫存
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("股票代碼","公司名稱","持有數量","持有成本","現價","漲跌","盈虧","累積未實現損益")
        #表示列,不显示
        table.column("股票代碼",width=160)
        table.column("公司名稱",width=80)
        table.column("持有數量",width=80)
        table.column("持有成本",width=80)
        table.column("現價",width=80)
        table.column("漲跌",width=80)
        table.column("盈虧",width=80)
        table.column("累積未實現損益",width=80)

        #显示表头
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("持有數量",text="持有數量")
        table.heading("持有成本",text="持有成本")
        table.heading("現價",text="現價")
        table.heading("漲跌",text="漲跌")
        table.heading("盈虧",text="盈虧")
        table.heading("累積未實現損益",text="累積未實現損益")
        
        table.grid(row = 0, column = 0)
        
        instock = client.service.QueryTodayPositionGve3XML_NS("", "TC", )
        root1 = ET.fromstring(instock)
        i = 1
        for country in root1.findall('PortfolioAsset'):
            print("第",i,"筆庫存紀錄")
            #LogID = country.get('LogID')
            AssetCode = country.get('AssetCode')
            CompName = country.get('CompName')
            Hold = country.get('Hold')
            Cost = country.get('Cost')
            QuotePrice = country.get('QuotePrice')
            UpDown = country.get('UpDown')
            PL = country.get('PL')
            UnRealizedPL = country.get('UnRealizedPL')
            print(AssetCode, CompName, Hold, Cost, QuotePrice, UpDown, PL, UnRealizedPL)
            i+=1
            table.insert("","end",values=(AssetCode,CompName,Hold,Cost,QuotePrice,UpDown,PL,UnRealizedPL))
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        #textPanel.insert("end", instock)
    def getDeal(): #成交紀錄
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("交易時間","股票代碼","公司名稱","買賣類型","掛單類型","成交價","成交量","手續費","交易訊息")
        table.column("交易時間",width=160)   #表示列,不显示
        table.column("股票代碼",width=80)
        table.column("公司名稱",width=80)
        table.column("買賣類型",width=80)
        table.column("掛單類型",width=80)
        table.column("成交價",width=80)
        table.column("成交量",width=80)
        table.column("手續費",width=80)
        table.column("交易訊息",width=80)

        table.heading("交易時間",text="交易時間")  #显示表头
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("買賣類型",text="買賣類型")
        table.heading("掛單類型",text="掛單類型")
        table.heading("成交價",text="成交價")
        table.heading("成交量",text="成交量")
        table.heading("手續費",text="手續費")
        table.heading("交易訊息",text="交易訊息")
        
        table.grid(row = 0, column = 0)
        deal = client.service.QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(1111708496, "2019/04/01", "2019/12/31", "TW", )
        i = 1
        root = ET.fromstring(deal)
        for country in root.findall('GVEUserLog'):
            print("第",i,"筆成交紀錄")
            #LogID = country.get('LogID')
            LogTime = country.get('LogTime')
            AssetCode = country.get('AssetCode')
            CompName = country.get('CompName')
            BSAction = country.get('BSAction')
            OrderType = country.get('OrderType')
            Price = country.get('Price')
            Volume = country.get('Volume')
            fee = country.get('fee')
            logdesc = country.get('logdesc')
            print(LogTime, AssetCode, CompName, BSAction, OrderType, Price, Volume, fee, logdesc)
            i+=1
            table.insert("","end",values=(LogTime,AssetCode,CompName,BSAction,OrderType,Price,Volume,fee,logdesc))
            
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
    def getOrder(): #下單
    
            #GMRIDstr = GMRIDstr_Entry.get()
            compcode = CompCode_Entry.get()
            price = Price_Entry.get()
            volume = Volume_Entry.get()
            bsaction = BSAction_Entry.get()
            ordertype = OrderType_Entry.get()
            #currency = Currency_Entry.get()
            isoddlot = IsOddLot_Entry.get()
            ordernote = OrderNote_Entry.get()
            #octype = OCtype_Entry.get()
            #combineno = CombineNo_Entry.get()
            #parameter = OrderParameter_Entry.get()
            #lang = lang_Entry.get()
            #ip = str_ip_Entry.get()

            result = client.service.PutOrderXML3("BCSP", compcode, price, volume, bsaction, ordertype, isoddlot, "TWD", ordernote, "0", "","0", "TC", "127.0.0.1", )
            print(result)
            new = result.split("\"")
            if new[1] == "Success":
                tk.messagebox.showinfo(title='回報', message='Success')
            elif new[1] == "Failure":
                tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:'+new[5])
            else:
                tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:格式輸入錯誤')

    def getPrice():
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("成交價","成交量","委買價","委買量","委賣價","委賣量","昨收價","漲停價","跌停價")
         #表示列,不显示
        table.column("成交價",width=160)
        table.column("成交量",width=80)
        table.column("委買價",width=80)
        table.column("委買量",width=80)
        table.column("委賣價",width=80)
        table.column("委賣量",width=80)
        table.column("昨收價",width=80)
        table.column("漲停價",width=80)
        table.column("跌停價",width=80)

        table.heading("成交價",text="成交價")  #显示表头
        table.heading("成交量",text="成交量")
        table.heading("委買價",text="委買價")
        table.heading("委買量",text="委買量")
        table.heading("委賣價",text="委賣價")
        table.heading("委賣量",text="委賣量")
        table.heading("昨收價",text="昨收價")
        table.heading("漲停價",text="漲停價")
        table.heading("跌停價",text="跌停價")
        
        table.grid(row = 0, column = 0)
        compcode = CompCode_Entry.get()
        price = client.service.QueryQuote5Price(compcode, )
        r = ET.fromstring(price)
        r_new = "您查詢的股價為:\n"+"成交價:"+str(r[0][0].text)+\
                                "\n"+"成交量:"+str(r[0][1].text)+\
                                "\n"+"委買價:"+str(r[0][2].text)+\
                                "\n"+"委買量:"+str(r[0][22].text)+\
                                "\n"+"委賣價:"+str(r[0][12].text)+\
                                "\n"+"委賣量:"+str(r[0][23].text)+\
                                "\n"+"昨收價:"+str(r[0][24].text)+\
                                "\n"+"漲停價:"+str(r[0][25].text)+\
                                "\n"+"跌停價:"+str(r[0][26].text)+"\n"
        
        
        table.insert("","end", values=(str(r[0][0].text),str(r[0][1].text),str(r[0][2].text),str(r[0][22].text),str(r[0][12].text),str(r[0][23].text),str(r[0][24].text),str(r[0][25].text),str(r[0][26].text)))
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        
    def cancelOrder():
        cancle_id = cancle_entry.get()
        TokenString = ""
        client.service.CancelOrderStr_NS(TokenString, cancle_id, )
        getOrderRecorde()
    #GMRIDstr
    #GMRIDstr = tk.Label(frame_l, text="GMRIDstr")
    #GMRIDstr.grid(row=0,column=0)
    #股票代碼
    CompCode = tk.Label(frame_l, text="CompCode")
    CompCode.grid(row=1,column=0)
    #價格
    Price = tk.Label(frame_l, text="Price")
    Price.grid(row=2,column=0)
    #成交量
    Volumn = tk.Label(frame_l, text="Volume")
    Volumn.grid(row=3,column=0)
    #使用代碼 普通買進(B),普通賣出(S),融資買入(MB),融資賣出(RB),融券買入(RS),
    BSAction = tk.Label(frame_l, text="BSAction")
    BSAction.grid(row=4,column=0)
    #下單類型 漲停價(LMTU),跌停價(LMTD),限價單(LMT)，期權市價單：MKT
    OrderType = tk.Label(frame_l, text="OrderType")
    OrderType.grid(row=5,column=0)
    #預設給零  0: normal (照ASSET CATALOG中的交易時間), 1:for TW 零股交易
    IsOddLot = tk.Label(frame_l, text="IsOddLot")
    IsOddLot.grid(row=7,column=0)
    #Currency TWD
    #Currency = tk.Label(frame_l, text="Currency")
    #Currency.grid(row=6,column=0)
    #預設ROD
    OrderNote = tk.Label(frame_l, text ="orderNote")
    OrderNote.grid(row=8,column=0)
    #現貨固定給零；期貨作多：buy，作空：sell；選擇權新倉：O，平倉：C
    #OCtype = tk.Label(frame_l, text ="OCtype")
    #OCtype.grid(row=9,column=0)
    #固定給空白
    #CombineNo = tk.Label(frame_l, text ="CombineNo")
    #CombineNo.grid(row=10,column=0)
    #預設給零  0:普通, 50:當沖單, 60:組合單
    #OrderParameter = tk.Label(frame_l, text ="OrderParameter")
    #OrderParameter.grid(row=11,column=0)
    #Lang //固定給TC
    #lang = tk.Label(frame_l, text ="lang")
    #lang.grid(row=12,column=0)
    #str_ip //IP位置
    #str_ip = tk.Label(frame_l, text ="str_ip")
    #str_ip.grid(row=13,column=0)
    #取消委託
    cancleOrder = tk.Label(frame_l, text = "--------取消委託--------")
    cancleOrder.grid(row=14,column=0)
    cancle = tk.Label(frame_l, text = "輸入ID:")
    cancle.grid(row = 15, column = 0)
    cancle_entry = tk.Entry(frame_l)
    cancle_entry.grid(row=15,column = 1)
    #lb.pack()
    #GMRIDstr = tk.StringVar(value="BCSP")
    CompCode = tk.StringVar(value="2330.tw")
    #Price = tk.StringVar(value="2330.tw")
    Volume = tk.StringVar(value="1000")
    BSAction = tk.StringVar(value="B")
    OrderType = tk.StringVar(value="MKT")
    #Currency = tk.StringVar(value="TWD")
    IsOddLot = tk.StringVar(value="0")
    OrderNote = tk.StringVar(value="ROD")
    #OCtype = tk.StringVar(value="0")
    #OrderParameter = tk.StringVar(value="0")
    #lang = tk.StringVar(value="TC")
    #str_ip = tk.StringVar(value="127.0.0.1")
    
    #GMRIDstr_Entry = tk.Entry(frame_l,textvariable=GMRIDstr)
    #GMRIDstr_Entry.grid(row=0,column=1)

    CompCode_Entry = tk.Entry(frame_l,textvariable=CompCode)
    CompCode_Entry.grid(row=1,column=1)

    Price_Entry = tk.Entry(frame_l,textvariable=Price)
    Price_Entry.grid(row=2,column=1)

    Volume_Entry = tk.Entry(frame_l,textvariable=Volume)
    Volume_Entry.grid(row=3,column=1)

    BSAction_Entry = tk.Entry(frame_l,textvariable=BSAction)
    BSAction_Entry.grid(row=4,column=1)

    OrderType_Entry = tk.Entry(frame_l,textvariable=OrderType)
    OrderType_Entry.grid(row=5,column=1)

    #Currency_Entry = tk.Entry(frame_l,textvariable=Currency)
    #Currency_Entry.grid(row=6,column=1)

    IsOddLot_Entry = tk.Entry(frame_l,textvariable=IsOddLot)
    IsOddLot_Entry.grid(row=7,column=1)

    OrderNote_Entry = tk.Entry(frame_l,textvariable=OrderNote)
    OrderNote_Entry.grid(row=8,column=1)

    #OCtype_Entry = tk.Entry(frame_l,textvariable=OCtype)
    #OCtype_Entry.grid(row=9,column=1)

    #CombineNo_Entry = tk.Entry(frame_l,textvariable=CombineNo)
    #CombineNo_Entry.grid(row=10,column=1)

    #OrderParameter_Entry = tk.Entry(frame_l,textvariable=OrderParameter)
    #OrderParameter_Entry.grid(row=11,column=1)

    #lang_Entry = tk.Entry(frame_l,textvariable=lang)
    #lang_Entry.grid(row=12,column=1)

    #str_ip_Entry = tk.Entry(frame_l,textvariable=str_ip)
    #str_ip_Entry.grid(row=13,column=1)

#-------------------------Button-------------------------#    
    order_btn = tk.Button(frame_c , text="下單", command=getOrder) #彈出視窗表示成功或失敗
    order_btn.grid()
        
    record_btn = tk.Button(frame_c, text="委託紀錄", command=getOrderRecorde)#以表格方式呈現
    record_btn.grid()
    
    instock_btn = tk.Button(frame_c, text="庫存查詢", command=getInstock) #以表格方式呈現
    instock_btn.grid()
    
    deal_btn = tk.Button(frame_c, text="成交查詢", command = getDeal)
    deal_btn.grid()
    
    stockprice_btn = tk.Button(frame_c, text="即時股價查詢", command=getPrice) #彈出視窗，輸入股票代碼，印出股價
    stockprice_btn.grid()
    
    cancle_btn = tk.Button(frame_l, text="取消委託", command = cancelOrder)
    cancle_btn.grid(row = 17,column = 0)

# %%
win = tk.Tk() #建立主視窗
win.title("股票回測") #視窗標題
win.geometry("1000x600")#寬*高
#style = ttk.Style(win)
#style.theme_use('classic') 
#win.resizable(False, False)#限制縮放
#win.config(background="#323232") #視窗背景顏色
#框架
frm = tk.Frame(win)
frm.grid(row = 0)
frm_l = tk.Frame(frm, ) #左視窗
frm_r = tk.Frame(frm) #右視窗
frm_l.grid(row = 1,column = 0)
frm_r.grid(row = 1,column = 1)
#tk.Label(frm,bg="#323232",fg="white",text="輸入股票代碼:" )
#-----------------------Text---------------------------------
#股票代碼
stockCode = tk.Label(frm_l, text="輸入股票代碼:")
stockCode.grid(row=0,column=0,sticky='NW')
#股票日期
startTime = tk.Label(frm_l, text="輸入起始時間:")
startTime.grid(row=1,column=0,sticky='NW')
endTime = tk.Label(frm_l, text='輸入結束時間')
endTime.grid(row=2,column=0,sticky='NW')
#初始金額
start_money = tk.Label(frm_l, text="輸入初始金額:")
start_money.grid(row=3,column=0,sticky='NW')
#低於幾%買進
buy = tk.Label(frm_l, text="輸入買進條件:")
buy.grid(row=4,column=0,sticky='NW')
#高於幾%賣出
sell = tk.Label(frm_l, text="輸入賣出條件:")
sell.grid(row=5,column=0,sticky='NW')
#停利
sProfit = tk.Label(frm_l, text="輸入停利條件:")
sProfit.grid(row=6,column=0,sticky='NW')
#停損
sLoss = tk.Label(frm_l, text="輸入停損條件:")
sLoss.grid(row=7,column=0,sticky='NW')
#lb.pack()

#-------------------------table------------------------------
table=ttk.Treeview(frm_r,show='headings')#表格
table["columns"]=("買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額","賣出獲利")
table.column("買/賣 狀態",width=100)   #表示列,不显示
table.column("交易日期",width=100)
table.column("股票價格",width=100)
table.column("股票庫存",width=100)
table.column("資金餘額",width=100)
table.column("賣出獲利",width=100)

table.heading("買/賣 狀態",text="買/賣 狀態")  #显示表头
table.heading("交易日期",text="交易日期")
table.heading("股票價格",text="股票價格")
table.heading("股票庫存",text="股票庫存")
table.heading("資金餘額",text="資金餘額")
table.heading("賣出獲利",text="賣出獲利")
table.grid()
#--------------------------textPanel-----------------------------------
#報酬率
pOfrate = tk.Label(frm_l, text=' 報酬率 :')
pOfrate.grid(row =14, column = 0,sticky='W')
textPanel = tk.Text(frm_l,height=1, width=4)
textPanel.grid(row =14,column=1,sticky='W')
#報酬率 1
ROP1 = tk.Label(frm_l, text=' K值大小')
ROP1.grid(row =15, column = 0,sticky='W')
textPanel1 = tk.Text(frm_l,height=1, width=4)
textPanel1.grid(row =15, column = 1,sticky='W')
ROP2 = tk.Label(frm_l, text=' 連三反彈')
ROP2.grid(row =16, column = 0,sticky='W')
textPanel2 = tk.Text(frm_l,height=1, width=4)
textPanel2.grid(row =16, column = 1,sticky='W')
ROP3 = tk.Label(frm_l, text=' 黃金交叉')
ROP3.grid(row =17, column = 0,sticky='W')
textPanel3 = tk.Text(frm_l, height=1, width=4)
textPanel3.grid(row =17, column = 1,sticky='W')
answer = tk.Label(frm_l, text=' 比較結果:')
answer.grid(row =18, column = 0,sticky='W')

#----------------------------entry-----------------------------------------
#Entry輸入框
stock = tk.StringVar(value='2330.TW')
time = tk.StringVar(value='2018')
sMoney =tk.StringVar(value='1000000')
bEntry = tk.StringVar(value='20')
sEntry = tk.StringVar(value='80')
pEntry = tk.StringVar(value='0.018')
lEntry = tk.StringVar(value='0.01')

stockCode_entry = tk.Entry(frm_l,textvariable=stock)
stockCode_entry.grid(row=0,column=1,sticky='W')
startTime_entry = tk.Entry(frm_l,textvariable=time)
startTime_entry.grid(row=1,column=1,sticky='W')
endTime_entry = tk.Entry(frm_l)
endTime_entry.grid(row=2,column=1,sticky='W')
start_money_entry = tk.Entry(frm_l,textvariable=sMoney)
start_money_entry.grid(row=3,column=1,sticky='W')
buy_entry = tk.Entry(frm_l,textvariable=bEntry)
buy_entry.grid(row=4,column=1,sticky='W')
sell_entry = tk.Entry(frm_l,textvariable=sEntry)
sell_entry.grid(row=5,column=1,sticky='W')
sProfit_entry = tk.Entry(frm_l,textvariable=pEntry)
sProfit_entry.grid(row=6,column=1,sticky='W')
sLoss_entry = tk.Entry(frm_l,textvariable=lEntry)
sLoss_entry.grid(row=7,column=1,sticky='W')
#option = tk.Option
optionList = ["K值小於設定值進場，大於設定值出場","K值連續3天小於設定值後反彈進場","黃金交叉與死亡交叉"]
v = tk.StringVar()
v.set("選擇條件")
optionmenu = tk.OptionMenu(frm_l, v, *optionList)#command=func(*optionList))
optionmenu.grid(row=8,column=0,sticky='W')
#en.pack()

#-------------------------Button-------------------------#
btn = tk.Button(frm_l, text="回測",command=callfunc) #button內容、顏色
#OR獨立寫 btn.config(bg = "skyblue")
#btn.config(width=5, height=5) #button大小
#btn.config(image=img) #不可跟上兩行同時，也就是說圖片就是button
#btn.config(command=say_hi)
btn.grid(row = 11,column = 0,pady = 10) #封裝
btn2 = tk.Button(frm_l, text="清除", command=deletetable) #button內容、顏色
#OR獨立寫 btn.config(bg = "skyblue")
#btn.config(width=5, height=5) #button大小
#btn.config(image=img) #不可跟上兩行同時，也就是說圖片就是button
#btn.config(command=say_hi)
btn2.grid(row = 12,column = 0, pady = 10) #封裝

btn3 = tk.Button(frm_l, text="下單", command=order)
btn3.grid(row = 11,column = 1, pady = 10)



btn4 = tk.Button(frm_l, text="Run3", command = Run3)
btn4.grid(row = 12,column = 1, pady = 10)        

win.mainloop()
# Out:
# 1 1000000
# 2016-01-04 00:00:00
# 0
# 139.5
# 尚未達到買點
# 2016-01-05 00:00:00
# 1
# 138.0
# 尚未達到買點
# 2016-01-06 00:00:00
# 2
# 135.5
# 尚未達到買點
# 2016-01-07 00:00:00
# 3
# 133.0
# 尚未達到買點
# 2016-01-08 00:00:00
# 4
# 134.0
# 尚未達到買點
# 2016-01-11 00:00:00
# 5
# 133.0
# 尚未達到買點
# 2016-01-12 00:00:00
# 6
# 133.0
# 尚未達到買點
# 2016-01-13 00:00:00
# 7
# 133.5
# 尚未達到買點
# 2016-01-14 00:00:00
# 8
# 131.5
# 尚未達到買點
# 2016-01-15 00:00:00
# 53
# 159.0
# 尚未達到買點
# 2016-03-30 00:00:00
# 54
# 161.5
# 尚未達到買點
# 2016-03-31 00:00:00
# 55
# 162.0
# 尚未達到買點
# 2016-04-01 00:00:00
# 56
# 158.5
# 尚未達到買點
# 2016-04-06 00:00:00
# 57
# 153.5
# 尚未達到買點
# 2016-04-07 00:00:00
# 58
# 154.5
# K值為: 14.682539682539675
# 買了一張股票，股價為: 154.5
# [154.5]
# 剩餘資金為: 845500.0
# 擁有1張股票
# 2016-04-08 00:00:00
# 59
# 157.5
# 尚未達到買賣點
# 2016-04-11 00:00:00
# 60
# 158.5
# 尚未達到買賣點
# 2016-04-12 00:00:00
# 61
# 158.5
# 尚未達到買賣點
# 2016-04-13 00:00:00
# 62
# 161.5
# 現在的股價= 161.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 154.5
# 最後一次購買股價+5 159.5
# 已達停利標準
# 賣出1張股票
# 股價為: 161.5
# 擁有資金: 1007000.0
# 獲利: 7000.0
# 報酬率: 0.7000000000000001
# 2016-04-14 00:00:00
# 63
# 161.5
# 尚未達到買點
# 2016-04-15 00:00:00
# 64
# 159.5
# 尚未達到買點
# 2016-04-18 00:00:00
# 65
# 158.0
# 尚未達到買點
# 2016-04-19 00:00:00
# 66
# 157.5
# 尚未達到買點
# 2016-04-20 00:00:00
# 67
# 154.0
# 尚未達到買點
# 2016-04-21 00:00:00
# 68
# 157.0
# 尚未達到買點
# 2016-04-22 00:00:00
# 69
# 156.5
# 尚未達到買點
# 2016-04-25 00:00:00
# 70
# 157.5
# 尚未達到買點
# 2016-04-26 00:00:00
# 71
# 158.0
# 尚未達到買點
# 2016-04-27 00:00:00
# 72
# 156.5
# 尚未達到買點
# 2016-04-28 00:00:00
# 73
# 153.0
# 尚未達到買點
# 2016-04-29 00:00:00
# 74
# 150.0
# K值為: 14.682539682539678
# 買了一張股票，股價為: 150.0
# [150.0]
# 剩餘資金為: 857000.0
# 擁有1張股票
# 2016-05-03 00:00:00
# 75
# 147.5
# K值為: 5.5555555555555545
# 買了一張股票，股價為: 147.5
# [150.0, 147.5]
# 剩餘資金為: 709500.0
# 擁有2張股票
# 2016-05-04 00:00:00
# 76
# 147.0
# K值為: 6.944444444444444
# 買了一張股票，股價為: 147.0
# [150.0, 147.5, 147.0]
# 剩餘資金為: 562500.0
# 擁有3張股票
# 2016-05-05 00:00:00
# 77
# 147.5
# K值為: 8.166666666666666
# 買了一張股票，股價為: 147.5
# [150.0, 147.5, 147.0, 147.5]
# 剩餘資金為: 415000.0
# 擁有4張股票
# 2016-05-06 00:00:00
# 78
# 148.0
# K值為: 10.722222222222221
# 買了一張股票，股價為: 148.0
# [150.0, 147.5, 147.0, 147.5, 148.0]
# 剩餘資金為: 267000.0
# 擁有5張股票
# 2016-05-09 00:00:00
# 79
# 147.5
# K值為: 13.333333333333334
# 買了一張股票，股價為: 147.5
# [150.0, 147.5, 147.0, 147.5, 148.0, 147.5]
# 剩餘資金為: 119500.0
# 擁有6張股票
# 2016-05-10 00:00:00
# 196
# 188.5
# 尚未達到買點
# 2016-10-28 00:00:00
# 197
# 189.5
# 尚未達到買點
# 2016-10-31 00:00:00
# 198
# 188.5
# 尚未達到買點
# 2016-11-01 00:00:00
# 199
# 189.5
# 尚未達到買點
# 2016-11-02 00:00:00
# 200
# 186.0
# 尚未達到買點
# 2016-11-03 00:00:00
# 201
# 184.5
# K值為: 15.384615384615294
# 買了一張股票，股價為: 184.5
# [184.5]
# 剩餘資金為: 873500.0
# 擁有1張股票
# 2016-11-04 00:00:00
# 202
# 184.5
# K值為: 1.8518518518517617
# 買了一張股票，股價為: 184.5
# [184.5, 184.5]
# 剩餘資金為: 689000.0
# 擁有2張股票
# 2016-11-07 00:00:00
# 203
# 189.0
# 尚未達到買賣點
# 2016-11-08 00:00:00
# 204
# 188.5
# 尚未達到買賣點
# 2016-11-09 00:00:00
# 205
# 182.0
# 尚未達到買賣點
# 2016-11-10 00:00:00
# 206
# 185.5
# 尚未達到買賣點
# 2016-11-11 00:00:00
# 207
# 181.5
# K值為: 15.47987616099062
# 買了一張股票，股價為: 181.5
# [184.5, 184.5, 181.5]
# 剩餘資金為: 507500.0
# 擁有3張股票
# 2016-11-14 00:00:00
# 208
# 180.5
# K值為: 17.067177748292206
# 買了一張股票，股價為: 180.5
# [184.5, 184.5, 181.5, 180.5]
# 剩餘資金為: 327000.0
# 擁有4張股票
# 2016-11-15 00:00:00
# 209
# 180.0
# K值為: 6.240238276851458
# 買了一張股票，股價為: 180.0
# [184.5, 184.5, 181.5, 180.5, 180.0]
# 剩餘資金為: 147000.0
# 擁有5張股票
# 2016-11-16 00:00:00
# 210
# 180.0
# 錢不夠再買一張股票
# 2016-11-17 00:00:00
# 211
# 181.5
# 錢不夠再買一張股票
# 2016-11-18 00:00:00
# 212
# 181.0
# 錢不夠再買一張股票
# 2016-11-21 00:00:00
# 213
# 181.0
# 錢不夠再買一張股票
# 2016-11-22 00:00:00
# 214
# 184.0
# 尚未達到買賣點
# 2016-11-23 00:00:00
# 215
# 185.5
# 現在的股價= 185.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 180.0
# 最後一次購買股價+5 185.0
# 已達停利標準
# 賣出5張股票
# 股價為: 185.5
# 擁有資金: 1074500.0
# 獲利: 74500.0
# 報酬率: 7.449999999999999
# 2016-11-24 00:00:00
# 216
# 183.0
# 尚未達到買點
# 2016-11-25 00:00:00
# 217
# 182.0
# 尚未達到買點
# 2016-11-28 00:00:00
# 218
# 184.0
# 尚未達到買點
# 2016-11-29 00:00:00
# 219
# 182.0
# 尚未達到買點
# 2016-11-30 00:00:00
# 220
# 183.0
# 尚未達到買點
# 2016-12-01 00:00:00
# 221
# 183.0
# 尚未達到買點
# 2016-12-02 00:00:00
# 222
# 178.0
# 尚未達到買點
# 2016-12-05 00:00:00
# 223
# 179.0
# K值為: 19.306184012066264
# 買了一張股票，股價為: 179.0
# [179.0]
# 剩餘資金為: 895500.0
# 擁有1張股票
# 2016-12-06 00:00:00
# 224
# 182.0
# 尚未達到買賣點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2016-11-17 00:00:00 K值為: 13.043478260869472
# 2016-11-18 00:00:00 K值為: 15.942028985507156
# 2016-11-21 00:00:00 K值為: 18.840579710144834
# 2016-11-22 00:00:00 K值為: 30.11272141706915
# 買了一張股票，股價為: 184.0
# [184.0]
# 剩餘資金為: 823000.0
# 擁有1張股票
# 2016-11-18 00:00:00
# 未達買賣點
# 2016-11-21 00:00:00
# 未達買賣點
# 2016-11-22 00:00:00
# 未達買賣點
# 2016-11-23 00:00:00
# 未達買賣點
# 2016-11-24 00:00:00
# 未達買賣點
# 2016-11-25 00:00:00
# 未達買賣點
# 2016-11-28 00:00:00
# 未達買賣點
# 2016-12-02 00:00:00
# 現在的股價= 178.0
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 184.0
# 最後一次購買股價-5 179.0
# 已達停損標準
# 賣出1張股票
# 股價為: 178.0
# 擁有資金: 1001000.0
# 獲利: 1000.0
# 報酬率: 0.1
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2016-12-23 00:00:00 K值為: -6.868579779014301e-14
# 2016-12-26 00:00:00 K值為: 3.703703703703635
# 2016-12-27 00:00:00 K值為: 9.25925925925919
# 2016-12-28 00:00:00 K值為: 22.98474945533762
# 買了一張股票，股價為: 182.0
# [182.0]
# 剩餘資金為: 819000.0
# 擁有1張股票
# 2016-12-26 00:00:00
# 未達買賣點
# 2016-12-27 00:00:00
# 未達買賣點
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py", line 4375, in get_value
#     tz=getattr(series.dtype, 'tz', None))
#   File "pandas\_libs\index.pyx", line 81, in pandas._libs.index.IndexEngine.get_value
#   File "pandas\_libs\index.pyx", line 89, in pandas._libs.index.IndexEngine.get_value
#   File "pandas\_libs\index.pyx", line 447, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 987, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 993, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 243
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\admin\appdata\local\programs\python\python37\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-269-4b30895bbe6f>", line 15, in Run3
#     b = int(second())
#   File "<ipython-input-274-d5f7846023c9>", line 44, in second
#     return testKDcontSet(start_money,sell,buy,sProfit,sLoss,close2,data)
#   File "<ipython-input-221-69aca6c44b81>", line 41, in testKDcontSet
#     if(close[i+3] >= record[-1]+5): #現在的股價 >= 停利條件
#   File "c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py", line 868, in __getitem__
#     result = self.index.get_value(self, key)
#   File "c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\datetimes.py", line 946, in get_value
#     return com.maybe_box(self, Index.get_value(self, series, key),
#   File "c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py", line 4381, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas\_libs\index.pyx", line 52, in pandas._libs.index.get_value_box
#   File "pandas\_libs\index.pyx", line 48, in pandas._libs.index.get_value_at
#   File "pandas\_libs\util.pxd", line 113, in pandas._libs.util.get_value_at
#   File "pandas\_libs\util.pxd", line 104, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# 1 1000000
# 2015-01-05 00:00:00
# 0
# 139.5
# 尚未達到買點
# 2015-01-06 00:00:00
# 1
# 133.5
# 尚未達到買點
# 2015-01-07 00:00:00
# 2
# 134.0
# 尚未達到買點
# 2015-01-08 00:00:00
# 3
# 138.0
# 尚未達到買點
# 2015-01-09 00:00:00
# 4
# 134.0
# 尚未達到買點
# 2015-01-12 00:00:00
# 5
# 132.0
# 尚未達到買點
# 2015-01-13 00:00:00
# 6
# 132.5
# 尚未達到買點
# 2015-01-14 00:00:00
# 7
# 130.0
# 尚未達到買點
# 2015-01-15 00:00:00
# 8
# 131.5
# 尚未達到買點
# 2015-01-16 00:00:00
# 9
# 137.0
# 尚未達到買點
# 2015-01-19 00:00:00
# 10
# 139.0
# 尚未達到買點
# 2015-01-20 00:00:00
# 11
# 138.0
# 尚未達到買點
# 2015-01-21 00:00:00
# 12
# 141.0
# 尚未達到買點
# 2015-01-22 00:00:00
# 13
# 140.0
# 尚未達到買點
# 2015-01-23 00:00:00
# 14
# 145.0
# 尚未達到買點
# 2015-01-26 00:00:00
# 15
# 145.0
# 尚未達到買點
# 2015-01-27 00:00:00
# 16
# 147.0
# 尚未達到買點
# 2015-01-28 00:00:00
# 17
# 146.5
# 尚未達到買點
# 2015-01-29 00:00:00
# 18
# 143.5
# 尚未達到買點
# 2015-01-30 00:00:00
# 19
# 141.0
# 尚未達到買點
# 2015-02-02 00:00:00
# 20
# 142.5
# 尚未達到買點
# 2015-02-03 00:00:00
# 21
# 144.5
# 尚未達到買點
# 2015-02-04 00:00:00
# 22
# 146.0
# 尚未達到買點
# 2015-02-05 00:00:00
# 23
# 145.5
# 尚未達到買點
# 2015-02-06 00:00:00
# 24
# 143.0
# 尚未達到買點
# 2015-02-09 00:00:00
# 25
# 142.0
# 尚未達到買點
# 2015-02-10 00:00:00
# 26
# 142.5
# 尚未達到買點
# 2015-02-11 00:00:00
# 27
# 148.0
# 尚未達到買點
# 2015-02-12 00:00:00
# 28
# 148.5
# 尚未達到買點
# 2015-02-13 00:00:00
# 29
# 148.5
# 尚未達到買點
# 2015-02-24 00:00:00
# 30
# 151.0
# 尚未達到買點
# 2015-02-25 00:00:00
# 31
# 154.5
# 尚未達到買點
# 2015-02-26 00:00:00
# 32
# 150.5
# 尚未達到買點
# 2015-03-02 00:00:00
# 33
# 149.0
# 尚未達到買點
# 2015-03-03 00:00:00
# 34
# 150.5
# 尚未達到買點
# 2015-03-04 00:00:00
# 35
# 150.5
# 尚未達到買點
# 2015-03-05 00:00:00
# 36
# 150.0
# 尚未達到買點
# 2015-03-06 00:00:00
# 37
# 149.0
# 尚未達到買點
# 2015-03-09 00:00:00
# 38
# 145.5
# K值為: 18.78735299787925
# 買了一張股票，股價為: 145.5
# [145.5]
# 剩餘資金為: 854500.0
# 擁有1張股票
# 2015-03-10 00:00:00
# 2015-06-08 00:00:00
# 100
# 138.5
# K值為: 7.43034055727546
# 買了一張股票，股價為: 138.5
# [146.5, 143.0, 141.0, 140.0, 138.5]
# 剩餘資金為: 351500.0
# 擁有5張股票
# 2015-06-09 00:00:00
# 101
# 139.0
# K值為: 7.017543859649041
# 買了一張股票，股價為: 139.0
# [146.5, 143.0, 141.0, 140.0, 138.5, 139.0]
# 剩餘資金為: 212500.0
# 擁有6張股票
# 2015-06-10 00:00:00
# 102
# 139.5
# K值為: 8.77192982456132
# 買了一張股票，股價為: 139.5
# [146.5, 143.0, 141.0, 140.0, 138.5, 139.0, 139.5]
# 剩餘資金為: 73000.0
# 擁有7張股票
# 2015-06-11 00:00:00
# 103
# 143.5
# 尚未達到買賣點
# 2015-06-12 00:00:00
# 104
# 144.5
# 現在的股價= 144.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 139.5
# 最後一次購買股價+5 144.5
# 已達停利標準
# 賣出7張股票
# 股價為: 144.5
# 擁有資金: 1084500.0
# 獲利: 84500.0
# 報酬率: 8.450000000000001
# 2015-06-15 00:00:00
# 105
# 143.0
# 尚未達到買點
# 2015-06-16 00:00:00
# 106
# 142.0
# 尚未達到買點
# 2015-06-17 00:00:00
# 107
# 142.5
# 尚未達到買點
# 2015-06-18 00:00:00
# 108
# 142.0
# 尚未達到買點
# 2015-06-22 00:00:00
# 109
# 142.0
# 尚未達到買點
# 2015-06-23 00:00:00
# 110
# 144.5
# 尚未達到買點
# 2015-06-24 00:00:00
# 111
# 145.0
# 尚未達到買點
# 2015-06-25 00:00:00
# 112
# 146.5
# 尚未達到買點
# 2015-06-26 00:00:00
# 113
# 146.0
# 尚未達到買點
# 2015-06-29 00:00:00
# 114
# 138.5
# 尚未達到買點
# 2015-06-30 00:00:00
# 115
# 140.5
# 尚未達到買點
# 2015-07-01 00:00:00
# 116
# 141.0
# K值為: 16.666666666666607
# 買了一張股票，股價為: 141.0
# [141.0]
# 剩餘資金為: 943500.0
# 擁有1張股票
# 2015-07-02 00:00:00
# 117
# 141.5
# 尚未達到買賣點
# 2015-07-03 00:00:00
# 118
# 142.5
# 尚未達到買賣點
# 2015-07-06 00:00:00
# 119
# 140.5
# 尚未達到買賣點
# 2015-07-07 00:00:00
# 120
# 140.5
# 尚未達到買賣點
# 2015-07-08 00:00:00
# 121
# 138.0
# K值為: 14.814814814814758
# 買了一張股票，股價為: 138.0
# [141.0, 138.0]
# 剩餘資金為: 805500.0
# 擁有2張股票
# 2015-07-09 00:00:00
# 122
# 136.5
# K值為: 17.211328976034803
# 買了一張股票，股價為: 136.5
# [141.0, 138.0, 136.5]
# 剩餘資金為: 669000.0
# 擁有3張股票
# 2015-07-10 00:00:00
# 123
# 136.5
# K值為: 19.607843137254847
# 買了一張股票，股價為: 136.5
# [141.0, 138.0, 136.5, 136.5]
# 剩餘資金為: 532500.0
# 擁有4張股票
# 2015-07-13 00:00:00
# 124
# 138.5
# 尚未達到買賣點
# 2015-07-14 00:00:00
# 125
# 138.5
# 尚未達到買賣點
# 2015-07-15 00:00:00
# 126
# 138.5
# 尚未達到買賣點
# 2015-07-16 00:00:00
# 127
# 136.5
# 尚未達到買賣點
# 2015-07-17 00:00:00
# 128
# 140.0
# 尚未達到買賣點
# 2015-07-20 00:00:00
# 129
# 139.0
# 尚未達到買賣點
# 2015-07-21 00:00:00
# 130
# 140.5
# 尚未達到買賣點
# 2015-07-22 00:00:00
# 131
# 139.0
# 尚未達到買賣點
# 2015-07-23 00:00:00
# 132
# 136.0
# 尚未達到買賣點
# 2015-07-24 00:00:00
# 133
# 137.0
# 尚未達到買賣點
# 2015-07-27 00:00:00
# 134
# 134.0
# K值為: 10.256410256410204
# 買了一張股票，股價為: 134.0
# [141.0, 138.0, 136.5, 136.5, 134.0]
# 剩餘資金為: 398500.0
# 擁有5張股票
# 2015-07-28 00:00:00
# 135
# 134.0
# K值為: 7.692307692307639
# 買了一張股票，股價為: 134.0
# [141.0, 138.0, 136.5, 136.5, 134.0, 134.0]
# 剩餘資金為: 264500.0
# 擁有6張股票
# 2015-07-29 00:00:00
# 136
# 135.5
# K值為: 6.249999999999947
# 買了一張股票，股價為: 135.5
# [141.0, 138.0, 136.5, 136.5, 134.0, 134.0, 135.5]
# 剩餘資金為: 129000.0
# 擁有7張股票
# 2015-07-30 00:00:00
# 137
# 138.5
# 尚未達到買賣點
# 2015-07-31 00:00:00
# 138
# 139.5
# 尚未達到買賣點
# 2015-08-03 00:00:00
# 139
# 134.5
# 尚未達到買賣點
# 2015-08-04 00:00:00
# 140
# 136.5
# 尚未達到買賣點
# 2015-08-05 00:00:00
# 141
# 134.0
# 錢不夠再買一張股票
# 2015-08-06 00:00:00
# 142
# 134.0
# 尚未達到買賣點
# 2015-08-07 00:00:00
# 143
# 133.0
# 錢不夠再買一張股票
# 2015-08-10 00:00:00
# 144
# 129.0
# 現在的股價= 129.0
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 135.5
# 最後一次購買股價-5 130.5
# 已達停損標準
# 賣出7張股票
# 股價為: 129.0
# i: 144
# 擁有資金: 1032000.0
# 獲利: 32000.0
# 報酬率: 3.2
# 2015-08-11 00:00:00
# 145
# 130.5
# 尚未達到買點
# 2015-08-12 00:00:00
# 146
# 128.5
# 尚未達到買點
# 2015-08-13 00:00:00
# 147
# 128.0
# 尚未達到買點
# 2015-08-14 00:00:00
# 148
# 126.0
# K值為: 15.975473801560701
# 買了一張股票，股價為: 126.0
# [126.0]
# 剩餘資金為: 906000.0
# 擁有1張股票
# 2015-08-17 00:00:00
# 149
# 124.0
# K值為: 11.8729096989966
# 買了一張股票，股價為: 124.0
# [126.0, 124.0]
# 剩餘資金為: 782000.0
# 擁有2張股票
# 2015-08-18 00:00:00
# 150
# 126.0
# K值為: 13.15496098104788
# 買了一張股票，股價為: 126.0
# [126.0, 124.0, 126.0]
# 剩餘資金為: 656000.0
# 擁有3張股票
# 2015-08-19 00:00:00
# 151
# 125.0
# K值為: 16.60561660561655
# 買了一張股票，股價為: 125.0
# [126.0, 124.0, 126.0, 125.0]
# 2015-10-14 00:00:00
# 189
# 136.5
# 尚未達到買點
# 2015-10-15 00:00:00
# 190
# 140.0
# 尚未達到買點
# 2015-10-16 00:00:00
# 191
# 137.5
# 尚未達到買點
# 2015-10-19 00:00:00
# 192
# 138.0
# 尚未達到買點
# 2015-10-20 00:00:00
# 193
# 139.0
# 尚未達到買點
# 2015-10-21 00:00:00
# 194
# 138.5
# 尚未達到買點
# 2015-10-22 00:00:00
# 195
# 137.5
# 尚未達到買點
# 2015-10-23 00:00:00
# 196
# 140.0
# 尚未達到買點
# 2015-10-26 00:00:00
# 197
# 140.0
# 尚未達到買點
# 2015-10-27 00:00:00
# 198
# 139.0
# 尚未達到買點
# 2015-10-28 00:00:00
# 199
# 138.0
# 尚未達到買點
# 2015-10-29 00:00:00
# 200
# 136.5
# 尚未達到買點
# 2015-10-30 00:00:00
# 201
# 136.5
# K值為: 18.51851851851841
# 買了一張股票，股價為: 136.5
# [136.5]
# 剩餘資金為: 848500.0
# 擁有1張股票
# 2015-11-02 00:00:00
# 202
# 137.5
# K值為: 17.037037037036928
# 買了一張股票，股價為: 137.5
# [136.5, 137.5]
# 剩餘資金為: 711000.0
# 擁有2張股票
# 2015-11-03 00:00:00
# 203
# 139.5
# 尚未達到買賣點
# 2015-11-04 00:00:00
# 204
# 144.5
# 現在的股價= 144.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 137.5
# 最後一次購買股價+5 142.5
# 已達停利標準
# 賣出2張股票
# 股價為: 144.5
# 擁有資金: 1000000.0
# 獲利: 0.0
# 報酬率: 0.0
# 2015-11-05 00:00:00
# 205
# 142.5
# 尚未達到買點
# 2015-11-06 00:00:00
# 206
# 140.0
# 尚未達到買點
# 2015-11-09 00:00:00
# 207
# 142.0
# 尚未達到買點
# 2015-11-10 00:00:00
# 208
# 139.5
# 尚未達到買點
# 2015-11-11 00:00:00
# 209
# 137.5
# 尚未達到買點
# 2015-11-12 00:00:00
# 210
# 138.5
# 尚未達到買點
# 2015-11-13 00:00:00
# 211
# 136.0
# K值為: 18.518518518518423
# 買了一張股票，股價為: 136.0
# [136.0]
# 剩餘資金為: 864000.0
# 擁有1張股票
# 2015-11-16 00:00:00
# 212
# 135.0
# K值為: 14.285714285714192
# 買了一張股票，股價為: 135.0
# [136.0, 135.0]
# 剩餘資金為: 729000.0
# 擁有2張股票
# 2015-11-17 00:00:00
# 213
# 138.5
# K值為: 17.460317460317366
# 買了一張股票，股價為: 138.5
# [136.0, 135.0, 138.5]
# 剩餘資金為: 590500.0
# 擁有3張股票
# 2015-11-18 00:00:00
# 214
# 137.0
# 尚未達到買賣點
# 2015-11-19 00:00:00
# 215
# 140.5
# 尚未達到買賣點
# 2015-11-20 00:00:00
# 216
# 141.0
# 尚未達到買賣點
# 2015-11-23 00:00:00
# 217
# 141.0
# K值為: 86.2962962962962
# 手上有3張股票可賣
# 賣出3張股票
# 股價為: 141.0
# i: 217
# 擁有資金: 1013500.0
# 獲利: 13500.0
# 報酬率: 1.35
# 2015-11-24 00:00:00
# 2015-05-11 00:00:00
# 80
# 148.5
# 2015-05-12 00:00:00
# 81
# 147.5
# record: [148.5]
# 2015-05-11 00:00:00 K值為: 20.833333333333247 D值為: 21.87986305633353 2015-05-12 00:00:00 K值為: 28.787878787878707 D值為: 22.586155674390856
# 買了一張股票，股價為: 148.5
# 剩餘資金為: 876500.0
# 擁有1張股票
# 2015-05-13 00:00:00
# 82
# 148.0
# 2015-05-14 00:00:00
# 83
# 146.0
# 2015-05-15 00:00:00
# 84
# 146.5
# 2015-05-15 00:00:00 K值為: 40.6926406926406 D值為: 39.30375180375169 2015-05-15 00:00:00 K值為: 41.07142857142848 D值為: 43.39826839826828
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 146.0
# 擁有資金: 1022500.0
# 獲利: 22500.0
# 報酬率: 2.25
# 2015-05-18 00:00:00
# 85
# 146.5
# 2015-05-19 00:00:00
# 86
# 146.5
# record: [146.5]
# 2015-05-18 00:00:00 K值為: 29.761904761904674 D值為: 37.17532467532456 2015-05-19 00:00:00 K值為: 37.499999999999915 D值為: 36.111111111111
# 買了一張股票，股價為: 146.5
# 剩餘資金為: 876000.0
# 擁有1張股票
# 2015-05-20 00:00:00
# 87
# 146.5
# 2015-05-21 00:00:00
# 88
# 145.5
# 2015-05-21 00:00:00 K值為: 37.499999999999915 D值為: 34.92063492063482 2015-05-21 00:00:00 K值為: 32.40740740740733 D值為: 35.80246913580237
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 146.5
# 擁有資金: 1022500.0
# 獲利: 22500.0
# 報酬率: 2.25
# 2015-05-22 00:00:00
# 89
# 145.5
# 2015-05-25 00:00:00
# 90
# 147.5
# record: [145.5]
# 2015-05-22 00:00:00 K值為: 27.314814814814735 D值為: 32.40740740740731 2015-05-25 00:00:00 K值為: 37.03703703703696 D值為: 32.253086419753
# 買了一張股票，股價為: 145.5
# 剩餘資金為: 877000.0
# 擁有1張股票
# 2015-05-26 00:00:00
# 91
# 146.5
# 2015-05-27 00:00:00
# 92
# 145.0
# 2015-05-28 00:00:00
# 93
# 147.0
# 2015-05-28 00:00:00 K值為: 43.05555555555548 D值為: 42.129629629629534 2015-05-28 00:00:00 K值為: 41.666666666666586 D值為: 43.67283950617275
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 145.0
# 擁有資金: 1022000.0
# 獲利: 22000.0
# 報酬率: 2.1999999999999997
# 2015-05-29 00:00:00
# 94
# 146.0
# 2015-06-01 00:00:00
# 95
# 145.0
# record: [146.0]
# 2015-05-29 00:00:00 K值為: 37.49999999999992 D值為: 40.74074074074065 2015-06-01 00:00:00 K值為: 40.740740740740655 D值為: 39.96913580246903
# 買了一張股票，股價為: 146.0
# 剩餘資金為: 876000.0
# 擁有1張股票
# 2015-06-02 00:00:00
# 96
# 144.0
# 2015-06-02 00:00:00 K值為: 40.740740740740655 D值為: 39.96913580246903 2015-06-02 00:00:00 K值為: 23.24074074074066 D值為: 33.82716049382706
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 145.0
# 擁有資金: 1021000.0
# 剩餘資金為: 888000.0
# 擁有1張股票
# 2015-07-03 00:00:00
# 118
# 142.5
# 2015-07-06 00:00:00
# 119
# 140.5
# 2015-07-07 00:00:00
# 120
# 140.5
# 2015-07-07 00:00:00 K值為: 33.33333333333328 D值為: 32.098765432098695 2015-07-07 00:00:00 K值為: 29.629629629629573 D值為: 32.71604938271598
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 140.5
# 擁有資金: 1028500.0
# 獲利: 28500.0
# 報酬率: 2.85
# 2015-07-08 00:00:00
# 121
# 138.0
# 2015-07-09 00:00:00
# 122
# 136.5
# 2015-07-10 00:00:00
# 123
# 136.5
# record: [136.5]
# 2015-07-09 00:00:00 K值為: 17.211328976034803 D值為: 20.55192447349303 2015-07-10 00:00:00 K值為: 19.607843137254847 D值為: 17.21132897603479
# 買了一張股票，股價為: 136.5
# 剩餘資金為: 892000.0
# 擁有1張股票
# 2015-07-13 00:00:00
# 124
# 138.5
# 2015-07-14 00:00:00
# 125
# 138.5
# 2015-07-15 00:00:00
# 126
# 138.5
# 2015-07-16 00:00:00
# 127
# 136.5
# 2015-07-16 00:00:00 K值為: 52.94117647058818 D值為: 45.09803921568621 2015-07-16 00:00:00 K值為: 45.71078431372544 D值為: 47.9166666666666
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 138.5
# 擁有資金: 1030500.0
# 獲利: 30500.0
# 報酬率: 3.05
# 2015-07-17 00:00:00
# 128
# 140.0
# record: [136.5]
# 2015-07-16 00:00:00 K值為: 45.71078431372544 D值為: 47.9166666666666 2015-07-17 00:00:00 K值為: 53.06372549019603 D值為: 50.57189542483653
# 買了一張股票，股價為: 136.5
# 剩餘資金為: 894000.0
# 擁有1張股票
# 2015-07-20 00:00:00
# 129
# 139.0
# 2015-07-21 00:00:00
# 130
# 140.5
# 2015-07-22 00:00:00
# 131
# 139.0
# 2015-07-23 00:00:00
# 132
# 136.0
# 2015-07-23 00:00:00 K值為: 65.86538461538457 D值為: 65.0106837606837 2015-07-23 00:00:00 K值為: 47.59615384615379 D值為: 62.12606837606831
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 139.0
# 擁有資金: 1033000.0
# 獲利: 33000.0
# 報酬率: 3.3000000000000003
# 2015-07-24 00:00:00
# 133
# 137.0
# 2015-07-27 00:00:00
# 134
# 134.0
# 2015-07-28 00:00:00
# 135
# 134.0
# 2015-07-29 00:00:00
# 136
# 135.5
# 2015-07-30 00:00:00
# 137
# 138.5
# record: [135.5]
# 2015-07-29 00:00:00 K值為: 6.249999999999947 D值為: 8.066239316239255 2015-07-30 00:00:00 K值為: 24.999999999999947 D值為: 12.98076923076917
# 買了一張股票，股價為: 135.5
# 剩餘資金為: 897500.0
# 擁有1張股票
# 2015-07-31 00:00:00
# 138
# 139.5
# 2015-08-03 00:00:00
# 139
# 134.5
# 2015-08-04 00:00:00
# 140
# 136.5
# 2015-08-04 00:00:00 K值為: 45.75854700854696 D值為: 40.067663817663764 2015-08-04 00:00:00 K值為: 39.82905982905978 D值為: 45.01068376068371
# 2015-09-08 00:00:00
# 165
# 123.0
# 2015-09-09 00:00:00
# 166
# 129.0
# 2015-09-10 00:00:00
# 167
# 125.0
# record: [129.0]
# 2015-09-09 00:00:00 K值為: 48.621553884711716 D值為: 49.06909346268606 2015-09-10 00:00:00 K值為: 52.380952380952316 D值為: 46.009952417274995
# 買了一張股票，股價為: 129.0
# 剩餘資金為: 907000.0
# 擁有1張股票
# 2015-09-11 00:00:00
# 168
# 127.5
# 2015-09-14 00:00:00
# 169
# 127.5
# 2015-09-15 00:00:00
# 170
# 126.0
# 2015-09-16 00:00:00
# 171
# 129.5
# 2015-09-17 00:00:00
# 172
# 131.0
# 2015-09-18 00:00:00
# 173
# 131.5
# 2015-09-21 00:00:00
# 174
# 129.5
# 2015-09-22 00:00:00
# 175
# 129.0
# 2015-09-22 00:00:00 K值為: 89.35672514619876 D值為: 89.13185742133102 2015-09-22 00:00:00 K值為: 79.99999999999993 D值為: 88.506335282651
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 129.5
# 擁有資金: 1036500.0
# 獲利: 36500.0
# 報酬率: 3.65
# 2015-09-23 00:00:00
# 176
# 124.5
# 2015-09-24 00:00:00
# 177
# 127.0
# 2015-09-25 00:00:00
# 178
# 127.0
# 2015-09-29 00:00:00
# 179
# 127.0
# record: [127.0]
# 2015-09-25 00:00:00 K值為: 26.031746031745943 D值為: 37.08994708994701 2015-09-29 00:00:00 K值為: 35.71428571428562 D值為: 32.69841269841262
# 買了一張股票，股價為: 127.0
# 剩餘資金為: 909500.0
# 擁有1張股票
# 2015-09-30 00:00:00
# 180
# 130.0
# 2015-10-01 00:00:00
# 181
# 133.5
# 2015-10-02 00:00:00
# 182
# 132.0
# 2015-10-01 00:00:00 K值為: 69.67418546365906 D值為: 51.79615705931487 2015-10-02 00:00:00 K值為: 84.08521303258136 D值為: 67.91979949874678
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 133.5
# 擁有資金: 1043000.0
# 獲利: 43000.0
# 報酬率: 4.3
# 2015-10-05 00:00:00
# 183
# 132.5
# 2015-10-06 00:00:00
# 184
# 133.0
# 2015-10-07 00:00:00
# 185
# 135.0
# record: [133.0]
# 2015-10-06 00:00:00 K值為: 80.14354066985636 D值為: 83.39788866104647 2015-10-07 00:00:00 K值為: 85.57378294220389 D值為: 83.89407863092065
# 買了一張股票，股價為: 133.0
# 剩餘資金為: 910000.0
# 擁有1張股票
# 2015-10-08 00:00:00
# 186
# 136.0
# 2015-10-12 00:00:00
# 187
# 138.5
# 2015-10-13 00:00:00
# 188
# 137.5
# 2015-10-12 00:00:00 K值為: 94.24603174603165 D值為: 89.29299258246618 2015-10-13 00:00:00 K值為: 91.66666666666657 D值為: 91.32395382395374
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 138.5
# 擁有資金: 1048500.0
# 獲利: 48500.0
# 報酬率: 4.8500000000000005
# 2015-10-14 00:00:00
# 189
# 136.5
# 2015-10-15 00:00:00
# 190
# 140.0
# 2015-10-16 00:00:00
# 191
# 137.5
# 2015-10-19 00:00:00
# 192
# 138.0
# 2015-10-20 00:00:00
# 193
# 139.0
# 2015-10-21 00:00:00
# 194
# 138.5
# 2015-10-22 00:00:00
# 195
# 137.5
# 2015-10-23 00:00:00
# 196
# 140.0
# 2015-10-26 00:00:00
# 197
# 140.0
# record: [140.0]
# 2015-10-23 00:00:00 K值為: 56.11111111111101 D值為: 58.85620915032672 2015-10-26 00:00:00 K值為: 63.33333333333323 D值為: 57.962962962962884
# 買了一張股票，股價為: 140.0
# 剩餘資金為: 908500.0
# 擁有1張股票
# 2015-10-27 00:00:00
# 198
# 139.0
# 2015-10-28 00:00:00
# 199
# 138.0
# 2015-10-28 00:00:00 K值為: 73.33333333333323 D值為: 64.25925925925918 2015-10-28 00:00:00 K值為: 61.481481481481374 D值為: 66.04938271604931
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 139.0
# 擁有資金: 1047500.0
# 獲利: 47500.0
# 報酬率: 4.75
# 2015-10-29 00:00:00
# 200
# 136.5
# 2015-10-30 00:00:00
# 201
# 136.5
# 2015-11-02 00:00:00
# 202
# 137.5
# 2015-11-03 00:00:00
# 203
# 139.5
# record: [137.5]
# 2015-11-02 00:00:00 K值為: 17.037037037036928 D值為: 23.45679012345671 2015-11-03 00:00:00 K值為: 43.7037037037036 D值為: 26.419753086419675
# 買了一張股票，股價為: 137.5
# 剩餘資金為: 910000.0
# 擁有1張股票
# 2015-11-04 00:00:00
# 204
# 144.5
# 2015-11-05 00:00:00
# 205
# 142.5
# 2015-11-04 00:00:00 K值為: 73.33333333333323 D值為: 44.69135802469128 2015-11-05 00:00:00 K值為: 85.92592592592582 D值為: 67.65432098765426
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 144.5
# 擁有資金: 1054500.0
# 獲利: 54500.0
# 報酬率: 5.45
# 2015-11-06 00:00:00
# 206
# 140.0
# 2015-11-09 00:00:00
# 207
# 142.0
# 2015-11-10 00:00:00
# 208
# 139.5
# 2015-11-11 00:00:00
# 209
# 137.5
# 2015-11-12 00:00:00
# 210
# 138.5
# 2015-11-13 00:00:00
# 211
# 136.0
# 2015-11-16 00:00:00
# 212
# 135.0
# 2015-11-17 00:00:00
# 213
# 138.5
# record: [135.0]
# 2015-11-16 00:00:00 K值為: 14.285714285714192 D值為: 22.04585537918865 2015-11-17 00:00:00 K值為: 17.460317460317366 D值為: 16.75485008818336
# 買了一張股票，股價為: 135.0
# 剩餘資金為: 919500.0
# 擁有1張股票
# 2015-11-18 00:00:00
# 214
# 137.0
# 2015-11-19 00:00:00
# 215
# 140.5
# 2015-11-20 00:00:00
# 216
# 141.0
# 2015-11-19 00:00:00 K值為: 48.35978835978827 D值為: 31.0934744268077 2015-11-20 00:00:00 K值為: 65.18518518518509 D值為: 47.00176366843027
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 140.5
# 擁有資金: 1060000.0
# 獲利: 60000.0
# 報酬率: 6.0
# 2015-11-23 00:00:00
# 217
# 141.0
# 2015-11-24 00:00:00
# 218
# 139.5
# 2015-11-25 00:00:00
