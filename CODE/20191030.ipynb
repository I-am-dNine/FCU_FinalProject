# %% [raw]
# """"problem talib need install wheel
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
# import talib
# """

# %%
try:
    import xml.etree.cElementTree as ET
except ImportError:
    import xml.etree.ElementTree as ET

# %%
# basic
import numpy as np
import pandas as pd
import pymongo
# visual
import matplotlib.pyplot as plt
# %matplotlib inline
#time
import datetime 

#talib
import talib
from talib import abstract

#gui
import tkinter as tk
from  tkinter import ttk  
from tkinter import messagebox
import requests
import re

# %%
import io
import requests
import datetime


def crawl_price(stock_id):
    now = int(datetime.datetime.now().timestamp())+86400
    url = "https://query1.finance.yahoo.com/v7/finance/download/" + stock_id + "?period1=0&period2=" + str(now) + "&interval=1d&events=history&crumb=hP2rOschxO0"

    response = requests.post(url)
    
    f = io.StringIO(response.text)
    df = pd.read_csv(f, index_col='Date', parse_dates=['Date'] )
    return df

# %%
from suds.client import Client
from suds.xsd.doctor import Import, ImportDoctor
url="http://61.220.30.176/WebOrder/GVETransacs.asmx?WSDL"
imp=Import('http://www.w3.org/2001/XMLSchema',location='http://www.w3.org/2001/XMLSchema.xsd')
imp.filter.add('http://tempuri.org/')
client = Client(url, doctor=ImportDoctor(imp))
print(client)
# Out:
# Suds ( https://github.com/cackharot/suds-py3 )  version: 1.3.3.0 IN  build: 20170311
#
# Service ( GVETransacs ) tns="http://tempuri.org/"
#    Prefixes (1)
#       ns0 = "http://tempuri.org/"
#    Ports (2):
#       (GVETransacsSoap)
#          Methods (248):
#             AdjustOrder(xs:string UserName, xs:string GameCode, xs:string CompCode, xs:string Price, xs:string Volume, xs:string BSAction, xs:string OrderType, xs:string ExpireDate, xs:string OrgVolume, xs:string OrderSource, xs:string CombineNo, )
#             CancelOrder(xs:string OrderID, )
#             CancelOrderStr_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:string comment, )
#             ChangeOrder(xs:string OrderID, xs:double Volume, )
#             ChangeOrderPrice(xs:int gmrid, xs:string orderno, xs:string ordertype, xs:string ordernote, xs:float price, xs:string Lang, )
#             ChangeOrder_NS(xs:string TokenString, xs:string OrderID, xs:double Volume, )
#             ChangeOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:double Volume, xs:string comment, )
#             CheckAndUpdateAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             CheckAndUpdateFuturAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             ClearPosition(xs:string AssetCode, )
#             DeleteSMSWaitingMultiRecord(xs:string SMSID, xs:string message, )
#             DeleteSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             FollowOrderAddSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FollowOrderDeleteSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FuturesFinalSettle()
#             GMRIDToStr(xs:int GMRID, )
#             GMRStrToInt(xs:string GMRIDStr, )
#             GetTradableAsset(xs:string AssetCode, )
#             GetTradableAssetList()
#             GetTradableAssetListXML()
#             MarkupQuoteItemDataXML(xs:string AssetCodeList, xs:string QuoteItemLine, xs:string Language, )
#             NewFollowOrderSubscribe(xs:string GMRID, xs:string SubscribeID, xs:int dailylimit, )
#             NewSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             OptionFinalSettle()
#             PutBatchOrder(GVEWSOrderList sGVEWSOrderList, )
#             PutCombineOrder(xs:string GMRID, xs:string CompCode1, xs:string BSAction1, xs:int Volume1, xs:string CompCode2, xs:string BSAction2, xs:int Volume2, xs:string OrderType, xs:float PriceDiff, xs:string OptiNote, xs:string OptiCombinNo, xs:string lang, )
#             PutOrder(GVEWSOrder Order, )
#             PutOrderXML(xs:int GMRID, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML1(xs:string GMRIDStr, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML2(xs:string GMRIDStr, xs:string AssetCode, xs:int PFLAssetID, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML3(xs:string GMRIDStr, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string str_ip, )
#             PutOrderXML3_STWS(xs:int GMRID, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             PutOrderXML3_STWS_2(xs:int GMRID, xs:string CompCode, xs:string username, xs:string gamecode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string expiredate, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             QueryAllSectorList(xs:int ExchID, )
#             QueryAllSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryAllWarrantsSectorList(xs:int ExchID, )
#             QueryAllWarrantsSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryCataIDByGmridAssetClass(xs:string GMRID, xs:string AssetClass, xs:string Lang, )
#             QueryCompanyData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryCountryCode(xs:string Lang, )
#             QueryDayRangeTFXML(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDayRangeTFXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLog()
#             QueryDealLogBusinessTransactionSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogBy2(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2DiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, )
#             QueryDealLogBy2DiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, xs:string comment, )
#             QueryDealLogBy2XML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2XML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, xs:string Language, )
#             QueryDealLogByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogByGMRDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByGMRDayRangeXML(xs:int GMRID, xs:string StartDate, xs:string EndDate, )
#             QueryDealLogByGMRDayRangeXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByOrderID(xs:string OrderID, )
#             QueryDealLogByOrderIDXML(xs:string OrderID, )
#             QueryDealLogByOrderIDXML_NS(xs:string OrderID, xs:string TokenString, xs:string Language, )
#             QueryDealLogCheckSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogCheckSheetByBSActionCompType(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDealLogCheckSheet_STWS(xs:string Comptype, xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogFundTrading(xs:string GMRID, xs:string Lang, )
#             QueryDealLogGVE3ByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogMarginRateSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogWriteOff(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDividendData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryDividendInfoByCompCode(xs:string CompCode, )
#             QueryDividendInfoByCompCode_NS(xs:string CompCode, xs:string Language, )
#             QueryDividendInfoByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDividendInfoByDayRange_NS(xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryDividendInfoByExchDayRange(xs:string ExchID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryExchRate(xs:string HomeFX, xs:string ForeignFx, xs:int amount, )
#             QueryFXCrossRate(xs:string Lang, xs:string Fx, )
#             QueryFameHistoryByGMRID(xs:string GMRIDStr, )
#             QueryFameList(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGMRFameDateXml_NS(xs:string GMRIDStr, xs:dateTime FameDay, )
#             QueryFameListByGameCode(xs:string GameCode, )
#             QueryFameListByGameCodeFameDate(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGameCodeUsername(xs:string GameCode, xs:string Username, )
#             QueryFameListTop10ByGameCode_xml(xs:string GameCode, )
#             QueryFollowOrderApprovedHistoryByWeek_xml(xs:string GMRID, xs:int Year, xs:int Week, )
#             QueryFollowOrderBasicDataByGMRID(xs:string GMRID, )
#             QueryFollowOrderCreditUsedDetail_XML(xs:string GMRID, xs:int followid, )
#             QueryFollowOrderFollowerByGMRID(xs:string GMRIDStr, )
#             QueryFollowOrderMyFansApproved_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansSentSummary_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansWaitForApprove_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolAllList_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolList_XML(xs:string GMRID, )
#             QueryFollowOrderSubScribedByGMRID(xs:string GMRIDStr, )
#             QueryFundDividendInfoByDayRange(xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryFutureSeriesByFutureClass(xs:string FutuClass, )
#             QueryFuturesListMobileXML_NS(xs:int gmrid, xs:string AssetCatalog, xs:string Lang, )
#             QueryFuturesMarginXml(xs:string ExchID, )
#             QueryFuturesPriceByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryFuturesPriceCountByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, )
#             QueryFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string Language, )
#             QueryFuturesQuotePrice(xs:string ExchID, )
#             QueryFuturesQuotePriceXML(xs:string ExchID, )
#             QueryFuturesQuotePriceXML_NS(xs:string ExchID, xs:string Language, )
#             QueryFuturesQuotePrice_NS(xs:string ExchID, xs:string Language, )
#             QueryFxCurrenctAccountListByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryFxQuotePrice(xs:string Lang, )
#             QueryFxQuotePrice_DS(xs:string Lang, )
#             QueryGMRHisFame(xs:int GMRID, )
#             QueryGameDailyReportXML(xs:string gamecode, xs:string itemname, xs:string daydate, )
#             QueryGameRuleRealtimeChecking(xs:int gmrid, )
#             QueryHistoricalFame()
#             QueryHistoricalQuoteData(xs:string AssetCode, xs:int DWM, xs:int Len, )
#             QueryIndexDataByDate(xs:string IndexName, xs:string daydate, xs:string flied, )
#             QueryLatestFameListByGMRID(xs:string GMRID, )
#             QueryLatestFameListByGMRID2(xs:string GMRID, )
#             QueryLatestFameListByGameCodeCountXML(xs:string GameCode, )
#             QueryLatestFameListByGameCodeNewXML(xs:string GameCode, xs:string day, xs:int PageNum, xs:int PageSize, xs:string Lang, )
#             QueryMarketSnap(xs:string CompCode1, xs:string CompCode2, )
#             QueryMarketSnap2(xs:string compcodelist, xs:string lang, )
#             QueryNewsDetailByRptID(xs:long RptID, )
#             QueryNewsTitleByRptIDDate_xml(xs:long RptID, xs:dateTime Daydate, )
#             QueryNewsTop10Title()
#             QueryOddlotWaitingOrderListXML_NS(xs:int SearchTarget, xs:string Language, )
#             QueryOptionATMPriceByOptionClass(xs:string optionclass, )
#             QueryOptionClassByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryOptionClassXML(xs:string ExchID, )
#             QueryOptionSerial(xs:string OptionClass, )
#             QueryOptionUnderlyingPrice(xs:string OptiClass, )
#             QueryOptionUnderlyingPriceXML(xs:string OptiClass, )
#             QueryOptionsBasePrice(xs:string OptiClass, xs:string Lang, )
#             QueryOptionsListMobileXML(xs:string Opticlass, xs:string CPType, xs:string Lang, )
#             QueryOptionsMarginXml(xs:string OptiClass, xs:string CPType, xs:dateTime Maturiy, )
#             QueryOptionsQuotePrice(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOptionsQuotePriceXML(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOrderList()
#             QueryOrderListByDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML2(xs:string GMRIDStr, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryOrderListByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListByDiff2XML_NS(xs:string GMRIDStr, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, xs:string comment, )
#             QueryOrderListGVE3ByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListXML()
#             QueryOrderMaxVolume(xs:string GMRID, xs:string Compcode, xs:string BASction, )
#             QueryOrderStatus(xs:string OrderID, )
#             QueryPortfolioXML()
#             QueryPortfolioXML_NS(xs:string TokenString, )
#             QueryProverb()
#             QueryQuote5Price(xs:string CompCode, )
#             QueryQuotePrice(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2XML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePriceAndAllowOrder(xs:string Compcode, xs:string Gamecode, xs:string Language, )
#             QueryQuotePriceByAssetCatalog(xs:string AssetCatalog, xs:string Target, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingUDP(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingVol(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorID(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDCompTypeCount(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompTypeNew_DS(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int PageNum, xs:int Pagesize, xs:string Language, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompType_DS_NS(xs:string SectorID, xs:string CompType, xs:string Language, )
#             QueryQuotePriceBySectorIDOrderingUDP(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDOrderingVol(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDXML(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDXML_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_DS_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS2(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceXML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice_NS(xs:string AssetCodeList, xs:string Language, )
#             QueryReportClosePositionByGMRDayRange(xs:int gmrid, xs:string startdate, xs:string enddate, xs:string comptypes, xs:string Lang, )
#             QueryReportFutureTradingPerformace(xs:int gmrid, xs:string startdate, xs:string enddate, )
#             QuerySHGYIDX(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySHGYStockData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string Lang, )
#             QuerySelfQuoteListByGMRID(xs:string GMRIDStr, )
#             QuerySelfQuoteListByGMRID_NS(xs:string GMRIDStr, )
#             QueryStockFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string catagory, xs:string Language, )
#             QuerySubscribeNewIssueByGMRID(xs:string GMRID, xs:string Lang, )
#             QuerySystemCompanyChecksumXml_NS(xs:string market, )
#             QueryTodayDealStatisticFutureandOption(xs:string GMRID, xs:string Daydate, )
#             QueryTodayDealStatisticStock(xs:string GMRID, xs:string Daydate, )
#             QueryTodayOpenNAV()
#             QueryTodayOpenNAV_NS(xs:string TokenString, )
#             QueryTodayPositionByCompType(xs:string GMRID, xs:string CompTypeList, xs:string Lang, )
#             QueryTodayPositionByCurrency(xs:string GMRID, xs:string CurrencyList, xs:string Lang, )
#             QueryTodayPositionFund(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundDetailByCompCode(xs:string GMRID, xs:string CompCode, xs:string Lang, )
#             QueryTodayPositionFundXinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionGve3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryTodayPositionNotSettled(xs:string GMRID, xs:string Lang, )
#             QueryTodayTFXML()
#             QueryTodayTFXML_NS(xs:string TokenString, )
#             QueryTotalTFXML()
#             QueryTotalTFXML_NS(xs:string TokenString, )
#             QueryTradeLogSimpleByGMRID(xs:string GMRID, xs:string Language, )
#             QueryTransferAccountListByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListFXByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListGVE3ByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferRecordListGVE3ByGMRIDXML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryTroubleTeamRecordByGMRID(xs:string GMRIDStr, )
#             QueryUserCash(xs:string GMRID, xs:string Lang, )
#             QueryUserCashBriefByGMRID(xs:string GMRID, )
#             QueryUserCashByGMRAccountCurrencyXML_NS(xs:int gmrid, xs:string TradeAccount, xs:string Currency, xs:string Lang, )
#             QueryUserCashGVE3ByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserCashGroupByAccountByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserDetailByGMRID(xs:string GMRIDStr, )
#             QueryUserDetailByUsername(xs:string Username, )
#             QueryUserExchIDByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserProfileByGMRID(xs:string GMRIDStr, )
#             QueryVexchOrderStatisticFutureandOptionAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOption(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOptionByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticStock(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticStockByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserFutureOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserFutureOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserOptionOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserOptionOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserStockOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserStockOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryWaitingOrderList()
#             QueryWaitingOrderListGVE3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingOrderListXML()
#             QueryWaitingOrderListXML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingSMSList()
#             QueryWaitingSMSListGroupByEmail(xs:string Lang, )
#             QueryWarrantsData(xs:string CompCode, xs:string Lang, xs:string AssetClass, xs:string StartDate, xs:string EndDate, xs:string Issuer, )
#             ResetGameInitCash(xs:string GameCode, xs:string InitHold, xs:string AssetCode, )
#             SMSSendComplete(xs:int SMSID, xs:string message, )
#             SetLanguage(xs:string sLanguage, )
#             SignUpStatis(xs:string Gamecode, )
#             TransferCash(xs:string FromAccount, xs:string ToAccount, xs:double Amount, )
#             TransferCash_NS(xs:string GMRID, xs:string FromAccount, xs:string FromCurrency, xs:string ToAccount, xs:string ToCurrency, xs:double Amount, )
#             UpdateFollowOrderDailyLimit(xs:string GMRID, xs:int followed, xs:int dailylimit, )
#             UpdateFollowOrderSubscribeStatus(xs:string followorderids, xs:string GMRID, xs:int toStatus, )
#             UpdateSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, xs:string colname, xs:string Data, )
#             UpdateSelfQuoteDefault(xs:string GMRID, xs:string QuoteID, )
#             UpdateSelfQuoteNameByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string SelfQuoteName, )
#             UpdateSubscribeNewIssue(xs:string GMRID, xs:int sysid, xs:float subscribe, )
#          Types (101):
#             ArrayOfAnyType
#             ArrayOfString
#             AssetOrderType
#             BSActionType
#             xs:ENTITIES
#             xs:ENTITY
#             GVEWSOrder
#             GVEWSOrderList
#             GVEWSPortfolio
#             GVEWSResult
#             GVEWSUserLogList
#             xs:ID
#             xs:IDREF
#             xs:IDREFS
#             xs:NCName
#             xs:NMTOKEN
#             xs:NMTOKENS
#             xs:NOTATION
#             xs:Name
#             OrderStatusCatalog
#             xs:QName
#             ResultCode
#             xs:all
#             xs:allNNI
#             xs:annotated
#             xs:anyType
#             xs:anyURI
#             xs:attribute
#             xs:attributeGroup
#             xs:attributeGroupRef
#             xs:base64Binary
#             xs:blockSet
#             xs:boolean
#             xs:byte
#             xs:complexRestrictionType
#             xs:complexType
#             xs:date
#             xs:dateTime
#             xs:decimal
#             xs:derivationControl
#             xs:derivationSet
#             xs:double
#             xs:duration
#             xs:element
#             xs:explicitGroup
#             xs:extensionType
#             xs:facet
#             xs:float
#             xs:formChoice
#             xs:fullDerivationSet
#             xs:gDay
#             xs:gMonth
#             xs:gMonthDay
#             xs:gYear
#             xs:gYearMonth
#             xs:group
#             xs:groupRef
#             xs:hexBinary
#             xs:int
#             xs:integer
#             xs:keybase
#             xs:language
#             xs:localComplexType
#             xs:localElement
#             xs:localSimpleType
#             xs:long
#             xs:namedAttributeGroup
#             xs:namedGroup
#             xs:namespaceList
#             xs:narrowMaxMin
#             xs:negativeInteger
#             xs:noFixedFacet
#             xs:nonNegativeInteger
#             xs:nonPositiveInteger
#             xs:normalizedString
#             xs:numFacet
#             xs:openAttrs
#             xs:positiveInteger
#             xs:public
#             xs:realGroup
#             xs:reducedDerivationControl
#             xs:restrictionType
#             xs:short
#             xs:simpleDerivationSet
#             xs:simpleExplicitGroup
#             xs:simpleExtensionType
#             xs:simpleRestrictionType
#             xs:simpleType
#             xs:string
#             xs:time
#             xs:token
#             xs:topLevelAttribute
#             xs:topLevelComplexType
#             xs:topLevelElement
#             xs:topLevelSimpleType
#             xs:typeDerivationControl
#             xs:unsignedByte
#             xs:unsignedInt
#             xs:unsignedLong
#             xs:unsignedShort
#             xs:wildcard
#       (GVETransacsSoap12)
#          Methods (248):
#             AdjustOrder(xs:string UserName, xs:string GameCode, xs:string CompCode, xs:string Price, xs:string Volume, xs:string BSAction, xs:string OrderType, xs:string ExpireDate, xs:string OrgVolume, xs:string OrderSource, xs:string CombineNo, )
#             CancelOrder(xs:string OrderID, )
#             CancelOrderStr_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS(xs:string TokenString, xs:string OrderID, )
#             CancelOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:string comment, )
#             ChangeOrder(xs:string OrderID, xs:double Volume, )
#             ChangeOrderPrice(xs:int gmrid, xs:string orderno, xs:string ordertype, xs:string ordernote, xs:float price, xs:string Lang, )
#             ChangeOrder_NS(xs:string TokenString, xs:string OrderID, xs:double Volume, )
#             ChangeOrder_NS_STWS(xs:int GMRID, xs:string OrderID, xs:double Volume, xs:string comment, )
#             CheckAndUpdateAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             CheckAndUpdateFuturAssetData(xs:string CompCode, xs:string CompName, xs:string CompType, xs:string Category, xs:string AssetCatalog, xs:string YClose, xs:string AssetClass, )
#             ClearPosition(xs:string AssetCode, )
#             DeleteSMSWaitingMultiRecord(xs:string SMSID, xs:string message, )
#             DeleteSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             FollowOrderAddSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FollowOrderDeleteSubscribe(xs:string GMRIDStr, xs:string subscribeID, )
#             FuturesFinalSettle()
#             GMRIDToStr(xs:int GMRID, )
#             GMRStrToInt(xs:string GMRIDStr, )
#             GetTradableAsset(xs:string AssetCode, )
#             GetTradableAssetList()
#             GetTradableAssetListXML()
#             MarkupQuoteItemDataXML(xs:string AssetCodeList, xs:string QuoteItemLine, xs:string Language, )
#             NewFollowOrderSubscribe(xs:string GMRID, xs:string SubscribeID, xs:int dailylimit, )
#             NewSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, )
#             OptionFinalSettle()
#             PutBatchOrder(GVEWSOrderList sGVEWSOrderList, )
#             PutCombineOrder(xs:string GMRID, xs:string CompCode1, xs:string BSAction1, xs:int Volume1, xs:string CompCode2, xs:string BSAction2, xs:int Volume2, xs:string OrderType, xs:float PriceDiff, xs:string OptiNote, xs:string OptiCombinNo, xs:string lang, )
#             PutOrder(GVEWSOrder Order, )
#             PutOrderXML(xs:int GMRID, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML1(xs:string GMRIDStr, xs:string AssetCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML2(xs:string GMRIDStr, xs:string AssetCode, xs:int PFLAssetID, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string UseCurrency, )
#             PutOrderXML3(xs:string GMRIDStr, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string str_ip, )
#             PutOrderXML3_STWS(xs:int GMRID, xs:string CompCode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             PutOrderXML3_STWS_2(xs:int GMRID, xs:string CompCode, xs:string username, xs:string gamecode, xs:double Price, xs:double Volume, xs:string BSAction, xs:string OrderType, xs:string expiredate, xs:int IsOddLot, xs:string Currency, xs:string OrderNote, xs:string OCType, xs:string CombineNo, xs:string OrderParameter, xs:string Lang, xs:string comment, )
#             QueryAllSectorList(xs:int ExchID, )
#             QueryAllSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryAllWarrantsSectorList(xs:int ExchID, )
#             QueryAllWarrantsSectorList_NS(xs:int ExchID, xs:string Language, )
#             QueryCataIDByGmridAssetClass(xs:string GMRID, xs:string AssetClass, xs:string Lang, )
#             QueryCompanyData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryCountryCode(xs:string Lang, )
#             QueryDayRangeTFXML(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDayRangeTFXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLog()
#             QueryDealLogBusinessTransactionSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogBy2(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2DiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, )
#             QueryDealLogBy2DiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string CompTypeList, xs:string LogcodeList, xs:string Lang, xs:string comment, )
#             QueryDealLogBy2XML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, )
#             QueryDealLogBy2XML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string CompTypeList, xs:string LogCodeList, xs:string Language, )
#             QueryDealLogByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogByGMRDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDealLogByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByGMRDayRangeXML(xs:int GMRID, xs:string StartDate, xs:string EndDate, )
#             QueryDealLogByGMRDayRangeXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogByOrderID(xs:string OrderID, )
#             QueryDealLogByOrderIDXML(xs:string OrderID, )
#             QueryDealLogByOrderIDXML_NS(xs:string OrderID, xs:string TokenString, xs:string Language, )
#             QueryDealLogCheckSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogCheckSheetByBSActionCompType(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDealLogCheckSheet_STWS(xs:string Comptype, xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogFundTrading(xs:string GMRID, xs:string Lang, )
#             QueryDealLogGVE3ByGMRCompCodeDayRange(xs:string GMRID, xs:string CompCode, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(xs:int GMRID, xs:string StartDate, xs:string EndDate, xs:string Language, )
#             QueryDealLogMarginRateSheet(xs:string Comptype, xs:string GMRID, xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryDealLogWriteOff(xs:string GMRID, xs:string CompTypeList, xs:string BSAction, xs:string Startdate, xs:string Enddate, xs:string Lang, )
#             QueryDividendData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QueryDividendInfoByCompCode(xs:string CompCode, )
#             QueryDividendInfoByCompCode_NS(xs:string CompCode, xs:string Language, )
#             QueryDividendInfoByDayRange(xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryDividendInfoByDayRange_NS(xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryDividendInfoByExchDayRange(xs:string ExchID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryExchRate(xs:string HomeFX, xs:string ForeignFx, xs:int amount, )
#             QueryFXCrossRate(xs:string Lang, xs:string Fx, )
#             QueryFameHistoryByGMRID(xs:string GMRIDStr, )
#             QueryFameList(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGMRFameDateXml_NS(xs:string GMRIDStr, xs:dateTime FameDay, )
#             QueryFameListByGameCode(xs:string GameCode, )
#             QueryFameListByGameCodeFameDate(xs:string GameCode, xs:dateTime FameDay, )
#             QueryFameListByGameCodeUsername(xs:string GameCode, xs:string Username, )
#             QueryFameListTop10ByGameCode_xml(xs:string GameCode, )
#             QueryFollowOrderApprovedHistoryByWeek_xml(xs:string GMRID, xs:int Year, xs:int Week, )
#             QueryFollowOrderBasicDataByGMRID(xs:string GMRID, )
#             QueryFollowOrderCreditUsedDetail_XML(xs:string GMRID, xs:int followid, )
#             QueryFollowOrderFollowerByGMRID(xs:string GMRIDStr, )
#             QueryFollowOrderMyFansApproved_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansSentSummary_XML(xs:string GMRID, )
#             QueryFollowOrderMyFansWaitForApprove_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolAllList_XML(xs:string GMRID, )
#             QueryFollowOrderMyIdolList_XML(xs:string GMRID, )
#             QueryFollowOrderSubScribedByGMRID(xs:string GMRIDStr, )
#             QueryFundDividendInfoByDayRange(xs:string StartDate, xs:string EndDate, xs:string Lang, )
#             QueryFutureSeriesByFutureClass(xs:string FutuClass, )
#             QueryFuturesListMobileXML_NS(xs:int gmrid, xs:string AssetCatalog, xs:string Lang, )
#             QueryFuturesMarginXml(xs:string ExchID, )
#             QueryFuturesPriceByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryFuturesPriceCountByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, )
#             QueryFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string Language, )
#             QueryFuturesQuotePrice(xs:string ExchID, )
#             QueryFuturesQuotePriceXML(xs:string ExchID, )
#             QueryFuturesQuotePriceXML_NS(xs:string ExchID, xs:string Language, )
#             QueryFuturesQuotePrice_NS(xs:string ExchID, xs:string Language, )
#             QueryFxCurrenctAccountListByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryFxQuotePrice(xs:string Lang, )
#             QueryFxQuotePrice_DS(xs:string Lang, )
#             QueryGMRHisFame(xs:int GMRID, )
#             QueryGameDailyReportXML(xs:string gamecode, xs:string itemname, xs:string daydate, )
#             QueryGameRuleRealtimeChecking(xs:int gmrid, )
#             QueryHistoricalFame()
#             QueryHistoricalQuoteData(xs:string AssetCode, xs:int DWM, xs:int Len, )
#             QueryIndexDataByDate(xs:string IndexName, xs:string daydate, xs:string flied, )
#             QueryLatestFameListByGMRID(xs:string GMRID, )
#             QueryLatestFameListByGMRID2(xs:string GMRID, )
#             QueryLatestFameListByGameCodeCountXML(xs:string GameCode, )
#             QueryLatestFameListByGameCodeNewXML(xs:string GameCode, xs:string day, xs:int PageNum, xs:int PageSize, xs:string Lang, )
#             QueryMarketSnap(xs:string CompCode1, xs:string CompCode2, )
#             QueryMarketSnap2(xs:string compcodelist, xs:string lang, )
#             QueryNewsDetailByRptID(xs:long RptID, )
#             QueryNewsTitleByRptIDDate_xml(xs:long RptID, xs:dateTime Daydate, )
#             QueryNewsTop10Title()
#             QueryOddlotWaitingOrderListXML_NS(xs:int SearchTarget, xs:string Language, )
#             QueryOptionATMPriceByOptionClass(xs:string optionclass, )
#             QueryOptionClassByGMRAssetCatalog(xs:string GMRID, xs:string AssetCatalogid, xs:string Lang, )
#             QueryOptionClassXML(xs:string ExchID, )
#             QueryOptionSerial(xs:string OptionClass, )
#             QueryOptionUnderlyingPrice(xs:string OptiClass, )
#             QueryOptionUnderlyingPriceXML(xs:string OptiClass, )
#             QueryOptionsBasePrice(xs:string OptiClass, xs:string Lang, )
#             QueryOptionsListMobileXML(xs:string Opticlass, xs:string CPType, xs:string Lang, )
#             QueryOptionsMarginXml(xs:string OptiClass, xs:string CPType, xs:dateTime Maturiy, )
#             QueryOptionsQuotePrice(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOptionsQuotePriceXML(xs:string OptionUnderlyingCode, xs:string YYYYMM, xs:int CP, )
#             QueryOrderList()
#             QueryOrderListByDayRange(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, )
#             QueryOrderListByDayRangeXML2(xs:string GMRIDStr, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Lang, )
#             QueryOrderListByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListByDiff2XML_NS(xs:string GMRIDStr, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, )
#             QueryOrderListByDiffXML_NS_STWS(xs:int gmrid, xs:string ptr, xs:string startdate, xs:string enddate, xs:int RecordNo, xs:int direction, xs:string Lang, xs:string comment, )
#             QueryOrderListGVE3ByDayRangeXML_NS(xs:string TokenString, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryOrderListXML()
#             QueryOrderMaxVolume(xs:string GMRID, xs:string Compcode, xs:string BASction, )
#             QueryOrderStatus(xs:string OrderID, )
#             QueryPortfolioXML()
#             QueryPortfolioXML_NS(xs:string TokenString, )
#             QueryProverb()
#             QueryQuote5Price(xs:string CompCode, )
#             QueryQuotePrice(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice2XML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePriceAndAllowOrder(xs:string Compcode, xs:string Gamecode, xs:string Language, )
#             QueryQuotePriceByAssetCatalog(xs:string AssetCatalog, xs:string Target, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingUDP(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceByAssetCatalogOrderingVol(xs:string AssetCatalog, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorID(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDCompTypeCount(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompTypeNew_DS(xs:string SectorID, xs:string gmrid, xs:string CompType, xs:int PageNum, xs:int Pagesize, xs:string Language, xs:int top, xs:string sort, )
#             QueryQuotePriceBySectorIDCompType_DS_NS(xs:string SectorID, xs:string CompType, xs:string Language, )
#             QueryQuotePriceBySectorIDOrderingUDP(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDOrderingVol(xs:string CatagoryID, xs:string Ordering, xs:string Lang, )
#             QueryQuotePriceBySectorIDXML(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorIDXML_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_DS_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceBySectorID_NS2(xs:string SectorID, xs:string Language, )
#             QueryQuotePriceXML(xs:string AssetCodeList, xs:string Language, )
#             QueryQuotePrice_NS(xs:string AssetCodeList, xs:string Language, )
#             QueryReportClosePositionByGMRDayRange(xs:int gmrid, xs:string startdate, xs:string enddate, xs:string comptypes, xs:string Lang, )
#             QueryReportFutureTradingPerformace(xs:int gmrid, xs:string startdate, xs:string enddate, )
#             QuerySHGYIDX(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySHGYStockData(xs:string StartDate, xs:string EndDate, xs:string CompCode, xs:string OrderColum, xs:int PageSize, xs:int NowPage, )
#             QuerySelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string Lang, )
#             QuerySelfQuoteListByGMRID(xs:string GMRIDStr, )
#             QuerySelfQuoteListByGMRID_NS(xs:string GMRIDStr, )
#             QueryStockFuturesPricePaginationByGMRAssetCatalog(xs:string gmrid, xs:string AssetCatalog, xs:int PageNum, xs:int Pagesize, xs:string catagory, xs:string Language, )
#             QuerySubscribeNewIssueByGMRID(xs:string GMRID, xs:string Lang, )
#             QuerySystemCompanyChecksumXml_NS(xs:string market, )
#             QueryTodayDealStatisticFutureandOption(xs:string GMRID, xs:string Daydate, )
#             QueryTodayDealStatisticStock(xs:string GMRID, xs:string Daydate, )
#             QueryTodayOpenNAV()
#             QueryTodayOpenNAV_NS(xs:string TokenString, )
#             QueryTodayPositionByCompType(xs:string GMRID, xs:string CompTypeList, xs:string Lang, )
#             QueryTodayPositionByCurrency(xs:string GMRID, xs:string CurrencyList, xs:string Lang, )
#             QueryTodayPositionFund(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundDetailByCompCode(xs:string GMRID, xs:string CompCode, xs:string Lang, )
#             QueryTodayPositionFundXinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionFundinCurrency(xs:string GMRID, xs:string Lang, )
#             QueryTodayPositionGve3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryTodayPositionNotSettled(xs:string GMRID, xs:string Lang, )
#             QueryTodayTFXML()
#             QueryTodayTFXML_NS(xs:string TokenString, )
#             QueryTotalTFXML()
#             QueryTotalTFXML_NS(xs:string TokenString, )
#             QueryTradeLogSimpleByGMRID(xs:string GMRID, xs:string Language, )
#             QueryTransferAccountListByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListFXByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryTransferAccountListGVE3ByGMRID_NS(xs:string GMRID, xs:string Lang, )
#             QueryTransferRecordListGVE3ByGMRIDXML_NS(xs:int GMRID, xs:dateTime StartDate, xs:dateTime EndDate, xs:string Language, )
#             QueryTroubleTeamRecordByGMRID(xs:string GMRIDStr, )
#             QueryUserCash(xs:string GMRID, xs:string Lang, )
#             QueryUserCashBriefByGMRID(xs:string GMRID, )
#             QueryUserCashByGMRAccountCurrencyXML_NS(xs:int gmrid, xs:string TradeAccount, xs:string Currency, xs:string Lang, )
#             QueryUserCashGVE3ByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserCashGroupByAccountByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserDetailByGMRID(xs:string GMRIDStr, )
#             QueryUserDetailByUsername(xs:string Username, )
#             QueryUserExchIDByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryUserProfileByGMRID(xs:string GMRIDStr, )
#             QueryVexchOrderStatisticFutureandOptionAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticFutureandOptionBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockAsk(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockAskByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchOrderStatisticStockBid(xs:string Gamecode, xs:string Lang, )
#             QueryVexchOrderStatisticStockBidByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOption(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticFutureandOptionByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchTodayDealStatisticStock(xs:string Gamecode, xs:string Lang, )
#             QueryVexchTodayDealStatisticStockByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserFutureOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserFutureOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserOptionOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserOptionOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryVexchUserStockOI(xs:string Gamecode, xs:string Lang, )
#             QueryVexchUserStockOIByGMRID(xs:string GMRID, xs:string Lang, )
#             QueryWaitingOrderList()
#             QueryWaitingOrderListGVE3XML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingOrderListXML()
#             QueryWaitingOrderListXML_NS(xs:string TokenString, xs:string Language, )
#             QueryWaitingSMSList()
#             QueryWaitingSMSListGroupByEmail(xs:string Lang, )
#             QueryWarrantsData(xs:string CompCode, xs:string Lang, xs:string AssetClass, xs:string StartDate, xs:string EndDate, xs:string Issuer, )
#             ResetGameInitCash(xs:string GameCode, xs:string InitHold, xs:string AssetCode, )
#             SMSSendComplete(xs:int SMSID, xs:string message, )
#             SetLanguage(xs:string sLanguage, )
#             SignUpStatis(xs:string Gamecode, )
#             TransferCash(xs:string FromAccount, xs:string ToAccount, xs:double Amount, )
#             TransferCash_NS(xs:string GMRID, xs:string FromAccount, xs:string FromCurrency, xs:string ToAccount, xs:string ToCurrency, xs:double Amount, )
#             UpdateFollowOrderDailyLimit(xs:string GMRID, xs:int followed, xs:int dailylimit, )
#             UpdateFollowOrderSubscribeStatus(xs:string followorderids, xs:string GMRID, xs:int toStatus, )
#             UpdateSelfQuoteDataByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string CompCode, xs:string colname, xs:string Data, )
#             UpdateSelfQuoteDefault(xs:string GMRID, xs:string QuoteID, )
#             UpdateSelfQuoteNameByGMRID_NS(xs:string GMRIDStr, xs:string SelfQuoteID, xs:string SelfQuoteName, )
#             UpdateSubscribeNewIssue(xs:string GMRID, xs:int sysid, xs:float subscribe, )
#          Types (101):
#             ArrayOfAnyType
#             ArrayOfString
#             AssetOrderType
#             BSActionType
#             xs:ENTITIES
#             xs:ENTITY
#             GVEWSOrder
#             GVEWSOrderList
#             GVEWSPortfolio
#             GVEWSResult
#             GVEWSUserLogList
#             xs:ID
#             xs:IDREF
#             xs:IDREFS
#             xs:NCName
#             xs:NMTOKEN
#             xs:NMTOKENS
#             xs:NOTATION
#             xs:Name
#             OrderStatusCatalog
#             xs:QName
#             ResultCode
#             xs:all
#             xs:allNNI
#             xs:annotated
#             xs:anyType
#             xs:anyURI
#             xs:attribute
#             xs:attributeGroup
#             xs:attributeGroupRef
#             xs:base64Binary
#             xs:blockSet
#             xs:boolean
#             xs:byte
#             xs:complexRestrictionType
#             xs:complexType
#             xs:date
#             xs:dateTime
#             xs:decimal
#             xs:derivationControl
#             xs:derivationSet
#             xs:double
#             xs:duration
#             xs:element
#             xs:explicitGroup
#             xs:extensionType
#             xs:facet
#             xs:float
#             xs:formChoice
#             xs:fullDerivationSet
#             xs:gDay
#             xs:gMonth
#             xs:gMonthDay
#             xs:gYear
#             xs:gYearMonth
#             xs:group
#             xs:groupRef
#             xs:hexBinary
#             xs:int
#             xs:integer
#             xs:keybase
#             xs:language
#             xs:localComplexType
#             xs:localElement
#             xs:localSimpleType
#             xs:long
#             xs:namedAttributeGroup
#             xs:namedGroup
#             xs:namespaceList
#             xs:narrowMaxMin
#             xs:negativeInteger
#             xs:noFixedFacet
#             xs:nonNegativeInteger
#             xs:nonPositiveInteger
#             xs:normalizedString
#             xs:numFacet
#             xs:openAttrs
#             xs:positiveInteger
#             xs:public
#             xs:realGroup
#             xs:reducedDerivationControl
#             xs:restrictionType
#             xs:short
#             xs:simpleDerivationSet
#             xs:simpleExplicitGroup
#             xs:simpleExtensionType
#             xs:simpleRestrictionType
#             xs:simpleType
#             xs:string
#             xs:time
#             xs:token
#             xs:topLevelAttribute
#             xs:topLevelComplexType
#             xs:topLevelElement
#             xs:topLevelSimpleType
#             xs:typeDerivationControl
#             xs:unsignedByte
#             xs:unsignedInt
#             xs:unsignedLong
#             xs:unsignedShort
#             xs:wildcard
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 第一種

# %%
#9日 K值低於 20% 買進，高於 80% 賣出
def testKD92080set(start_money,close,data):
    K = data.iloc[0:,1] #取 K 值
    #D = data.iloc[0:,2] #取 D 值
    #DIF = data2.iloc[0:,0] #取 DIF 值
    #DEA = data2.iloc[0:,1] #取 DEA 值
    #MACD = data2.iloc[0:,2] #取 MACD 值
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    principal = float(start_money)
    stock_count = 0 #股票張數
    bought_money = 0 #剩餘金額
    final_money = 0 #最終金額
    profit = 0 #獲利
    rateOfReturn = 0.0 #報酬率
    record = [] #存取購買股票時的股價
    lastROP = [] #存取報酬率

    try:
        
        for i in range(len(K)):
            print(date[i])
            print(i)
            print(close[i])
            if(stock_count==0):
                if(float(start_money)>=close[i]*1000):
                    if(K[i]<20):
                        print('K值為:',K[i])
                        print("買了一張股票，股價為:",close[i])
                        stock_count = stock_count + 1
                        start_money = float(start_money) - close[i]*1000
                        record.append(close[i]) #將買的股價放入recorde陣列裡
                        print(record)
                        print('剩餘資金為:',start_money)
                        print('擁有'+str(stock_count)+ '張股票')
                        table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                        #"買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額" 
                    else:
                        print("尚未達到買點")
                        #continue
                else:
                    print("錢不購買")
                    #continue
            else:
                if(close[i] >= record[-1]+5): #現在的股價 >= 停利條件
                    print('現在的股價=',close[i])
                    print('條件: 現股>=最後一次購買股價+10 = ') # recode[-1]為最後一次交易的股價
                    print('最後一次購買股價',record[-1])
                    print('最後一次購買股價+5',record[-1]+5)
                    print('已達停利標準')
                    final_money = start_money + stock_count*close[i]*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:] = []
                    stock_count = 0
                    print("股價為:",close[i])
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                    lastROP.append(rateOfReturn)
                    start_money = final_money #將初始金額改為賣出後的總金額
                    #continue
                elif(close[i] <= record[-1]-5):
                    print('現在的股價=',close[i]) 
                    print('條件: 現股<=最後一次購買股價-5 = ')
                    print('最後一次購買股價',record[-1])
                    print('最後一次購買股價-5',record[-1]-5)
                    print('已達停損標準')
                    final_money = start_money + stock_count*close[i]*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:] = []
                    stock_count = 0
                    print("股價為:",close[i])
                    print("i:",i)
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                    lastROP.append(rateOfReturn)
                    start_money = final_money #將初始金額改為賣出後的總金額
                    #continue
                elif(K[i]<20):
                    if(float(start_money)>=close[i]*1000):
                        print('K值為:',K[i])
                        print("買了一張股票，股價為:",close[i])
                        stock_count = stock_count + 1
                        start_money = float(start_money) - close[i]*1000
                        record.append(close[i]) #將買的股價放入recorde陣列裡
                        print(record)
                        print('剩餘資金為:',start_money)
                        print('擁有'+str(stock_count)+ '張股票')
                        table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                        #"買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額" 
                    else:
                        print("錢不夠再買一張股票")
                        #continue
                elif(K[i]>80):
                    print('K值為:',K[i])
                    print("手上有"+str(stock_count)+"張股票可賣")
                    final_money = start_money + stock_count*close[i]*1000
                    print('賣出'+str(stock_count)+'張股票')
                    record[:] = []
                    stock_count = 0
                    print("股價為:",close[i])
                    print("i:",i)
                    print("擁有資金:",final_money)
                    profit = final_money - principal
                    rateOfReturn = profit/principal*100
                    print("獲利:" , profit)
                    print("報酬率:" , rateOfReturn)
                    table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                    lastROP.append(rateOfReturn)
                    start_money = final_money
                else:
                    print("尚未達到買賣點")
                    #continue
        print("\n")        
        print('總報酬率',lastROP[-1])
        #textPanel.insert("end", rateOfReturn)
        textPanel1.insert("end", lastROP[-1])
        return lastROP[-1]
    except:
        tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:金額輸入錯誤')
        return "Fail"

# %% [markdown]
# ## 第二種

# %%
#K值連續三天低於20後反彈(買進)，K值連續三天高於80後反彈(賣出)
def testKDcontSet(start_money,sell,buy,sProfit,sLoss,close,data):
    K = data.iloc[0:,1] #取 K 值
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    principal = float(start_money)
    stock_count = 0 #股票張數
    #bought_money = 0 #剩餘金額
    final_money = 0 #最終金額
    profit = 0 #獲利
    rateOfReturn = 0.0 #報酬率
    record = [] #存取購買股票時的股價
    lastROP = [] #存取報酬率
    print("2",start_money)
    try:
        for i in range(3,len(K)):
            if stock_count == 0:
                if float(start_money)>=close[i]*1000:
                    if K[i-1]<int(buy) and K[i-2]<int(buy) and K[i-3]<int(buy): 
                        if K[i]>int(buy): # K值連續 3 天小於 20 後上升
                            stock_count = stock_count + 1 #買一張股票
                            start_money = float(start_money) - (float(close[i])*1000) #剩餘資金 = 初始資金 - 當日股價
                            print(date[i-3],'K值為:',K[i-3])
                            print(date[i-2],'K值為:',K[i-2])
                            print(date[i-1],'K值為:',K[i-1])
                            print(date[i],'K值為:',K[i])
                            print("買了一張股票，股價為:",close[i])
                            record.append(close[i]) #將買的股價放入record陣列裡
                            print(record)
                            print('剩餘資金為:',start_money)
                            print('擁有'+str(stock_count)+ '張股票')
                            table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                    else:
                        print("未達買點")
                        continue
                else:
                    print("資金不足")
                    continue

            else:
                if(close[i] >= record[-1]+5): #現在的股價 >= 停利條件
                        print(date[i])
                        print('現在的股價=',close[i]) 
                        print('條件: 現股>=最後一次購買股價+5 = ') # recode[-1]為最後一次交易的股價
                        print('最後一次購買股價',record[-1])
                        print('最後一次購買股價+5',record[-1]+5)
                        print('已達停利標準')
                        final_money = start_money + stock_count*close[i]*1000
                        print('賣出'+str(stock_count)+'張股票')
                        record[:] = []
                        stock_count = 0
                        print("股價為:",close[i])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        lastROP.append(rateOfReturn)
                        print("獲利:" , profit)
                        print("報酬率:" , rateOfReturn)
                        table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                        #lastROP.append(rateOfReturn)
                        start_money = final_money #將初始金額改為賣出後的總金額
                        continue
                elif(close[i] <= record[-1]-5): #現在的股價 <= 停利條件
                        print(date[i])
                        print('現在的股價=',close[i]) 
                        print('條件: 現股<=最後一次購買股價-5 = ')
                        print('最後一次購買股價',record[-1])
                        print('最後一次購買股價-5',record[-1]-5)
                        print('已達停損標準')
                        final_money = start_money + stock_count*close[i]*1000
                        print('賣出'+str(stock_count)+'張股票')
                        record[:] = []
                        stock_count = 0
                        print("股價為:",close[i])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        lastROP.append(rateOfReturn)
                        print("獲利:" , profit)
                        print("報酬率:" , rateOfReturn)
                        table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit)) 

                        #lastROP.append(rateOfReturn)
                        start_money = final_money #將初始金額改為賣出後的總金額
                        continue

                elif K[i-1]<int(buy) and K[i-2]<int(buy) and K[i-3]<int(buy):
                    if K[i]>int(buy):
                        if float(start_money)>=close[i]*1000:
                            stock_count = stock_count + 1 #買一張股票
                            start_money = float(start_money) - (float(close[i])*1000) #剩餘資金 = 初始資金 - 當日股價
                            print(date[i-1],'K值為:',K[i-1])
                            print(date[i-2],'K值為:',K[i-2])
                            print(date[i-3],'K值為:',K[i-3])
                            print(date[i],'K值為:',K[i])
                            print("買了一張股票，股價為:",close[i])
                            record.append(close[i]) #將買的股價放入record陣列裡
                            print(record)
                            print('剩餘資金為:',start_money)
                            print('擁有'+str(stock_count)+ '張股票')
                            table.insert("","end",values=("BUY",date[i],close[i],str(stock_count),start_money))
                        else:
                            print("資金不足")
                elif K[i-1]>int(sell) and K[i-2]>int(sell) and K[i-3]>int(sell):
                    if K[i]<int(sell):
                        print(date[i-1],'K值為:',K[i-1])
                        print(date[i-2],'K值為:',K[i-2])
                        print(date[i-3],'K值為:',K[i-3])
                        print(date[i],'K值為:',K[i])
                        print("手上有"+str(stock_count)+"張股票可賣")
                        final_money = start_money + stock_count*float(close[i])*1000
                        print('賣出'+str(stock_count)+'張股票')
                        record[:]=[]
                        stock_count = 0
                        print("股價為:",close[i])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        lastROP.append(rateOfReturn)
                        print("獲利:" , profit)
                        print("報酬率:" , )
                        table.insert("","end",values=("SELL",date[i],close[i],str(stock_count),final_money,profit))
                        #lastROP.append(rateOfReturn)
                        start_money = final_money
                else:
                    print(date[i])
                    print("未達買賣點")
        print("\n")        
        #textPanel.insert("end", lastROP[-1])
        textPanel2.insert("end", lastROP[-1])
        print('總報酬率',lastROP[-1])
        return lastROP[-1] 
    except:
        tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:金額輸入錯誤')
        return "Fail"

# %% [markdown]
# ## 第三種

# %%
## K值向上突破D值 (黃金交叉)，K值向下突破 D值 (死亡交叉)
def testKDcrossSet(start_money,close,data):
    K = data.iloc[0:,1] #取 K 值
    D = data.iloc[0:,2] #取 D 值
    principal = float(start_money)
    #close = df.Close['2018'] #取每日收盤價
    date = data.iloc[0:,0] #取日期
    stock_count = 0 #股票張數
    bought_money = 0.0 #剩餘金額
    final_money = 0.0 #最終金額
    profit = 0.0 #獲利
    rateOfReturn = 0.0 #報酬率
    lastROP = []  
    record = []
    try:  
        for i in range(1,len(K)):
            #print(date[i])
            print(date[i])
            print(i)
            print(close[i])
            if(len(record)==0): #手上沒股票
                if(float(start_money)>=close[i-1]*1000): #身上錢夠
                    if (K[i-1]<D[i-1] and K[i]>D[i]): #黃金交叉，買股票
                            stock_count = stock_count + 1
                            start_money = float(start_money) - (float(close[i-1])*1000)
                            record.append(close[i-1])
                            print("record:",record)
                            print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                            print("買了一張股票，股價為:",close[i-1])
                            print('剩餘資金為:',start_money)
                            print('擁有'+str(stock_count)+ '張股票')
                            table.insert("","end",values=("BUY",date[i-1],close[i-1],str(stock_count),start_money))
                    else: #不是黃金交叉，直接進入下個迴圈
                        continue
                else: #錢不夠，進入下個迴圈
                    continue
            elif(len(record)!=0): #身上有股票，判斷是否符合停利/停損，是->賣掉，否->判斷為黃金交叉(買)/死亡交叉(賣)/都不是(繼續)
                    if close[i-1] >= record[-1]+5 :#停利，賣股票
                        print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                        print("手上有"+str(stock_count)+"張股票可賣")
                        final_money = start_money + stock_count*float(close[i-1])*1000
                        print('賣出'+str(stock_count)+'張股票')
                        stock_count = 0
                        record[:]=[]
                        print("股價為:",close[i-1])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        print("獲利:" , profit)
                        print("報酬率:" , rateOfReturn)
                        rateOfReturn = round(rateOfReturn, 2)
                        lastROP.append(rateOfReturn)
                        table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                        start_money = final_money
                    elif close[i-1] <= record[-1]-5 :
                        print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                        print("手上有"+str(stock_count)+"張股票可賣")
                        final_money = start_money + stock_count*float(close[i-1])*1000
                        print('賣出'+str(stock_count)+'張股票')
                        stock_count = 0
                        record[:]=[]
                        print("股價為:",close[i-1])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        print("獲利:" , profit)
                        print("報酬率:" , rateOfReturn)
                        rateOfReturn = round(rateOfReturn, 2)
                        lastROP.append(rateOfReturn)
                        table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                        start_money = final_money
                    elif (K[i-1]<D[i-1] and K[i]>D[i]):#買
                            if float(start_money)>=close[i]*1000:
                                stock_count = stock_count + 1 #買一張股票
                                bought_money = start_money - (float(close[i-1])*1000) #剩餘資金 = 上一次交易剩餘資金 - 當日股價
                                record.append(close[i])
                                print(date[i-1],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                                print("買了一張股票，股價為:",close[i-1])
                                print('剩餘資金為:',bought_money)
                                print('擁有'+str(stock_count)+ '張股票')
                                table.insert("","end",values=("BUY",date[i-1],close[i-1],str(stock_count),bought_money))
                                start_money = bought_money
                            else:
                                continue
                    elif (K[i-1]>D[i-1] and K[i]<D[i]):
                        print(date[i],'K值為:',K[i-1], 'D值為:',D[i-1], date[i], 'K值為:',K[i], 'D值為:',D[i])
                        print("手上有"+str(stock_count)+"張股票可賣")
                        final_money = start_money + stock_count*float(close[i-1])*1000
                        print('賣出'+str(stock_count)+'張股票')
                        stock_count = 0
                        record[:]=[]
                        print("股價為:",close[i-1])
                        print("擁有資金:",final_money)
                        profit = final_money - principal
                        rateOfReturn = profit/principal*100
                        rateOfReturn = round(rateOfReturn, 2)
                        print("獲利:" , profit)
                        print("報酬率:" , rateOfReturn)
                        lastROP.append(rateOfReturn)
                        print(lastROP)
                        table.insert("","end",values=("SELL",date[i-1],close[i-1],str(stock_count),final_money,profit))
                        start_money = final_money

        textPanel3.insert("end",lastROP[-1])
        return lastROP[-1]
    except:
        tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:金額輸入錯誤')
        return "Fail"

# %%
def first():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    #buy = buy_entry.get()
    #sell = sell_entry.get()
    #sProfit = sProfit_entry.get()
    #sLoss = sLoss_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;
    
    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
        #data.plot()
    data.reset_index(inplace=True)
        #print(data)

        #testKDcrossSet(start_money,close,sProfit,sLoss,data)

    return testKD92080set(start_money,close2,data)

# %%
def second():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    buy = buy_entry.get()
    sell = sell_entry.get()
    sProfit = sProfit_entry.get()
    sLoss = sLoss_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;


    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
        #data.plot()
    data.reset_index(inplace=True)
        #print(data)

        #testKDcrossSet(start_money,close,sProfit,sLoss,data)

    return testKDcontSet(start_money,sell,buy,sProfit,sLoss,close2,data)

# %%
def third():
    stock = stockCode_entry.get()
    start_money = start_money_entry.get()
    #buy = buy_entry.get()
    #sell = sell_entry.get()
    start_time = startTime_entry.get()
    end_time = endTime_entry.get()
    #sProfit = sProfit_entry.get()
    #sLoss = sLoss_entry.get()
    df = crawl_price(stock)
    close = df.Close[start_time:end_time].dropna().astype(float)
    close2 = round(close, 2)
    openp = df.Open[start_time:end_time]
    high = df.High[start_time:end_time]
    low = df.Low[start_time:end_time]
    volumn = df.Volume[start_time:end_time]
    stock = {
    'close':close.dropna().astype(float),
    'open':openp.dropna().astype(float),
    'high':high.dropna().astype(float),
    'low':low.dropna().astype(float),
    'volume': volumn.dropna().astype(float),
    }
    #callTable()
    def talib2df(talib_output):
        if type(talib_output) == list:
            ret = pd.DataFrame(talib_output).transpose()
        else:
            ret = pd.Series(talib_output)
        ret.index = stock['close'].index
        return ret;
    data = talib2df(talib.abstract.STOCH(stock,fastk_period=9,
                slowk_period=3,
                slowk_matype=0,
                slowd_period=3,
                slowd_matype=0))
        #data.plot()
    data.reset_index(inplace=True)
        #print(data)

        #testKDcrossSet(start_money,close,sProfit,sLoss,data)

    return testKDcrossSet(start_money,close2,data)

# %%
def callfunc():
    ans = v.get()
    if(ans=="K值小於設定值進場，大於設定值出場"):
        first()
        #table=ttk.Treeview(frm_r)#表格
    elif(ans=="K值連續3天小於設定值後反彈進場"):
        second()
    elif(ans=="黃金交叉與死亡交叉"):
        third()
def Run3():
    #first()
    #second()
    #third()
    a = int(first())
    b = int(second())
    c = int(third())
    if a>b:
        if b>c:
            print("第一個策略獲利最多")
            bestanswer = "第一個策略獲利最多"
        else:
            if a>c:
                print('第一個策略獲利最多')
                bestanswer = "第一個策略獲利最多"

            else:
                print('第三個策略獲利最多')
                bestanswer = "第三個策略獲利最多"
    elif a<b:
        if b<c:
            print('第三個策略獲利最多')
            bestanswer = "第三個策略獲利最多"
        else:
            if c>a:
                print('第二個策略獲利最多')
                bestanswer = "第二個策略獲利最多"
            else:
                print('第二個策略獲利最多')
                bestanswer = "第二個策略獲利最多"

    answer2 = tk.Label(frm_l, text= bestanswer)
    answer2.grid(row =18, column = 1,sticky='W')
def deletetable():
    x = table.get_children()
    for item in x: 
        table.delete(item) 
    textPanel.delete('1.0','end') 
    textPanel1.delete('1.0','end') 
    textPanel2.delete('1.0','end') 
    textPanel3.delete('1.0','end')

# %%
def order():
    win.destroy()
    order = tk.Tk()
    order.title('下單')
    order.geometry("1300x800")
    frame = tk.Frame(order)
    frame.grid(row = 0)
    frame_l = tk.Frame(frame, ) #左視窗
    frame_r = tk.Frame(frame) #右視窗
    frame_c = tk.Frame(frame,)
    frame_l.grid(row = 1,column = 0)
    frame_r.grid(row = 1,column = 2)
    frame_c.grid(row = 1,column = 1)
    #textPanel = tk.Text(frame_r,height=30, width=65)
    #textPanel.grid()
    
    
    
    
    def getOrderRecorde(): #委託紀錄id(

        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("委託時間","委託單ID","股票代碼","公司名稱","委託價格","委託數量","買賣類型","掛單類型")
        #表示列,不显示
        table.column("委託時間",width=160)
        table.column("委託單ID",width=100)
        table.column("股票代碼",width=80)
        table.column("公司名稱",width=80)
        table.column("委託價格",width=80)
        table.column("委託數量",width=80)
        table.column("買賣類型",width=80)
        table.column("掛單類型",width=80)

        #显示表头
        table.heading("委託時間",text="委託時間")
        table.heading("委託單ID",text="委託單ID")
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("委託價格",text="委託價格")
        table.heading("委託數量",text="委託數量")
        table.heading("買賣類型",text="買賣類型")
        table.heading("掛單類型",text="掛單類型")
        
        table.grid(row = 0, column = 0)
        order = client.service.QueryWaitingOrderListGVE3XML_NS("", "TC", )
        root2 = ET.fromstring(order)
        i = 1
        for country in root2.findall('Order'):
            print("第",i,"筆委託紀錄")
            OrderTime = country.get('OrderTime')
            OrderID = country.get('OrderID')
            AssetID = country.get('AssetID')
            CompName = country.get('CompName')
            Price = country.get('Price')
            Volume = country.get('Volume')
            BSAction = country.get('BSAction')
            OrderType = country.get('OrderType')

            print(OrderTime, OrderID, AssetID, CompName, Price, Volume, BSAction, OrderType)
            i+=1
            table.insert("","end",values=(OrderTime,OrderID,AssetID,CompName,Price,Volume,BSAction,OrderType))
            
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        #textPanel.insert("end", order)
    def getInstock(): #庫存
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("股票代碼","公司名稱","持有數量","持有成本","現價","漲跌","盈虧","累積未實現損益")
        #表示列,不显示
        table.column("股票代碼",width=160)
        table.column("公司名稱",width=80)
        table.column("持有數量",width=80)
        table.column("持有成本",width=80)
        table.column("現價",width=80)
        table.column("漲跌",width=80)
        table.column("盈虧",width=80)
        table.column("累積未實現損益",width=80)

        #显示表头
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("持有數量",text="持有數量")
        table.heading("持有成本",text="持有成本")
        table.heading("現價",text="現價")
        table.heading("漲跌",text="漲跌")
        table.heading("盈虧",text="盈虧")
        table.heading("累積未實現損益",text="累積未實現損益")
        
        table.grid(row = 0, column = 0)
        
        instock = client.service.QueryTodayPositionGve3XML_NS("", "TC", )
        root1 = ET.fromstring(instock)
        i = 1
        for country in root1.findall('PortfolioAsset'):
            print("第",i,"筆庫存紀錄")
            #LogID = country.get('LogID')
            AssetCode = country.get('AssetCode')
            CompName = country.get('CompName')
            Hold = country.get('Hold')
            Cost = country.get('Cost')
            QuotePrice = country.get('QuotePrice')
            UpDown = country.get('UpDown')
            PL = country.get('PL')
            UnRealizedPL = country.get('UnRealizedPL')
            print(AssetCode, CompName, Hold, Cost, QuotePrice, UpDown, PL, UnRealizedPL)
            i+=1
            table.insert("","end",values=(AssetCode,CompName,Hold,Cost,QuotePrice,UpDown,PL,UnRealizedPL))
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        #textPanel.insert("end", instock)
    def getDeal(): #成交紀錄
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("交易時間","股票代碼","公司名稱","買賣類型","掛單類型","成交價","成交量","手續費","交易訊息")
        table.column("交易時間",width=160)   #表示列,不显示
        table.column("股票代碼",width=80)
        table.column("公司名稱",width=80)
        table.column("買賣類型",width=80)
        table.column("掛單類型",width=80)
        table.column("成交價",width=80)
        table.column("成交量",width=80)
        table.column("手續費",width=80)
        table.column("交易訊息",width=80)

        table.heading("交易時間",text="交易時間")  #显示表头
        table.heading("股票代碼",text="股票代碼")
        table.heading("公司名稱",text="公司名稱")
        table.heading("買賣類型",text="買賣類型")
        table.heading("掛單類型",text="掛單類型")
        table.heading("成交價",text="成交價")
        table.heading("成交量",text="成交量")
        table.heading("手續費",text="手續費")
        table.heading("交易訊息",text="交易訊息")
        
        table.grid(row = 0, column = 0)
        deal = client.service.QueryDealLogGVE3ByGMRDayRangeLiteXML_NS(1111708496, "2019/04/01", "2019/12/31", "TW", )
        i = 1
        root = ET.fromstring(deal)
        for country in root.findall('GVEUserLog'):
            print("第",i,"筆成交紀錄")
            #LogID = country.get('LogID')
            LogTime = country.get('LogTime')
            AssetCode = country.get('AssetCode')
            CompName = country.get('CompName')
            BSAction = country.get('BSAction')
            OrderType = country.get('OrderType')
            Price = country.get('Price')
            Volume = country.get('Volume')
            fee = country.get('fee')
            logdesc = country.get('logdesc')
            print(LogTime, AssetCode, CompName, BSAction, OrderType, Price, Volume, fee, logdesc)
            i+=1
            table.insert("","end",values=(LogTime,AssetCode,CompName,BSAction,OrderType,Price,Volume,fee,logdesc))
            
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
    def getOrder(): #下單
    
            #GMRIDstr = GMRIDstr_Entry.get()
            compcode = CompCode_Entry.get()
            price = Price_Entry.get()
            volume = Volume_Entry.get()
            bsaction = BSAction_Entry.get()
            ordertype = OrderType_Entry.get()
            #currency = Currency_Entry.get()
            isoddlot = IsOddLot_Entry.get()
            ordernote = OrderNote_Entry.get()
            #octype = OCtype_Entry.get()
            #combineno = CombineNo_Entry.get()
            #parameter = OrderParameter_Entry.get()
            #lang = lang_Entry.get()
            #ip = str_ip_Entry.get()

            result = client.service.PutOrderXML3("BCSP", compcode, price, volume, bsaction, ordertype, isoddlot, "TWD", ordernote, "0", "","0", "TC", "127.0.0.1", )
            print(result)
            new = result.split("\"")
            if new[1] == "Success":
                tk.messagebox.showinfo(title='回報', message='Success')
            elif new[1] == "Failure":
                tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:'+new[5])
            else:
                tk.messagebox.showinfo(title='回報',message = 'Failure\n'+'原因:格式輸入錯誤')

    def getPrice():
        table=ttk.Treeview(frame_r,show='headings')#表格
        table["columns"]=("成交價","成交量","委買價","委買量","委賣價","委賣量","昨收價","漲停價","跌停價")
         #表示列,不显示
        table.column("成交價",width=160)
        table.column("成交量",width=80)
        table.column("委買價",width=80)
        table.column("委買量",width=80)
        table.column("委賣價",width=80)
        table.column("委賣量",width=80)
        table.column("昨收價",width=80)
        table.column("漲停價",width=80)
        table.column("跌停價",width=80)

        table.heading("成交價",text="成交價")  #显示表头
        table.heading("成交量",text="成交量")
        table.heading("委買價",text="委買價")
        table.heading("委買量",text="委買量")
        table.heading("委賣價",text="委賣價")
        table.heading("委賣量",text="委賣量")
        table.heading("昨收價",text="昨收價")
        table.heading("漲停價",text="漲停價")
        table.heading("跌停價",text="跌停價")
        
        table.grid(row = 0, column = 0)
        compcode = CompCode_Entry.get()
        price = client.service.QueryQuote5Price(compcode, )
        r = ET.fromstring(price)
        r_new = "您查詢的股價為:\n"+"成交價:"+str(r[0][0].text)+\
                                "\n"+"成交量:"+str(r[0][1].text)+\
                                "\n"+"委買價:"+str(r[0][2].text)+\
                                "\n"+"委買量:"+str(r[0][22].text)+\
                                "\n"+"委賣價:"+str(r[0][12].text)+\
                                "\n"+"委賣量:"+str(r[0][23].text)+\
                                "\n"+"昨收價:"+str(r[0][24].text)+\
                                "\n"+"漲停價:"+str(r[0][25].text)+\
                                "\n"+"跌停價:"+str(r[0][26].text)+"\n"
        
        
        table.insert("","end", values=(str(r[0][0].text),str(r[0][1].text),str(r[0][2].text),str(r[0][22].text),str(r[0][12].text),str(r[0][23].text),str(r[0][24].text),str(r[0][25].text),str(r[0][26].text)))
        def deletetable(): #清除
            #x = table.get_children()
            #for item in x: 
                #table.delete(item) 
            table.destroy()
            del_btn.destroy()
        del_btn = tk.Button(frame_r, text="清除查詢內容", command=deletetable)
        del_btn.grid(row = 1, column = 0)
        
    def cancelOrder():
        cancle_id = cancle_entry.get()
        TokenString = ""
        client.service.CancelOrderStr_NS(TokenString, cancle_id, )
        getOrderRecorde()
    #GMRIDstr
    #GMRIDstr = tk.Label(frame_l, text="GMRIDstr")
    #GMRIDstr.grid(row=0,column=0)
    #股票代碼
    CompCode = tk.Label(frame_l, text="CompCode")
    CompCode.grid(row=1,column=0)
    #價格
    Price = tk.Label(frame_l, text="Price")
    Price.grid(row=2,column=0)
    #成交量
    Volumn = tk.Label(frame_l, text="Volume")
    Volumn.grid(row=3,column=0)
    #使用代碼 普通買進(B),普通賣出(S),融資買入(MB),融資賣出(RB),融券買入(RS),
    BSAction = tk.Label(frame_l, text="BSAction")
    BSAction.grid(row=4,column=0)
    #下單類型 漲停價(LMTU),跌停價(LMTD),限價單(LMT)，期權市價單：MKT
    OrderType = tk.Label(frame_l, text="OrderType")
    OrderType.grid(row=5,column=0)
    #預設給零  0: normal (照ASSET CATALOG中的交易時間), 1:for TW 零股交易
    IsOddLot = tk.Label(frame_l, text="IsOddLot")
    IsOddLot.grid(row=7,column=0)
    #Currency TWD
    #Currency = tk.Label(frame_l, text="Currency")
    #Currency.grid(row=6,column=0)
    #預設ROD
    OrderNote = tk.Label(frame_l, text ="orderNote")
    OrderNote.grid(row=8,column=0)
    #現貨固定給零；期貨作多：buy，作空：sell；選擇權新倉：O，平倉：C
    #OCtype = tk.Label(frame_l, text ="OCtype")
    #OCtype.grid(row=9,column=0)
    #固定給空白
    #CombineNo = tk.Label(frame_l, text ="CombineNo")
    #CombineNo.grid(row=10,column=0)
    #預設給零  0:普通, 50:當沖單, 60:組合單
    #OrderParameter = tk.Label(frame_l, text ="OrderParameter")
    #OrderParameter.grid(row=11,column=0)
    #Lang //固定給TC
    #lang = tk.Label(frame_l, text ="lang")
    #lang.grid(row=12,column=0)
    #str_ip //IP位置
    #str_ip = tk.Label(frame_l, text ="str_ip")
    #str_ip.grid(row=13,column=0)
    #取消委託
    cancleOrder = tk.Label(frame_l, text = "--------取消委託--------")
    cancleOrder.grid(row=14,column=0)
    cancle = tk.Label(frame_l, text = "輸入ID:")
    cancle.grid(row = 15, column = 0)
    cancle_entry = tk.Entry(frame_l)
    cancle_entry.grid(row=15,column = 1)
    #lb.pack()
    #GMRIDstr = tk.StringVar(value="BCSP")
    CompCode = tk.StringVar(value="2330.tw")
    #Price = tk.StringVar(value="2330.tw")
    Volume = tk.StringVar(value="1000")
    BSAction = tk.StringVar(value="B")
    OrderType = tk.StringVar(value="MKT")
    #Currency = tk.StringVar(value="TWD")
    IsOddLot = tk.StringVar(value="0")
    OrderNote = tk.StringVar(value="ROD")
    #OCtype = tk.StringVar(value="0")
    #OrderParameter = tk.StringVar(value="0")
    #lang = tk.StringVar(value="TC")
    #str_ip = tk.StringVar(value="127.0.0.1")
    
    #GMRIDstr_Entry = tk.Entry(frame_l,textvariable=GMRIDstr)
    #GMRIDstr_Entry.grid(row=0,column=1)

    CompCode_Entry = tk.Entry(frame_l,textvariable=CompCode)
    CompCode_Entry.grid(row=1,column=1)

    Price_Entry = tk.Entry(frame_l,textvariable=Price)
    Price_Entry.grid(row=2,column=1)

    Volume_Entry = tk.Entry(frame_l,textvariable=Volume)
    Volume_Entry.grid(row=3,column=1)

    BSAction_Entry = tk.Entry(frame_l,textvariable=BSAction)
    BSAction_Entry.grid(row=4,column=1)

    OrderType_Entry = tk.Entry(frame_l,textvariable=OrderType)
    OrderType_Entry.grid(row=5,column=1)

    #Currency_Entry = tk.Entry(frame_l,textvariable=Currency)
    #Currency_Entry.grid(row=6,column=1)

    IsOddLot_Entry = tk.Entry(frame_l,textvariable=IsOddLot)
    IsOddLot_Entry.grid(row=7,column=1)

    OrderNote_Entry = tk.Entry(frame_l,textvariable=OrderNote)
    OrderNote_Entry.grid(row=8,column=1)

    #OCtype_Entry = tk.Entry(frame_l,textvariable=OCtype)
    #OCtype_Entry.grid(row=9,column=1)

    #CombineNo_Entry = tk.Entry(frame_l,textvariable=CombineNo)
    #CombineNo_Entry.grid(row=10,column=1)

    #OrderParameter_Entry = tk.Entry(frame_l,textvariable=OrderParameter)
    #OrderParameter_Entry.grid(row=11,column=1)

    #lang_Entry = tk.Entry(frame_l,textvariable=lang)
    #lang_Entry.grid(row=12,column=1)

    #str_ip_Entry = tk.Entry(frame_l,textvariable=str_ip)
    #str_ip_Entry.grid(row=13,column=1)

#-------------------------Button-------------------------#    
    order_btn = tk.Button(frame_c , text="下單", command=getOrder) #彈出視窗表示成功或失敗
    order_btn.grid()
        
    record_btn = tk.Button(frame_c, text="委託紀錄", command=getOrderRecorde)#以表格方式呈現
    record_btn.grid()
    
    instock_btn = tk.Button(frame_c, text="庫存查詢", command=getInstock) #以表格方式呈現
    instock_btn.grid()
    
    deal_btn = tk.Button(frame_c, text="成交查詢", command = getDeal)
    deal_btn.grid()
    
    stockprice_btn = tk.Button(frame_c, text="即時股價查詢", command=getPrice) #彈出視窗，輸入股票代碼，印出股價
    stockprice_btn.grid()
    
    cancle_btn = tk.Button(frame_l, text="取消委託", command = cancelOrder)
    cancle_btn.grid(row = 17,column = 0)

# %%
win = tk.Tk() #建立主視窗
win.title("股票回測") #視窗標題
win.geometry("1000x600")#寬*高
#style = ttk.Style(win)
#style.theme_use('classic') 
#win.resizable(False, False)#限制縮放
#win.config(background="#323232") #視窗背景顏色
#框架
frm = tk.Frame(win)
frm.grid(row = 0)
frm_l = tk.Frame(frm, ) #左視窗
frm_r = tk.Frame(frm) #右視窗
frm_l.grid(row = 1,column = 0)
frm_r.grid(row = 1,column = 1)
#tk.Label(frm,bg="#323232",fg="white",text="輸入股票代碼:" )
#-----------------------Text---------------------------------
#股票代碼
stockCode = tk.Label(frm_l, text="輸入股票代碼:")
stockCode.grid(row=0,column=0,sticky='NW')
#股票日期
startTime = tk.Label(frm_l, text="輸入起始時間:")
startTime.grid(row=1,column=0,sticky='NW')
endTime = tk.Label(frm_l, text='輸入結束時間')
endTime.grid(row=2,column=0,sticky='NW')
#初始金額
start_money = tk.Label(frm_l, text="輸入初始金額:")
start_money.grid(row=3,column=0,sticky='NW')
#低於幾%買進
buy = tk.Label(frm_l, text="輸入買進條件:")
buy.grid(row=4,column=0,sticky='NW')
#高於幾%賣出
sell = tk.Label(frm_l, text="輸入賣出條件:")
sell.grid(row=5,column=0,sticky='NW')
#停利
sProfit = tk.Label(frm_l, text="輸入停利條件:")
sProfit.grid(row=6,column=0,sticky='NW')
#停損
sLoss = tk.Label(frm_l, text="輸入停損條件:")
sLoss.grid(row=7,column=0,sticky='NW')
#lb.pack()

#-------------------------table------------------------------
table=ttk.Treeview(frm_r,show='headings')#表格
table["columns"]=("買/賣 狀態","交易日期","股票價格","股票庫存","資金餘額","賣出獲利")
table.column("買/賣 狀態",width=100)   #表示列,不显示
table.column("交易日期",width=100)
table.column("股票價格",width=100)
table.column("股票庫存",width=100)
table.column("資金餘額",width=100)
table.column("賣出獲利",width=100)

table.heading("買/賣 狀態",text="買/賣 狀態")  #显示表头
table.heading("交易日期",text="交易日期")
table.heading("股票價格",text="股票價格")
table.heading("股票庫存",text="股票庫存")
table.heading("資金餘額",text="資金餘額")
table.heading("賣出獲利",text="賣出獲利")
table.grid()
#--------------------------textPanel-----------------------------------
#報酬率
pOfrate = tk.Label(frm_l, text=' 報酬率 :')
pOfrate.grid(row =14, column = 0,sticky='W')
textPanel = tk.Text(frm_l,height=1, width=4)
textPanel.grid(row =14,column=1,sticky='W')
#報酬率 1
ROP1 = tk.Label(frm_l, text=' K值大小')
ROP1.grid(row =15, column = 0,sticky='W')
textPanel1 = tk.Text(frm_l,height=1, width=4)
textPanel1.grid(row =15, column = 1,sticky='W')
ROP2 = tk.Label(frm_l, text=' 連三反彈')
ROP2.grid(row =16, column = 0,sticky='W')
textPanel2 = tk.Text(frm_l,height=1, width=4)
textPanel2.grid(row =16, column = 1,sticky='W')
ROP3 = tk.Label(frm_l, text=' 黃金交叉')
ROP3.grid(row =17, column = 0,sticky='W')
textPanel3 = tk.Text(frm_l, height=1, width=4)
textPanel3.grid(row =17, column = 1,sticky='W')
answer = tk.Label(frm_l, text=' 比較結果:')
answer.grid(row =18, column = 0,sticky='W')

#----------------------------entry-----------------------------------------
#Entry輸入框
stock = tk.StringVar(value='2330.TW')
time = tk.StringVar(value='2018')
sMoney =tk.StringVar(value='1000000')
bEntry = tk.StringVar(value='20')
sEntry = tk.StringVar(value='80')
pEntry = tk.StringVar(value='0.018')
lEntry = tk.StringVar(value='0.01')

stockCode_entry = tk.Entry(frm_l,textvariable=stock)
stockCode_entry.grid(row=0,column=1,sticky='W')
startTime_entry = tk.Entry(frm_l,textvariable=time)
startTime_entry.grid(row=1,column=1,sticky='W')
endTime_entry = tk.Entry(frm_l)
endTime_entry.grid(row=2,column=1,sticky='W')
start_money_entry = tk.Entry(frm_l,textvariable=sMoney)
start_money_entry.grid(row=3,column=1,sticky='W')
buy_entry = tk.Entry(frm_l,textvariable=bEntry)
buy_entry.grid(row=4,column=1,sticky='W')
sell_entry = tk.Entry(frm_l,textvariable=sEntry)
sell_entry.grid(row=5,column=1,sticky='W')
sProfit_entry = tk.Entry(frm_l,textvariable=pEntry)
sProfit_entry.grid(row=6,column=1,sticky='W')
sLoss_entry = tk.Entry(frm_l,textvariable=lEntry)
sLoss_entry.grid(row=7,column=1,sticky='W')
#option = tk.Option
optionList = ["K值小於設定值進場，大於設定值出場","K值連續3天小於設定值後反彈進場","黃金交叉與死亡交叉"]
v = tk.StringVar()
v.set("選擇條件")
optionmenu = tk.OptionMenu(frm_l, v, *optionList)#command=func(*optionList))
optionmenu.grid(row=8,column=0,sticky='W')
#en.pack()

#-------------------------Button-------------------------#
btn = tk.Button(frm_l, text="回測",command=callfunc) #button內容、顏色
#OR獨立寫 btn.config(bg = "skyblue")
#btn.config(width=5, height=5) #button大小
#btn.config(image=img) #不可跟上兩行同時，也就是說圖片就是button
#btn.config(command=say_hi)
btn.grid(row = 11,column = 0,pady = 10) #封裝
btn2 = tk.Button(frm_l, text="清除", command=deletetable) #button內容、顏色
#OR獨立寫 btn.config(bg = "skyblue")
#btn.config(width=5, height=5) #button大小
#btn.config(image=img) #不可跟上兩行同時，也就是說圖片就是button
#btn.config(command=say_hi)
btn2.grid(row = 12,column = 0, pady = 10) #封裝

btn3 = tk.Button(frm_l, text="下單", command=order)
btn3.grid(row = 11,column = 1, pady = 10)



btn4 = tk.Button(frm_l, text="Run3", command = Run3)
btn4.grid(row = 12,column = 1, pady = 10)        

win.mainloop()
# Out:
# 2018-01-02 00:00:00
# 0
# 232.5
# 尚未達到買點
# 2018-01-03 00:00:00
# 1
# 237.0
# 尚未達到買點
# 2018-01-04 00:00:00
# 2
# 239.5
# 尚未達到買點
# 2018-01-05 00:00:00
# 3
# 240.0
# 尚未達到買點
# 2018-01-08 00:00:00
# 4
# 242.0
# 尚未達到買點
# 2018-01-09 00:00:00
# 5
# 242.0
# 尚未達到買點
# 2018-01-10 00:00:00
# 6
# 236.5
# 尚未達到買點
# 2018-01-11 00:00:00
# 7
# 235.0
# 尚未達到買點
# 2018-01-12 00:00:00
# 8
# 237.0
# 尚未達到買點
# 2018-01-15 00:00:00
# 9
# 240.0
# 尚未達到買點
# 2018-01-16 00:00:00
# 10
# 240.5
# 尚未達到買點
# 2018-01-17 00:00:00
# 11
# 242.0
# 尚未達到買點
# 2018-01-18 00:00:00
# 12
# 248.5
# 尚未達到買點
# 2018-01-19 00:00:00
# 13
# 255.5
# 尚未達到買點
# 2018-01-22 00:00:00
# 14
# 261.5
# 尚未達到買點
# 2018-01-23 00:00:00
# 15
# 266.0
# 尚未達到買點
# 2018-01-24 00:00:00
# 16
# 258.0
# 尚未達到買點
# 2018-01-25 00:00:00
# 17
# 258.0
# 尚未達到買點
# 2018-01-26 00:00:00
# 18
# 255.0
# 尚未達到買點
# 2018-01-29 00:00:00
# 19
# 258.5
# 尚未達到買點
# 2018-01-30 00:00:00
# 20
# 253.0
# 尚未達到買點
# 2018-01-31 00:00:00
# 21
# 255.0
# 尚未達到買點
# 2018-02-01 00:00:00
# 22
# 259.5
# 尚未達到買點
# 2018-02-02 00:00:00
# 23
# 259.5
# 尚未達到買點
# 2018-02-05 00:00:00
# 24
# 253.0
# 尚未達到買點
# 2018-02-06 00:00:00
# 25
# 239.0
# 尚未達到買點
# 2018-02-07 00:00:00
# 26
# 240.0
# K值為: 19.00112233445567
# 買了一張股票，股價為: 240.0
# [240.0]
# 剩餘資金為: 760000.0
# 擁有1張股票
# 2018-02-08 00:00:00
# 27
# 238.5
# K值為: 18.28282828282828
# 買了一張股票，股價為: 238.5
# [240.0, 238.5]
# 剩餘資金為: 521500.0
# 擁有2張股票
# 2018-02-09 00:00:00
# 28
# 232.5
# 現在的股價= 232.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 238.5
# 最後一次購買股價-5 233.5
# 已達停損標準
# 賣出2張股票
# 股價為: 232.5
# i: 28
# 擁有資金: 986500.0
# 獲利: -13500.0
# 報酬率: -1.35
# 2018-02-12 00:00:00
# 29
# 236.5
# K值為: 17.76223776223776
# 買了一張股票，股價為: 236.5
# [236.5]
# 剩餘資金為: 750000.0
# 擁有1張股票
# 2018-02-21 00:00:00
# 30
# 242.5
# 現在的股價= 242.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 236.5
# 最後一次購買股價+5 241.5
# 已達停利標準
# 賣出1張股票
# 股價為: 242.5
# 擁有資金: 992500.0
# 獲利: -7500.0
# 報酬率: -0.75
# 2018-02-22 00:00:00
# 31
# 239.5
# 尚未達到買點
# 2018-02-23 00:00:00
# 32
# 245.0
# 尚未達到買點
# 2018-02-26 00:00:00
# 33
# 246.5
# 尚未達到買點
# 2018-02-27 00:00:00
# 34
# 246.0
# 尚未達到買點
# 2018-03-01 00:00:00
# 35
# 243.0
# 尚未達到買點
# 2018-03-02 00:00:00
# 36
# 240.0
# 尚未達到買點
# 2018-03-05 00:00:00
# 37
# 241.5
# 尚未達到買點
# 2018-03-06 00:00:00
# 38
# 250.0
# 尚未達到買點
# 2018-03-07 00:00:00
# 39
# 247.0
# 尚未達到買點
# 2018-03-08 00:00:00
# 40
# 249.5
# 尚未達到買點
# 2018-03-09 00:00:00
# 41
# 250.5
# 尚未達到買點
# 2018-03-12 00:00:00
# 42
# 254.0
# 尚未達到買點
# 2018-03-13 00:00:00
# 43
# 259.0
# 尚未達到買點
# 2018-03-14 00:00:00
# 44
# 257.0
# 尚未達到買點
# 2018-03-15 00:00:00
# 45
# 255.0
# 尚未達到買點
# 2018-03-16 00:00:00
# 46
# 255.0
# 尚未達到買點
# 2018-03-19 00:00:00
# 47
# 255.0
# 尚未達到買點
# 2018-03-20 00:00:00
# 48
# 253.0
# 尚未達到買點
# 2018-03-21 00:00:00
# 49
# 252.5
# 尚未達到買點
# 2018-03-22 00:00:00
# 50
# 251.5
# 尚未達到買點
# 2018-03-23 00:00:00
# 51
# 245.0
# 尚未達到買點
# 2018-03-26 00:00:00
# 52
# 243.5
# K值為: 13.280170122275388
# 買了一張股票，股價為: 243.5
# [243.5]
# 剩餘資金為: 749000.0
# 擁有1張股票
# 2018-03-27 00:00:00
# 53
# 251.0
# 現在的股價= 251.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 243.5
# 最後一次購買股價+5 248.5
# 已達停利標準
# 賣出1張股票
# 股價為: 251.0
# 擁有資金: 1000000.0
# 獲利: 0.0
# 報酬率: 0.0
# 2018-03-28 00:00:00
# 54
# 245.0
# 尚未達到買點
# 2018-03-29 00:00:00
# 55
# 244.0
# 尚未達到買點
# 2018-03-30 00:00:00
# 56
# 246.0
# 尚未達到買點
# 2018-04-02 00:00:00
# 57
# 246.5
# 尚未達到買點
# 2018-04-03 00:00:00
# 58
# 244.0
# 尚未達到買點
# 2018-04-09 00:00:00
# 59
# 245.0
# 尚未達到買點
# 2018-04-10 00:00:00
# 60
# 245.5
# 尚未達到買點
# 2018-04-11 00:00:00
# 61
# 248.0
# 尚未達到買點
# 2018-04-12 00:00:00
# 62
# 245.0
# 尚未達到買點
# 2018-04-13 00:00:00
# 63
# 244.5
# 尚未達到買點
# 2018-04-16 00:00:00
# 64
# 243.5
# 尚未達到買點
# 2018-04-17 00:00:00
# 65
# 238.0
# K值為: 19.22705314009662
# 買了一張股票，股價為: 238.0
# [238.0]
# 剩餘資金為: 762000.0
# 擁有1張股票
# 2018-04-18 00:00:00
# 66
# 238.0
# K值為: 12.115942028985506
# 買了一張股票，股價為: 238.0
# [238.0, 238.0]
# 剩餘資金為: 524000.0
# 擁有2張股票
# 2018-04-19 00:00:00
# 67
# 244.5
# 現在的股價= 244.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 238.0
# 最後一次購買股價+5 243.0
# 已達停利標準
# 賣出2張股票
# 股價為: 244.5
# 擁有資金: 1013000.0
# 獲利: 13000.0
# 報酬率: 1.3
# 2018-04-20 00:00:00
# 68
# 229.0
# 尚未達到買點
# 2018-04-23 00:00:00
# 69
# 226.5
# 尚未達到買點
# 2018-04-24 00:00:00
# 70
# 227.0
# K值為: 6.551840594393783
# 買了一張股票，股價為: 227.0
# [227.0]
# 剩餘資金為: 786000.0
# 擁有1張股票
# 2018-04-25 00:00:00
# 71
# 225.0
# K值為: 6.479690522243711
# 買了一張股票，股價為: 225.0
# [227.0, 225.0]
# 剩餘資金為: 561000.0
# 擁有2張股票
# 2018-04-26 00:00:00
# 72
# 222.0
# K值為: 5.770470664087682
# 買了一張股票，股價為: 222.0
# [227.0, 225.0, 222.0]
# 剩餘資金為: 339000.0
# 擁有3張股票
# 2018-04-27 00:00:00
# 73
# 223.5
# K值為: 6.47969052224371
# 買了一張股票，股價為: 223.5
# [227.0, 225.0, 222.0, 223.5]
# 剩餘資金為: 115500.0
# 擁有4張股票
# 2018-04-30 00:00:00
# 74
# 227.0
# 錢不夠再買一張股票
# 2018-05-02 00:00:00
# 75
# 223.0
# 錢不夠再買一張股票
# 2018-05-03 00:00:00
# 76
# 220.5
# 錢不夠再買一張股票
# 2018-05-04 00:00:00
# 77
# 223.0
# 錢不夠再買一張股票
# 2018-05-07 00:00:00
# 78
# 223.5
# 尚未達到買賣點
# 2018-05-08 00:00:00
# 79
# 228.0
# 尚未達到買賣點
# 2018-05-09 00:00:00
# 80
# 229.5
# 現在的股價= 229.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 223.5
# 最後一次購買股價+5 228.5
# 已達停利標準
# 賣出4張股票
# 股價為: 229.5
# 擁有資金: 1033500.0
# 獲利: 33500.0
# 報酬率: 3.35
# 2018-05-10 00:00:00
# 81
# 229.5
# 尚未達到買點
# 2018-05-11 00:00:00
# 82
# 233.0
# 尚未達到買點
# 2018-05-14 00:00:00
# 83
# 233.0
# 尚未達到買點
# 2018-05-15 00:00:00
# 84
# 230.5
# 尚未達到買點
# 2018-05-16 00:00:00
# 85
# 230.5
# 尚未達到買點
# 2018-05-17 00:00:00
# 86
# 226.5
# 尚未達到買點
# 2018-05-18 00:00:00
# 87
# 223.5
# 尚未達到買點
# 2018-05-21 00:00:00
# 88
# 229.0
# 尚未達到買點
# 2018-05-22 00:00:00
# 89
# 229.0
# 尚未達到買點
# 2018-05-23 00:00:00
# 90
# 228.5
# 尚未達到買點
# 2018-05-24 00:00:00
# 91
# 229.0
# 尚未達到買點
# 2018-05-25 00:00:00
# 92
# 228.5
# 尚未達到買點
# 2018-05-28 00:00:00
# 93
# 227.0
# 尚未達到買點
# 2018-05-29 00:00:00
# 94
# 225.0
# 尚未達到買點
# 2018-05-30 00:00:00
# 95
# 221.0
# K值為: 17.94871794871794
# 買了一張股票，股價為: 221.0
# [221.0]
# 剩餘資金為: 812500.0
# 擁有1張股票
# 2018-05-31 00:00:00
# 96
# 224.0
# K值為: 15.256410256410248
# 買了一張股票，股價為: 224.0
# [221.0, 224.0]
# 剩餘資金為: 588500.0
# 擁有2張股票
# 2018-06-01 00:00:00
# 97
# 224.0
# K值為: 19.230769230769223
# 買了一張股票，股價為: 224.0
# [221.0, 224.0, 224.0]
# 剩餘資金為: 364500.0
# 擁有3張股票
# 2018-06-04 00:00:00
# 98
# 229.0
# 現在的股價= 229.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 224.0
# 最後一次購買股價+5 229.0
# 已達停利標準
# 賣出3張股票
# 股價為: 229.0
# 擁有資金: 1051500.0
# 獲利: 51500.0
# 報酬率: 5.1499999999999995
# 2018-06-05 00:00:00
# 99
# 229.0
# 尚未達到買點
# 2018-06-06 00:00:00
# 100
# 230.0
# 尚未達到買點
# 2018-06-07 00:00:00
# 101
# 230.0
# 尚未達到買點
# 2018-06-08 00:00:00
# 102
# 227.0
# 尚未達到買點
# 2018-06-11 00:00:00
# 103
# 226.0
# 尚未達到買點
# 2018-06-12 00:00:00
# 104
# 229.0
# 尚未達到買點
# 2018-06-13 00:00:00
# 105
# 232.0
# 尚未達到買點
# 2018-06-14 00:00:00
# 106
# 226.5
# 尚未達到買點
# 2018-06-15 00:00:00
# 107
# 231.0
# 尚未達到買點
# 2018-06-19 00:00:00
# 108
# 225.0
# 尚未達到買點
# 2018-06-20 00:00:00
# 109
# 226.0
# 尚未達到買點
# 2018-06-21 00:00:00
# 110
# 226.5
# 尚未達到買點
# 2018-06-22 00:00:00
# 111
# 227.5
# 尚未達到買點
# 2018-06-25 00:00:00
# 112
# 218.0
# 尚未達到買點
# 2018-06-26 00:00:00
# 113
# 214.5
# K值為: 19.10507792860734
# 買了一張股票，股價為: 214.5
# [214.5]
# 剩餘資金為: 837000.0
# 擁有1張股票
# 2018-06-27 00:00:00
# 114
# 213.0
# K值為: 4.319704319704319
# 買了一張股票，股價為: 213.0
# [214.5, 213.0]
# 剩餘資金為: 624000.0
# 擁有2張股票
# 2018-06-28 00:00:00
# 115
# 212.0
# K值為: 7.4943074943074945
# 買了一張股票，股價為: 212.0
# [214.5, 213.0, 212.0]
# 剩餘資金為: 412000.0
# 擁有3張股票
# 2018-06-29 00:00:00
# 116
# 216.5
# K值為: 16.112541112541113
# 買了一張股票，股價為: 216.5
# [214.5, 213.0, 212.0, 216.5]
# 剩餘資金為: 195500.0
# 擁有4張股票
# 2018-07-02 00:00:00
# 117
# 214.0
# 尚未達到買賣點
# 2018-07-03 00:00:00
# 118
# 214.5
# 尚未達到買賣點
# 2018-07-04 00:00:00
# 119
# 216.0
# 尚未達到買賣點
# 2018-07-05 00:00:00
# 120
# 214.5
# 尚未達到買賣點
# 2018-07-06 00:00:00
# 121
# 217.0
# 尚未達到買賣點
# 2018-07-09 00:00:00
# 122
# 221.5
# 現在的股價= 221.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 216.5
# 最後一次購買股價+5 221.5
# 已達停利標準
# 賣出4張股票
# 股價為: 221.5
# 擁有資金: 1081500.0
# 獲利: 81500.0
# 報酬率: 8.15
# 2018-07-10 00:00:00
# 123
# 222.0
# 尚未達到買點
# 2018-07-11 00:00:00
# 124
# 220.0
# 尚未達到買點
# 2018-07-12 00:00:00
# 125
# 220.5
# 尚未達到買點
# 2018-07-13 00:00:00
# 126
# 224.5
# 尚未達到買點
# 2018-07-16 00:00:00
# 127
# 223.5
# 尚未達到買點
# 2018-07-17 00:00:00
# 128
# 221.5
# 尚未達到買點
# 2018-07-18 00:00:00
# 129
# 223.0
# 尚未達到買點
# 2018-07-19 00:00:00
# 130
# 224.5
# 尚未達到買點
# 2018-07-20 00:00:00
# 131
# 237.5
# 尚未達到買點
# 2018-07-23 00:00:00
# 132
# 241.0
# 尚未達到買點
# 2018-07-24 00:00:00
# 133
# 241.0
# 尚未達到買點
# 2018-07-25 00:00:00
# 134
# 240.5
# 尚未達到買點
# 2018-07-26 00:00:00
# 135
# 241.0
# 尚未達到買點
# 2018-07-27 00:00:00
# 136
# 244.5
# 尚未達到買點
# 2018-07-30 00:00:00
# 137
# 245.5
# 尚未達到買點
# 2018-07-31 00:00:00
# 138
# 246.0
# 尚未達到買點
# 2018-08-01 00:00:00
# 139
# 248.0
# 尚未達到買點
# 2018-08-02 00:00:00
# 140
# 244.5
# 尚未達到買點
# 2018-08-03 00:00:00
# 141
# 247.0
# 尚未達到買點
# 2018-08-06 00:00:00
# 142
# 245.5
# 尚未達到買點
# 2018-08-07 00:00:00
# 143
# 241.5
# 尚未達到買點
# 2018-08-08 00:00:00
# 144
# 247.5
# 尚未達到買點
# 2018-08-09 00:00:00
# 145
# 247.0
# 尚未達到買點
# 2018-08-10 00:00:00
# 146
# 245.0
# 尚未達到買點
# 2018-08-13 00:00:00
# 147
# 240.5
# 尚未達到買點
# 2018-08-14 00:00:00
# 148
# 243.5
# 尚未達到買點
# 2018-08-15 00:00:00
# 149
# 241.5
# 尚未達到買點
# 2018-08-16 00:00:00
# 150
# 239.0
# 尚未達到買點
# 2018-08-17 00:00:00
# 151
# 239.5
# K值為: 17.592592592592613
# 買了一張股票，股價為: 239.5
# [239.5]
# 剩餘資金為: 842000.0
# 擁有1張股票
# 2018-08-20 00:00:00
# 152
# 239.5
# K值為: 13.333333333333355
# 買了一張股票，股價為: 239.5
# [239.5, 239.5]
# 剩餘資金為: 602500.0
# 擁有2張股票
# 2018-08-21 00:00:00
# 153
# 241.0
# 尚未達到買賣點
# 2018-08-22 00:00:00
# 154
# 242.0
# 尚未達到買賣點
# 2018-08-23 00:00:00
# 155
# 244.5
# 現在的股價= 244.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 239.5
# 最後一次購買股價+5 244.5
# 已達停利標準
# 賣出2張股票
# 股價為: 244.5
# 擁有資金: 1091500.0
# 獲利: 91500.0
# 報酬率: 9.15
# 2018-08-24 00:00:00
# 156
# 243.5
# 尚未達到買點
# 2018-08-27 00:00:00
# 157
# 245.0
# 尚未達到買點
# 2018-08-28 00:00:00
# 158
# 249.5
# 尚未達到買點
# 2018-08-29 00:00:00
# 159
# 259.0
# 尚未達到買點
# 2018-08-30 00:00:00
# 160
# 263.5
# 尚未達到買點
# 2018-08-31 00:00:00
# 161
# 256.0
# 尚未達到買點
# 2018-09-03 00:00:00
# 162
# 257.0
# 尚未達到買點
# 2018-09-04 00:00:00
# 163
# 257.5
# 尚未達到買點
# 2018-09-05 00:00:00
# 164
# 264.0
# 尚未達到買點
# 2018-09-06 00:00:00
# 165
# 261.0
# 尚未達到買點
# 2018-09-07 00:00:00
# 166
# 264.0
# 尚未達到買點
# 2018-09-10 00:00:00
# 167
# 264.5
# 尚未達到買點
# 2018-09-11 00:00:00
# 168
# 260.0
# 尚未達到買點
# 2018-09-12 00:00:00
# 169
# 260.5
# 尚未達到買點
# 2018-09-13 00:00:00
# 170
# 255.0
# 尚未達到買點
# 2018-09-14 00:00:00
# 171
# 261.0
# 尚未達到買點
# 2018-09-17 00:00:00
# 172
# 258.0
# 尚未達到買點
# 2018-09-18 00:00:00
# 173
# 254.5
# 尚未達到買點
# 2018-09-19 00:00:00
# 174
# 258.0
# 尚未達到買點
# 2018-09-20 00:00:00
# 175
# 260.0
# 尚未達到買點
# 2018-09-21 00:00:00
# 176
# 261.5
# 尚未達到買點
# 2018-09-25 00:00:00
# 177
# 263.5
# 尚未達到買點
# 2018-09-26 00:00:00
# 178
# 263.5
# 尚未達到買點
# 2018-09-27 00:00:00
# 179
# 265.0
# 尚未達到買點
# 2018-09-28 00:00:00
# 180
# 262.5
# 尚未達到買點
# 2018-10-01 00:00:00
# 181
# 263.0
# 尚未達到買點
# 2018-10-02 00:00:00
# 182
# 257.5
# 尚未達到買點
# 2018-10-03 00:00:00
# 183
# 260.0
# 尚未達到買點
# 2018-10-04 00:00:00
# 184
# 254.0
# K值為: 12.96296296296297
# 買了一張股票，股價為: 254.0
# [254.0]
# 剩餘資金為: 837500.0
# 擁有1張股票
# 2018-10-05 00:00:00
# 185
# 250.0
# K值為: 13.968253968253975
# 買了一張股票，股價為: 250.0
# [254.0, 250.0]
# 剩餘資金為: 587500.0
# 擁有2張股票
# 2018-10-08 00:00:00
# 186
# 243.5
# 現在的股價= 243.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 250.0
# 最後一次購買股價-5 245.0
# 已達停損標準
# 賣出2張股票
# 股價為: 243.5
# i: 186
# 擁有資金: 1074500.0
# 獲利: 74500.0
# 報酬率: 7.449999999999999
# 2018-10-09 00:00:00
# 187
# 244.0
# K值為: 10.190476190476197
# 買了一張股票，股價為: 244.0
# [244.0]
# 剩餘資金為: 830500.0
# 擁有1張股票
# 2018-10-11 00:00:00
# 188
# 227.5
# 現在的股價= 227.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 244.0
# 最後一次購買股價-5 239.0
# 已達停損標準
# 賣出1張股票
# 股價為: 227.5
# i: 188
# 擁有資金: 1058000.0
# 獲利: 58000.0
# 報酬率: 5.800000000000001
# 2018-10-12 00:00:00
# 189
# 237.0
# K值為: 13.436359436359444
# 買了一張股票，股價為: 237.0
# [237.0]
# 剩餘資金為: 821000.0
# 擁有1張股票
# 2018-10-15 00:00:00
# 190
# 230.5
# 現在的股價= 230.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 237.0
# 最後一次購買股價-5 232.0
# 已達停損標準
# 賣出1張股票
# 股價為: 230.5
# i: 190
# 擁有資金: 1051500.0
# 獲利: 51500.0
# 報酬率: 5.1499999999999995
# 2018-10-16 00:00:00
# 191
# 237.0
# 尚未達到買點
# 2018-10-17 00:00:00
# 192
# 238.5
# 尚未達到買點
# 2018-10-18 00:00:00
# 193
# 236.5
# 尚未達到買點
# 2018-10-19 00:00:00
# 194
# 236.0
# 尚未達到買點
# 2018-10-22 00:00:00
# 195
# 237.0
# 尚未達到買點
# 2018-10-23 00:00:00
# 196
# 230.0
# 尚未達到買點
# 2018-10-24 00:00:00
# 197
# 229.5
# 尚未達到買點
# 2018-10-25 00:00:00
# 198
# 219.5
# K值為: 11.458333333333337
# 買了一張股票，股價為: 219.5
# [219.5]
# 剩餘資金為: 832000.0
# 擁有1張股票
# 2018-10-26 00:00:00
# 199
# 221.0
# K值為: 10.336538461538465
# 買了一張股票，股價為: 221.0
# [219.5, 221.0]
# 剩餘資金為: 611000.0
# 擁有2張股票
# 2018-10-29 00:00:00
# 200
# 222.5
# K值為: 12.179487179487182
# 買了一張股票，股價為: 222.5
# [219.5, 221.0, 222.5]
# 剩餘資金為: 388500.0
# 擁有3張股票
# 2018-10-30 00:00:00
# 201
# 223.0
# 尚未達到買賣點
# 2018-10-31 00:00:00
# 202
# 234.0
# 現在的股價= 234.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 222.5
# 最後一次購買股價+5 227.5
# 已達停利標準
# 賣出3張股票
# 股價為: 234.0
# 擁有資金: 1090500.0
# 獲利: 90500.0
# 報酬率: 9.049999999999999
# 2018-11-01 00:00:00
# 203
# 235.5
# 尚未達到買點
# 2018-11-02 00:00:00
# 204
# 236.5
# 尚未達到買點
# 2018-11-05 00:00:00
# 205
# 235.0
# 尚未達到買點
# 2018-11-06 00:00:00
# 206
# 234.5
# 尚未達到買點
# 2018-11-07 00:00:00
# 207
# 234.0
# 尚未達到買點
# 2018-11-08 00:00:00
# 208
# 236.5
# 尚未達到買點
# 2018-11-09 00:00:00
# 209
# 231.0
# 尚未達到買點
# 2018-11-12 00:00:00
# 210
# 231.5
# 尚未達到買點
# 2018-11-13 00:00:00
# 211
# 227.5
# 尚未達到買點
# 2018-11-14 00:00:00
# 212
# 228.5
# 尚未達到買點
# 2018-11-15 00:00:00
# 213
# 231.0
# 尚未達到買點
# 2018-11-16 00:00:00
# 214
# 226.0
# 尚未達到買點
# 2018-11-19 00:00:00
# 215
# 222.0
# 尚未達到買點
# 2018-11-20 00:00:00
# 216
# 218.0
# K值為: 5.86635586635586
# 買了一張股票，股價為: 218.0
# [218.0]
# 剩餘資金為: 872500.0
# 擁有1張股票
# 2018-11-21 00:00:00
# 217
# 219.0
# K值為: 10.150283321015023
# 買了一張股票，股價為: 219.0
# [218.0, 219.0]
# 剩餘資金為: 653500.0
# 擁有2張股票
# 2018-11-22 00:00:00
# 218
# 219.0
# K值為: 16.26016260162601
# 買了一張股票，股價為: 219.0
# [218.0, 219.0, 219.0]
# 剩餘資金為: 434500.0
# 擁有3張股票
# 2018-11-23 00:00:00
# 219
# 218.5
# 尚未達到買賣點
# 2018-11-26 00:00:00
# 220
# 223.0
# 尚未達到買賣點
# 2018-11-27 00:00:00
# 221
# 224.0
# 現在的股價= 224.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 219.0
# 最後一次購買股價+5 224.0
# 已達停利標準
# 賣出3張股票
# 股價為: 224.0
# 擁有資金: 1106500.0
# 獲利: 106500.0
# 報酬率: 10.65
# 2018-11-28 00:00:00
# 222
# 226.5
# 尚未達到買點
# 2018-11-29 00:00:00
# 223
# 229.0
# 尚未達到買點
# 2018-11-30 00:00:00
# 224
# 225.5
# 尚未達到買點
# 2018-12-03 00:00:00
# 225
# 235.0
# 尚未達到買點
# 2018-12-04 00:00:00
# 226
# 234.0
# 尚未達到買點
# 2018-12-05 00:00:00
# 227
# 226.0
# 尚未達到買點
# 2018-12-06 00:00:00
# 228
# 220.0
# 尚未達到買點
# 2018-12-07 00:00:00
# 229
# 221.0
# 尚未達到買點
# 2018-12-10 00:00:00
# 230
# 219.0
# K值為: 8.207070707070693
# 買了一張股票，股價為: 219.0
# [219.0]
# 剩餘資金為: 887500.0
# 擁有1張股票
# 2018-12-11 00:00:00
# 231
# 222.5
# K值為: 13.257575757575745
# 買了一張股票，股價為: 222.5
# [219.0, 222.5]
# 剩餘資金為: 665000.0
# 擁有2張股票
# 2018-12-12 00:00:00
# 232
# 226.5
# 尚未達到買賣點
# 2018-12-13 00:00:00
# 233
# 226.0
# 尚未達到買賣點
# 2018-12-14 00:00:00
# 234
# 222.5
# 尚未達到買賣點
# 2018-12-17 00:00:00
# 235
# 223.5
# 尚未達到買賣點
# 2018-12-18 00:00:00
# 236
# 222.5
# 尚未達到買賣點
# 2018-12-19 00:00:00
# 237
# 225.5
# 尚未達到買賣點
# 2018-12-20 00:00:00
# 238
# 221.0
# 尚未達到買賣點
# 2018-12-21 00:00:00
# 239
# 223.5
# 尚未達到買賣點
# 2018-12-24 00:00:00
# 240
# 220.0
# 尚未達到買賣點
# 2018-12-25 00:00:00
# 241
# 217.5
# 現在的股價= 217.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 222.5
# 最後一次購買股價-5 217.5
# 已達停損標準
# 賣出2張股票
# 股價為: 217.5
# i: 241
# 擁有資金: 1100000.0
# 獲利: 100000.0
# 報酬率: 10.0
# 2018-12-26 00:00:00
# 242
# 216.5
# K值為: 15.350140056022404
# 買了一張股票，股價為: 216.5
# [216.5]
# 剩餘資金為: 883500.0
# 擁有1張股票
# 2018-12-27 00:00:00
# 243
# 223.0
# 現在的股價= 223.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 216.5
# 最後一次購買股價+5 221.5
# 已達停利標準
# 賣出1張股票
# 股價為: 223.0
# 擁有資金: 1106500.0
# 獲利: 106500.0
# 報酬率: 10.65
# 2018-12-28 00:00:00
# 244
# 225.5
# 尚未達到買點
# 2019-01-02 00:00:00
# 245
# 219.5
# 尚未達到買點
# 2019-01-03 00:00:00
# 246
# 215.5
# 尚未達到買點
# 2019-01-04 00:00:00
# 247
# 208.0
# K值為: 19.543478260869563
# 買了一張股票，股價為: 208.0
# [208.0]
# 剩餘資金為: 898500.0
# 擁有1張股票
# 2019-01-07 00:00:00
# 248
# 213.0
# 現在的股價= 213.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 208.0
# 最後一次購買股價+5 213.0
# 已達停利標準
# 賣出1張股票
# 股價為: 213.0
# 擁有資金: 1111500.0
# 獲利: 111500.0
# 報酬率: 11.15
# 2019-01-08 00:00:00
# 249
# 211.0
# 尚未達到買點
# 2019-01-09 00:00:00
# 250
# 215.5
# 尚未達到買點
# 2019-01-10 00:00:00
# 251
# 216.0
# 尚未達到買點
# 2019-01-11 00:00:00
# 252
# 220.5
# 尚未達到買點
# 2019-01-14 00:00:00
# 253
# 218.5
# 尚未達到買點
# 2019-01-15 00:00:00
# 254
# 221.0
# 尚未達到買點
# 2019-01-16 00:00:00
# 255
# 217.5
# 尚未達到買點
# 2019-01-17 00:00:00
# 256
# 220.5
# 尚未達到買點
# 2019-01-18 00:00:00
# 257
# 218.5
# 尚未達到買點
# 2019-01-21 00:00:00
# 258
# 221.0
# 尚未達到買點
# 2019-01-22 00:00:00
# 259
# 223.0
# 尚未達到買點
# 2019-01-23 00:00:00
# 260
# 220.5
# 尚未達到買點
# 2019-01-24 00:00:00
# 261
# 222.5
# 尚未達到買點
# 2019-01-25 00:00:00
# 262
# 226.0
# 尚未達到買點
# 2019-01-28 00:00:00
# 263
# 229.0
# 尚未達到買點
# 2019-01-29 00:00:00
# 264
# 222.5
# 尚未達到買點
# 2019-01-30 00:00:00
# 265
# 221.0
# 尚未達到買點
# 2019-02-11 00:00:00
# 266
# 228.0
# 尚未達到買點
# 2019-02-12 00:00:00
# 267
# 230.0
# 尚未達到買點
# 2019-02-13 00:00:00
# 268
# 229.0
# 尚未達到買點
# 2019-02-14 00:00:00
# 269
# 227.0
# 尚未達到買點
# 2019-02-15 00:00:00
# 270
# 227.0
# 尚未達到買點
# 2019-02-18 00:00:00
# 271
# 230.0
# 尚未達到買點
# 2019-02-19 00:00:00
# 272
# 229.0
# 尚未達到買點
# 2019-02-20 00:00:00
# 273
# 234.5
# 尚未達到買點
# 2019-02-21 00:00:00
# 274
# 236.5
# 尚未達到買點
# 2019-02-22 00:00:00
# 275
# 236.5
# 尚未達到買點
# 2019-02-25 00:00:00
# 276
# 238.0
# 尚未達到買點
# 2019-02-26 00:00:00
# 277
# 239.5
# 尚未達到買點
# 2019-02-27 00:00:00
# 278
# 239.0
# 尚未達到買點
# 2019-03-04 00:00:00
# 279
# 235.5
# 尚未達到買點
# 2019-03-05 00:00:00
# 280
# 233.0
# 尚未達到買點
# 2019-03-06 00:00:00
# 281
# 234.0
# 尚未達到買點
# 2019-03-07 00:00:00
# 282
# 234.0
# 尚未達到買點
# 2019-03-08 00:00:00
# 283
# 230.0
# 尚未達到買點
# 2019-03-11 00:00:00
# 284
# 230.5
# K值為: 17.696969696969663
# 買了一張股票，股價為: 230.5
# [230.5]
# 剩餘資金為: 881000.0
# 擁有1張股票
# 2019-03-12 00:00:00
# 285
# 235.5
# 現在的股價= 235.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 230.5
# 最後一次購買股價+5 235.5
# 已達停利標準
# 賣出1張股票
# 股價為: 235.5
# 擁有資金: 1116500.0
# 獲利: 116500.0
# 報酬率: 11.65
# 2019-03-13 00:00:00
# 286
# 237.0
# 尚未達到買點
# 2019-03-14 00:00:00
# 287
# 234.5
# 尚未達到買點
# 2019-03-15 00:00:00
# 288
# 239.0
# 尚未達到買點
# 2019-03-18 00:00:00
# 289
# 241.0
# 尚未達到買點
# 2019-03-19 00:00:00
# 290
# 240.5
# 尚未達到買點
# 2019-03-20 00:00:00
# 291
# 242.0
# 尚未達到買點
# 2019-03-21 00:00:00
# 292
# 245.5
# 尚未達到買點
# 2019-03-22 00:00:00
# 293
# 248.5
# 尚未達到買點
# 2019-03-25 00:00:00
# 294
# 241.5
# 尚未達到買點
# 2019-03-26 00:00:00
# 295
# 244.0
# 尚未達到買點
# 2019-03-27 00:00:00
# 296
# 241.5
# 尚未達到買點
# 2019-03-28 00:00:00
# 297
# 242.0
# 尚未達到買點
# 2019-03-29 00:00:00
# 298
# 245.5
# 尚未達到買點
# 2019-04-01 00:00:00
# 299
# 245.5
# 尚未達到買點
# 2019-04-02 00:00:00
# 300
# 246.0
# 尚未達到買點
# 2019-04-03 00:00:00
# 301
# 246.5
# 尚未達到買點
# 2019-04-08 00:00:00
# 302
# 253.0
# 尚未達到買點
# 2019-04-09 00:00:00
# 303
# 254.0
# 尚未達到買點
# 2019-04-10 00:00:00
# 304
# 254.0
# 尚未達到買點
# 2019-04-11 00:00:00
# 305
# 252.0
# 尚未達到買點
# 2019-04-12 00:00:00
# 306
# 252.0
# 尚未達到買點
# 2019-04-15 00:00:00
# 307
# 255.5
# 尚未達到買點
# 2019-04-16 00:00:00
# 308
# 257.0
# 尚未達到買點
# 2019-04-17 00:00:00
# 309
# 261.5
# 尚未達到買點
# 2019-04-18 00:00:00
# 310
# 264.5
# 尚未達到買點
# 2019-04-19 00:00:00
# 311
# 264.5
# 尚未達到買點
# 2019-04-22 00:00:00
# 312
# 266.0
# 尚未達到買點
# 2019-04-23 00:00:00
# 313
# 268.0
# 尚未達到買點
# 2019-04-24 00:00:00
# 314
# 269.0
# 尚未達到買點
# 2019-04-25 00:00:00
# 315
# 267.5
# 尚未達到買點
# 2019-04-26 00:00:00
# 316
# 260.0
# 尚未達到買點
# 2019-04-29 00:00:00
# 317
# 259.5
# 尚未達到買點
# 2019-04-30 00:00:00
# 318
# 259.0
# K值為: 19.678160919540204
# 買了一張股票，股價為: 259.0
# [259.0]
# 剩餘資金為: 857500.0
# 擁有1張股票
# 2019-05-02 00:00:00
# 319
# 259.0
# K值為: 13.333333333333307
# 買了一張股票，股價為: 259.0
# [259.0, 259.0]
# 剩餘資金為: 598500.0
# 擁有2張股票
# 2019-05-03 00:00:00
# 320
# 265.0
# 現在的股價= 265.0
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 259.0
# 最後一次購買股價+5 264.0
# 已達停利標準
# 賣出2張股票
# 股價為: 265.0
# 擁有資金: 1128500.0
# 獲利: 128500.0
# 報酬率: 12.85
# 2019-05-06 00:00:00
# 321
# 259.0
# 尚未達到買點
# 2019-05-07 00:00:00
# 322
# 262.5
# 尚未達到買點
# 2019-05-08 00:00:00
# 323
# 260.0
# 尚未達到買點
# 2019-05-09 00:00:00
# 324
# 256.5
# 尚未達到買點
# 2019-05-10 00:00:00
# 325
# 256.0
# K值為: 12.43156199677936
# 買了一張股票，股價為: 256.0
# [256.0]
# 剩餘資金為: 872500.0
# 擁有1張股票
# 2019-05-13 00:00:00
# 326
# 250.5
# 現在的股價= 250.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 256.0
# 最後一次購買股價-5 251.0
# 已達停損標準
# 賣出1張股票
# 股價為: 250.5
# i: 326
# 擁有資金: 1123000.0
# 獲利: 123000.0
# 報酬率: 12.3
# 2019-05-14 00:00:00
# 327
# 248.5
# K值為: 11.317204301075241
# 買了一張股票，股價為: 248.5
# [248.5]
# 剩餘資金為: 874500.0
# 擁有1張股票
# 2019-05-15 00:00:00
# 328
# 249.0
# K值為: 14.650537634408574
# 買了一張股票，股價為: 249.0
# [248.5, 249.0]
# 剩餘資金為: 625500.0
# 擁有2張股票
# 2019-05-16 00:00:00
# 329
# 247.0
# K值為: 16.203703703703678
# 買了一張股票，股價為: 247.0
# [248.5, 249.0, 247.0]
# 剩餘資金為: 378500.0
# 擁有3張股票
# 2019-05-17 00:00:00
# 330
# 241.5
# 現在的股價= 241.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 247.0
# 最後一次購買股價-5 242.0
# 已達停損標準
# 賣出3張股票
# 股價為: 241.5
# i: 330
# 擁有資金: 1103000.0
# 獲利: 103000.0
# 報酬率: 10.299999999999999
# 2019-05-20 00:00:00
# 331
# 238.0
# K值為: 3.703703703703676
# 買了一張股票，股價為: 238.0
# [238.0]
# 剩餘資金為: 865000.0
# 擁有1張股票
# 2019-05-21 00:00:00
# 332
# 234.0
# K值為: 1.8518518518518245
# 買了一張股票，股價為: 234.0
# [238.0, 234.0]
# 剩餘資金為: 631000.0
# 擁有2張股票
# 2019-05-22 00:00:00
# 333
# 238.0
# K值為: 8.770090845562516
# 買了一張股票，股價為: 238.0
# [238.0, 234.0, 238.0]
# 剩餘資金為: 393000.0
# 擁有3張股票
# 2019-05-23 00:00:00
# 334
# 230.0
# 現在的股價= 230.0
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 238.0
# 最後一次購買股價-5 233.0
# 已達停損標準
# 賣出3張股票
# 股價為: 230.0
# i: 334
# 擁有資金: 1083000.0
# 獲利: 83000.0
# 報酬率: 8.3
# 2019-05-24 00:00:00
# 335
# 233.0
# K值為: 11.463693539165211
# 買了一張股票，股價為: 233.0
# [233.0]
# 剩餘資金為: 850000.0
# 擁有1張股票
# 2019-05-27 00:00:00
# 336
# 231.0
# K值為: 6.060606060606035
# 買了一張股票，股價為: 231.0
# [233.0, 231.0]
# 剩餘資金為: 619000.0
# 擁有2張股票
# 2019-05-28 00:00:00
# 337
# 230.5
# K值為: 6.91530691530689
# 買了一張股票，股價為: 230.5
# [233.0, 231.0, 230.5]
# 剩餘資金為: 388500.0
# 擁有3張股票
# 2019-05-29 00:00:00
# 338
# 229.5
# K值為: 6.157731157731132
# 買了一張股票，股價為: 229.5
# [233.0, 231.0, 230.5, 229.5]
# 剩餘資金為: 159000.0
# 擁有4張股票
# 2019-05-30 00:00:00
# 339
# 231.0
# 錢不夠再買一張股票
# 2019-05-31 00:00:00
# 340
# 235.5
# 現在的股價= 235.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 229.5
# 最後一次購買股價+5 234.5
# 已達停利標準
# 賣出4張股票
# 股價為: 235.5
# 擁有資金: 1101000.0
# 獲利: 101000.0
# 報酬率: 10.100000000000001
# 2019-06-03 00:00:00
# 341
# 238.0
# 尚未達到買點
# 2019-06-04 00:00:00
# 342
# 233.0
# 尚未達到買點
# 2019-06-05 00:00:00
# 343
# 235.0
# 尚未達到買點
# 2019-06-06 00:00:00
# 344
# 232.0
# 尚未達到買點
# 2019-06-10 00:00:00
# 345
# 240.0
# 尚未達到買點
# 2019-06-11 00:00:00
# 346
# 244.5
# 尚未達到買點
# 2019-06-12 00:00:00
# 347
# 246.0
# 尚未達到買點
# 2019-06-13 00:00:00
# 348
# 240.0
# 尚未達到買點
# 2019-06-14 00:00:00
# 349
# 236.0
# 尚未達到買點
# 2019-06-17 00:00:00
# 350
# 233.0
# 尚未達到買點
# 2019-06-18 00:00:00
# 351
# 235.5
# 尚未達到買點
# 2019-06-19 00:00:00
# 352
# 244.0
# 尚未達到買點
# 2019-06-20 00:00:00
# 353
# 245.0
# 尚未達到買點
# 2019-06-21 00:00:00
# 354
# 248.5
# 尚未達到買點
# 2019-06-24 00:00:00
# 355
# 241.0
# 尚未達到買點
# 2019-06-25 00:00:00
# 356
# 238.5
# 尚未達到買點
# 2019-06-26 00:00:00
# 357
# 234.5
# 尚未達到買點
# 2019-06-27 00:00:00
# 358
# 240.5
# 尚未達到買點
# 2019-06-28 00:00:00
# 359
# 239.0
# 尚未達到買點
# 2019-07-01 00:00:00
# 360
# 248.5
# 尚未達到買點
# 2019-07-02 00:00:00
# 361
# 249.0
# 尚未達到買點
# 2019-07-03 00:00:00
# 362
# 242.5
# 尚未達到買點
# 2019-07-04 00:00:00
# 363
# 244.0
# 尚未達到買點
# 2019-07-05 00:00:00
# 364
# 243.0
# 尚未達到買點
# 2019-07-08 00:00:00
# 365
# 242.5
# 尚未達到買點
# 2019-07-09 00:00:00
# 366
# 242.0
# 尚未達到買點
# 2019-07-10 00:00:00
# 367
# 247.0
# 尚未達到買點
# 2019-07-11 00:00:00
# 368
# 250.0
# 尚未達到買點
# 2019-07-12 00:00:00
# 369
# 250.5
# 尚未達到買點
# 2019-07-15 00:00:00
# 370
# 254.5
# 尚未達到買點
# 2019-07-16 00:00:00
# 371
# 256.0
# 尚未達到買點
# 2019-07-17 00:00:00
# 372
# 252.0
# 尚未達到買點
# 2019-07-18 00:00:00
# 373
# 254.0
# 尚未達到買點
# 2019-07-19 00:00:00
# 374
# 259.0
# 尚未達到買點
# 2019-07-22 00:00:00
# 375
# 264.0
# 尚未達到買點
# 2019-07-23 00:00:00
# 376
# 264.0
# 尚未達到買點
# 2019-07-24 00:00:00
# 377
# 265.0
# 尚未達到買點
# 2019-07-25 00:00:00
# 378
# 265.0
# 尚未達到買點
# 2019-07-26 00:00:00
# 379
# 261.0
# 尚未達到買點
# 2019-07-29 00:00:00
# 380
# 261.0
# 尚未達到買點
# 2019-07-30 00:00:00
# 381
# 260.0
# 尚未達到買點
# 2019-07-31 00:00:00
# 382
# 259.5
# 尚未達到買點
# 2019-08-01 00:00:00
# 383
# 256.5
# 尚未達到買點
# 2019-08-02 00:00:00
# 384
# 251.5
# K值為: 13.88556618819778
# 買了一張股票，股價為: 251.5
# [251.5]
# 剩餘資金為: 849500.0
# 擁有1張股票
# 2019-08-05 00:00:00
# 385
# 246.5
# 現在的股價= 246.5
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 251.5
# 最後一次購買股價-5 246.5
# 已達停損標準
# 賣出1張股票
# 股價為: 246.5
# i: 385
# 擁有資金: 1096000.0
# 獲利: 96000.0
# 報酬率: 9.6
# 2019-08-06 00:00:00
# 386
# 248.5
# K值為: 15.003968253968267
# 買了一張股票，股價為: 248.5
# [248.5]
# 剩餘資金為: 847500.0
# 擁有1張股票
# 2019-08-07 00:00:00
# 387
# 248.0
# 尚未達到買賣點
# 2019-08-08 00:00:00
# 388
# 253.5
# 現在的股價= 253.5
# 條件: 現股>=最後一次購買股價+10 =
# 最後一次購買股價 248.5
# 最後一次購買股價+5 253.5
# 已達停利標準
# 賣出1張股票
# 股價為: 253.5
# 擁有資金: 1101000.0
# 獲利: 101000.0
# 報酬率: 10.100000000000001
# 2019-08-12 00:00:00
# 389
# 251.0
# 尚未達到買點
# 2019-08-13 00:00:00
# 390
# 246.5
# 尚未達到買點
# 2019-08-14 00:00:00
# 391
# 249.5
# 尚未達到買點
# 2019-08-15 00:00:00
# 392
# 248.0
# 尚未達到買點
# 2019-08-16 00:00:00
# 393
# 250.0
# 尚未達到買點
# 2019-08-19 00:00:00
# 394
# 252.0
# 尚未達到買點
# 2019-08-20 00:00:00
# 395
# 254.5
# 尚未達到買點
# 2019-08-21 00:00:00
# 396
# 254.5
# 尚未達到買點
# 2019-08-22 00:00:00
# 397
# 254.0
# 尚未達到買點
# 2019-08-23 00:00:00
# 398
# 254.0
# 尚未達到買點
# 2019-08-26 00:00:00
# 399
# 248.5
# 尚未達到買點
# 2019-08-27 00:00:00
# 400
# 250.0
# 尚未達到買點
# 2019-08-28 00:00:00
# 401
# 252.0
# 尚未達到買點
# 2019-08-29 00:00:00
# 402
# 254.0
# 尚未達到買點
# 2019-08-30 00:00:00
# 403
# 259.0
# 尚未達到買點
# 2019-09-02 00:00:00
# 404
# 257.5
# 尚未達到買點
# 2019-09-03 00:00:00
# 405
# 254.0
# 尚未達到買點
# 2019-09-04 00:00:00
# 406
# 257.5
# 尚未達到買點
# 2019-09-05 00:00:00
# 407
# 263.0
# 尚未達到買點
# 2019-09-06 00:00:00
# 408
# 263.5
# 尚未達到買點
# 2019-09-10 00:00:00
# 409
# 261.5
# 尚未達到買點
# 2019-09-11 00:00:00
# 410
# 263.0
# 尚未達到買點
# 2019-09-12 00:00:00
# 411
# 262.5
# 尚未達到買點
# 2019-09-16 00:00:00
# 412
# 265.5
# 尚未達到買點
# 2019-09-17 00:00:00
# 413
# 265.0
# 尚未達到買點
# 2019-09-18 00:00:00
# 414
# 267.0
# 尚未達到買點
# 2019-09-19 00:00:00
# 415
# 265.0
# 尚未達到買點
# 2019-09-20 00:00:00
# 416
# 264.0
# 尚未達到買點
# 2019-09-23 00:00:00
# 417
# 264.0
# 尚未達到買點
# 2019-09-24 00:00:00
# 418
# 265.0
# 尚未達到買點
# 2019-09-25 00:00:00
# 419
# 266.0
# 尚未達到買點
# 2019-09-26 00:00:00
# 420
# 268.0
# 尚未達到買點
# 2019-09-27 00:00:00
# 421
# 272.0
# 尚未達到買點
# 2019-10-01 00:00:00
# 422
# 280.0
# 尚未達到買點
# 2019-10-02 00:00:00
# 423
# 279.5
# 尚未達到買點
# 2019-10-03 00:00:00
# 424
# 276.5
# 尚未達到買點
# 2019-10-04 00:00:00
# 425
# 276.5
# 尚未達到買點
# 2019-10-07 00:00:00
# 426
# 278.0
# 尚未達到買點
# 2019-10-08 00:00:00
# 427
# 286.5
# 尚未達到買點
# 2019-10-09 00:00:00
# 428
# 282.0
# 尚未達到買點
# 2019-10-14 00:00:00
# 429
# 290.0
# 尚未達到買點
# 2019-10-15 00:00:00
# 430
# 293.5
# 尚未達到買點
# 2019-10-16 00:00:00
# 431
# 296.5
# 尚未達到買點
# 2019-10-17 00:00:00
# 432
# 293.5
# 尚未達到買點
# 2019-10-18 00:00:00
# 433
# 293.0
# 尚未達到買點
# 2019-10-21 00:00:00
# 434
# 290.0
# 尚未達到買點
# 2019-10-22 00:00:00
# 435
# 294.0
# 尚未達到買點
# 2019-10-23 00:00:00
# 436
# 293.0
# 尚未達到買點
# 2019-10-24 00:00:00
# 437
# 293.0
# 尚未達到買點
# 2019-10-25 00:00:00
# 438
# 293.5
# 尚未達到買點
# 2019-10-28 00:00:00
# 439
# 294.5
# 尚未達到買點
# 2019-10-29 00:00:00
# 440
# 298.5
# 尚未達到買點
# 2019-10-30 00:00:00
# 441
# 298.0
# 尚未達到買點
#
#
# 總報酬率 10.100000000000001
# 2 1000000
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-02-08 00:00:00 K值為: 18.28282828282828
# 2018-02-09 00:00:00 K值為: 16.829836829836825
# 2018-02-12 00:00:00 K值為: 17.76223776223776
# 2018-02-21 00:00:00 K值為: 26.666666666666668
# 買了一張股票，股價為: 242.5
# [242.5]
# 剩餘資金為: 757500.0
# 擁有1張股票
# 2018-02-22 00:00:00
# 未達買賣點
# 2018-02-23 00:00:00
# 未達買賣點
# 2018-02-26 00:00:00
# 未達買賣點
# 2018-02-27 00:00:00
# 未達買賣點
# 2018-03-01 00:00:00
# 未達買賣點
# 2018-03-02 00:00:00
# 未達買賣點
# 2018-03-05 00:00:00
# 未達買賣點
# 2018-03-06 00:00:00
# 現在的股價= 250.0
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 242.5
# 最後一次購買股價+5 247.5
# 已達停利標準
# 賣出1張股票
# 股價為: 250.0
# 擁有資金: 1007500.0
# 獲利: 7500.0
# 報酬率: 0.75
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-05-02 00:00:00 K值為: 14.893617021276595
# 2018-05-03 00:00:00 K值為: 12.796793092815294
# 2018-05-04 00:00:00 K值為: 16.786154794942956
# 2018-05-07 00:00:00 K值為: 28.532608695652176
# 買了一張股票，股價為: 223.5
# [223.5]
# 剩餘資金為: 784000.0
# 擁有1張股票
# 2018-05-08 00:00:00
# 未達買賣點
# 2018-05-09 00:00:00
# 現在的股價= 229.5
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 223.5
# 最後一次購買股價+5 228.5
# 已達停利標準
# 賣出1張股票
# 股價為: 229.5
# 擁有資金: 1013500.0
# 獲利: 13500.0
# 報酬率: 1.35
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-05-30 00:00:00 K值為: 17.94871794871794
# 2018-05-31 00:00:00 K值為: 15.256410256410248
# 2018-06-01 00:00:00 K值為: 19.230769230769223
# 2018-06-04 00:00:00 K值為: 43.7062937062937
# 買了一張股票，股價為: 229.0
# [229.0]
# 剩餘資金為: 784500.0
# 擁有1張股票
# 2018-06-05 00:00:00
# 未達買賣點
# 2018-06-06 00:00:00
# 未達買賣點
# 2018-06-07 00:00:00
# 未達買賣點
# 2018-06-08 00:00:00
# 未達買賣點
# 2018-06-08 00:00:00 K值為: 81.81818181818183
# 2018-06-07 00:00:00 K值為: 91.94577352472089
# 2018-06-06 00:00:00 K值為: 88.91547049441785
# 2018-06-11 00:00:00 K值為: 65.15151515151516
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 226.0
# 擁有資金: 1010500.0
# 獲利: 10500.0
# 報酬率:
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-06-27 00:00:00 K值為: 4.319704319704319
# 2018-06-28 00:00:00 K值為: 7.4943074943074945
# 2018-06-29 00:00:00 K值為: 16.112541112541113
# 2018-07-02 00:00:00 K值為: 22.61904761904762
# 買了一張股票，股價為: 214.0
# [214.0]
# 剩餘資金為: 796500.0
# 擁有1張股票
# 2018-07-03 00:00:00
# 未達買賣點
# 2018-07-04 00:00:00
# 未達買賣點
# 2018-07-05 00:00:00
# 未達買賣點
# 2018-07-06 00:00:00
# 未達買賣點
# 2018-07-09 00:00:00
# 現在的股價= 221.5
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 214.0
# 最後一次購買股價+5 219.0
# 已達停利標準
# 賣出1張股票
# 股價為: 221.5
# 擁有資金: 1018000.0
# 獲利: 18000.0
# 報酬率: 1.7999999999999998
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-10-11 00:00:00 K值為: 7.760683760683768
# 2018-10-12 00:00:00 K值為: 13.436359436359444
# 2018-10-15 00:00:00 K值為: 12.677100177100185
# 2018-10-16 00:00:00 K值為: 22.350759850759857
# 買了一張股票，股價為: 237.0
# [237.0]
# 剩餘資金為: 781000.0
# 擁有1張股票
# 2018-10-17 00:00:00
# 未達買賣點
# 2018-10-18 00:00:00
# 未達買賣點
# 2018-10-19 00:00:00
# 未達買賣點
# 2018-10-22 00:00:00
# 未達買賣點
# 2018-10-23 00:00:00
# 現在的股價= 230.0
# 條件: 現股<=最後一次購買股價-5 =
# 最後一次購買股價 237.0
# 最後一次購買股價-5 232.0
# 已達停損標準
# 賣出1張股票
# 股價為: 230.0
# 擁有資金: 1011000.0
# 獲利: 11000.0
# 報酬率: 1.0999999999999999
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-10-25 00:00:00 K值為: 11.458333333333337
# 2018-10-26 00:00:00 K值為: 10.336538461538465
# 2018-10-29 00:00:00 K值為: 12.179487179487182
# 2018-10-30 00:00:00 K值為: 21.270396270396272
# 買了一張股票，股價為: 223.0
# [223.0]
# 剩餘資金為: 788000.0
# 擁有1張股票
# 2018-10-31 00:00:00
# 現在的股價= 234.0
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 223.0
# 最後一次購買股價+5 228.0
# 已達停利標準
# 賣出1張股票
# 股價為: 234.0
# 擁有資金: 1022000.0
# 獲利: 22000.0
# 報酬率: 2.1999999999999997
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2018-11-20 00:00:00 K值為: 5.86635586635586
# 2018-11-21 00:00:00 K值為: 10.150283321015023
# 2018-11-22 00:00:00 K值為: 16.26016260162601
# 2018-11-23 00:00:00 K值為: 24.59349593495934
# 買了一張股票，股價為: 218.5
# [218.5]
# 剩餘資金為: 803500.0
# 擁有1張股票
# 2018-11-26 00:00:00
# 未達買賣點
# 2018-11-27 00:00:00
# 現在的股價= 224.0
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 218.5
# 最後一次購買股價+5 223.5
# 已達停利標準
# 賣出1張股票
# 股價為: 224.0
# 擁有資金: 1027500.0
# 獲利: 27500.0
# 報酬率: 2.75
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2019-05-28 00:00:00 K值為: 6.91530691530689
# 2019-05-29 00:00:00 K值為: 6.157731157731132
# 2019-05-30 00:00:00 K值為: 12.97591297591295
# 2019-05-31 00:00:00 K值為: 33.10886644219975
# 買了一張股票，股價為: 235.5
# [235.5]
# 剩餘資金為: 792000.0
# 擁有1張股票
# 2019-06-03 00:00:00
# 未達買賣點
# 2019-06-04 00:00:00
# 未達買賣點
# 2019-06-05 00:00:00
# 未達買賣點
# 2019-06-06 00:00:00
# 未達買賣點
# 2019-06-10 00:00:00
# 未達買賣點
# 2019-06-11 00:00:00
# 現在的股價= 244.5
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 235.5
# 最後一次購買股價+5 240.5
# 已達停利標準
# 賣出1張股票
# 股價為: 244.5
# 擁有資金: 1036500.0
# 獲利: 36500.0
# 報酬率: 3.65
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 2019-08-02 00:00:00 K值為: 13.88556618819778
# 2019-08-05 00:00:00 K值為: 6.700937950937965
# 2019-08-06 00:00:00 K值為: 15.003968253968267
# 2019-08-07 00:00:00 K值為: 24.514837819185658
# 買了一張股票，股價為: 248.0
# [248.0]
# 剩餘資金為: 788500.0
# 擁有1張股票
# 2019-08-08 00:00:00
# 現在的股價= 253.5
# 條件: 現股>=最後一次購買股價+5 =
# 最後一次購買股價 248.0
# 最後一次購買股價+5 253.0
# 已達停利標準
# 賣出1張股票
# 股價為: 253.5
# 擁有資金: 1042000.0
# 獲利: 42000.0
# 報酬率: 4.2
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
# 未達買點
#
#
# 總報酬率 4.2
# 2018-01-03 00:00:00
# 1
# 237.0
# 2018-01-04 00:00:00
# 2
# 239.5
# 2018-01-05 00:00:00
# 3
# 240.0
# 2018-01-08 00:00:00
# 4
# 242.0
# 2018-01-09 00:00:00
# 5
# 242.0
# 2018-01-10 00:00:00
# 6
# 236.5
# 2018-01-11 00:00:00
# 7
# 235.0
# 2018-01-12 00:00:00
# 8
# 237.0
# 2018-01-15 00:00:00
# 9
# 240.0
# 2018-01-16 00:00:00
# 10
# 240.5
# 2018-01-17 00:00:00
# 11
# 242.0
# 2018-01-18 00:00:00
# 12
# 248.5
# 2018-01-19 00:00:00
# 13
# 255.5
# 2018-01-22 00:00:00
# 14
# 261.5
# 2018-01-23 00:00:00
# 15
# 266.0
# 2018-01-24 00:00:00
# 16
# 258.0
# 2018-01-25 00:00:00
# 17
# 258.0
# 2018-01-26 00:00:00
# 18
# 255.0
# 2018-01-29 00:00:00
# 19
# 258.5
# 2018-01-30 00:00:00
# 20
# 253.0
# 2018-01-31 00:00:00
# 21
# 255.0
# 2018-02-01 00:00:00
# 22
# 259.5
# 2018-02-02 00:00:00
# 23
# 259.5
# record: [259.5]
# 2018-02-01 00:00:00 K值為: 38.601532567049816 D值為: 46.81019278720429 2018-02-02 00:00:00 K值為: 43.76026272577997 D值為: 42.39341969227028
# 買了一張股票，股價為: 259.5
# 剩餘資金為: 740500.0
# 擁有1張股票
# 2018-02-05 00:00:00
# 24
# 253.0
# 2018-02-06 00:00:00
# 25
# 239.0
# 2018-02-05 00:00:00 K值為: 41.88712522045855 D值為: 41.41630683776279 2018-02-06 00:00:00 K值為: 29.585537918871253 D值為: 38.41097528836993
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 253.0
# 擁有資金: 993500.0
# 獲利: -6500.0
# 報酬率: -0.65
# 2018-02-07 00:00:00
# 26
# 240.0
# 2018-02-08 00:00:00
# 27
# 238.5
# 2018-02-09 00:00:00
# 28
# 232.5
# 2018-02-12 00:00:00
# 29
# 236.5
# record: [232.5]
# 2018-02-09 00:00:00 K值為: 16.829836829836825 D值為: 18.03792914904027 2018-02-12 00:00:00 K值為: 17.76223776223776 D值為: 17.624967624967635
# 買了一張股票，股價為: 232.5
# 剩餘資金為: 761000.0
# 擁有1張股票
# 2018-02-21 00:00:00
# 30
# 242.5
# 2018-02-22 00:00:00
# 31
# 239.5
# 2018-02-21 00:00:00 K值為: 26.666666666666668 D值為: 20.41958041958043 2018-02-22 00:00:00 K值為: 34.20431420431421 D值為: 26.211072877739564
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 242.5
# 擁有資金: 1003500.0
# 獲利: 3500.0
# 報酬率: 0.35000000000000003
# 2018-02-23 00:00:00
# 32
# 245.0
# 2018-02-26 00:00:00
# 33
# 246.5
# 2018-02-27 00:00:00
# 34
# 246.0
# 2018-03-01 00:00:00
# 35
# 243.0
# 2018-03-02 00:00:00
# 36
# 240.0
# 2018-03-05 00:00:00
# 37
# 241.5
# 2018-03-06 00:00:00
# 38
# 250.0
# record: [241.5]
# 2018-03-05 00:00:00 K值為: 53.37243401759533 D值為: 66.44844025998529 2018-03-06 00:00:00 K值為: 63.347181492342806 D值為: 60.87623547300971
# 買了一張股票，股價為: 241.5
# 剩餘資金為: 762000.0
# 擁有1張股票
# 2018-03-07 00:00:00
# 39
# 247.0
# 2018-03-06 00:00:00 K值為: 63.347181492342806 D值為: 60.87623547300971 2018-03-07 00:00:00 K值為: 69.53405017921149 D值為: 62.084555229716564
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 250.0
# 擁有資金: 1012000.0
# 獲利: 12000.0
# 報酬率: 1.2
# 2018-03-08 00:00:00
# 40
# 249.5
# 2018-03-09 00:00:00
# 41
# 250.5
# 2018-03-12 00:00:00
# 42
# 254.0
# 2018-03-13 00:00:00
# 43
# 259.0
# 2018-03-14 00:00:00
# 44
# 257.0
# 2018-03-15 00:00:00
# 45
# 255.0
# 2018-03-16 00:00:00
# 46
# 255.0
# 2018-03-19 00:00:00
# 47
# 255.0
# 2018-03-20 00:00:00
# 48
# 253.0
# 2018-03-21 00:00:00
# 49
# 252.5
# 2018-03-22 00:00:00
# 50
# 251.5
# 2018-03-23 00:00:00
# 51
# 245.0
# 2018-03-26 00:00:00
# 52
# 243.5
# 2018-03-27 00:00:00
# 53
# 251.0
# record: [243.5]
# 2018-03-26 00:00:00 K值為: 13.280170122275388 D值為: 23.073339915445207 2018-03-27 00:00:00 K值為: 25.454545454545457 D值為: 20.224298119034987
# 買了一張股票，股價為: 243.5
# 剩餘資金為: 768500.0
# 擁有1張股票
# 2018-03-28 00:00:00
# 54
# 245.0
# 2018-03-27 00:00:00 K值為: 25.454545454545457 D值為: 20.224298119034987 2018-03-28 00:00:00 K值為: 31.278300243817487 D值為: 23.3376719402128
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 251.0
# 擁有資金: 1019500.0
# 獲利: 19500.0
# 報酬率: 1.95
# 2018-03-29 00:00:00
# 55
# 244.0
# 2018-03-30 00:00:00
# 56
# 246.0
# 2018-04-02 00:00:00
# 57
# 246.5
# record: [246.0]
# 2018-03-30 00:00:00 K值為: 25.10946907498631 D值為: 29.85934882486609 2018-04-02 00:00:00 K值為: 29.409171075837737 D值為: 29.23630576887284
# 買了一張股票，股價為: 246.0
# 剩餘資金為: 773500.0
# 擁有1張股票
# 2018-04-03 00:00:00
# 58
# 244.0
# 2018-04-09 00:00:00
# 59
# 245.0
# 2018-04-10 00:00:00
# 60
# 245.5
# 2018-04-11 00:00:00
# 61
# 248.0
# 2018-04-12 00:00:00
# 62
# 245.0
# 2018-04-13 00:00:00
# 63
# 244.5
# 2018-04-13 00:00:00 K值為: 49.5906432748538 D值為: 43.61823361823364 2018-04-13 00:00:00 K值為: 46.666666666666664 D值為: 48.26510721247565
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 245.0
# 擁有資金: 1018500.0
# 獲利: 18500.0
# 報酬率: 1.85
# [-0.65, 0.35, 1.2, 1.95, 1.85]
# 2018-04-16 00:00:00
# 64
# 243.5
# 2018-04-17 00:00:00
# 65
# 238.0
# 2018-04-18 00:00:00
# 66
# 238.0
# 2018-04-19 00:00:00
# 67
# 244.5
# record: [238.0]
# 2018-04-18 00:00:00 K值為: 12.115942028985506 D值為: 20.818035426731104 2018-04-19 00:00:00 K值為: 26.782608695652172 D值為: 19.375201288244792
# 買了一張股票，股價為: 238.0
# 剩餘資金為: 780500.0
# 擁有1張股票
# 2018-04-20 00:00:00
# 68
# 229.0
# 2018-04-19 00:00:00 K值為: 26.782608695652172 D值為: 19.375201288244792 2018-04-20 00:00:00 K值為: 26.92063492063492 D值為: 21.939728548424227
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 244.5
# 擁有資金: 1025000.0
# 獲利: 25000.0
# 報酬率: 2.5
# 2018-04-23 00:00:00
# 69
# 226.5
# 2018-04-24 00:00:00
# 70
# 227.0
# 2018-04-25 00:00:00
# 71
# 225.0
# 2018-04-26 00:00:00
# 72
# 222.0
# 2018-04-27 00:00:00
# 73
# 223.5
# record: [222.0]
# 2018-04-26 00:00:00 K值為: 5.770470664087682 D值為: 6.267333926908417 2018-04-27 00:00:00 K值為: 6.47969052224371 D值為: 6.243283902858393
# 買了一張股票，股價為: 222.0
# 剩餘資金為: 803000.0
# 擁有1張股票
# 2018-04-30 00:00:00
# 74
# 227.0
# 2018-05-02 00:00:00
# 75
# 223.0
# 2018-04-30 00:00:00 K值為: 13.475177304964538 D值為: 8.575112830432003 2018-05-02 00:00:00 K值為: 14.893617021276595 D值為: 11.61616161616164
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 227.0
# 擁有資金: 1030000.0
# 獲利: 30000.0
# 報酬率: 3.0
# 2018-05-03 00:00:00
# 76
# 220.5
# 2018-05-04 00:00:00
# 77
# 223.0
# record: [220.5]
# 2018-05-03 00:00:00 K值為: 12.796793092815294 D值為: 13.721862473018836 2018-05-04 00:00:00 K值為: 16.786154794942956 D值為: 14.825521636344973
# 買了一張股票，股價為: 220.5
# 剩餘資金為: 809500.0
# 擁有1張股票
# 2018-05-07 00:00:00
# 78
# 223.5
# 2018-05-08 00:00:00
# 79
# 228.0
# 2018-05-09 00:00:00
# 80
# 229.5
# 2018-05-08 00:00:00 K值為: 58.45588235294118 D值為: 34.59154861451213 2018-05-09 00:00:00 K值為: 72.34477124183007 D值為: 53.11108743014116
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 228.0
# 擁有資金: 1037500.0
# 獲利: 37500.0
# 報酬率: 3.75
# 2018-05-10 00:00:00
# 81
# 229.5
# 2018-05-11 00:00:00
# 82
# 233.0
# 2018-05-14 00:00:00
# 83
# 233.0
# 2018-05-15 00:00:00
# 84
# 230.5
# 2018-05-16 00:00:00
# 85
# 230.5
# 2018-05-17 00:00:00
# 86
# 226.5
# 2018-05-18 00:00:00
# 87
# 223.5
# 2018-05-21 00:00:00
# 88
# 229.0
# 2018-05-22 00:00:00
# 89
# 229.0
# record: [229.0]
# 2018-05-21 00:00:00 K值為: 29.487179487179485 D值為: 42.295061260578485 2018-05-22 00:00:00 K值為: 33.333333333333336 D值為: 33.150183150183146
# 買了一張股票，股價為: 229.0
# 剩餘資金為: 808500.0
# 擁有1張股票
# 2018-05-23 00:00:00
# 90
# 228.5
# 2018-05-24 00:00:00
# 91
# 229.0
# 2018-05-25 00:00:00
# 92
# 228.5
# 2018-05-25 00:00:00 K值為: 48.48484848484848 D值為: 43.434343434343425 2018-05-25 00:00:00 K值為: 47.69119769119769 D值為: 48.22029822029821
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 229.0
# 擁有資金: 1037500.0
# 獲利: 37500.0
# 報酬率: 3.75
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75]
# 2018-05-28 00:00:00
# 93
# 227.0
# 2018-05-29 00:00:00
# 94
# 225.0
# 2018-05-30 00:00:00
# 95
# 221.0
# 2018-05-31 00:00:00
# 96
# 224.0
# 2018-06-01 00:00:00
# 97
# 224.0
# record: [224.0]
# 2018-05-31 00:00:00 K值為: 15.256410256410248 D值為: 21.914936914936902 2018-06-01 00:00:00 K值為: 19.230769230769223 D值為: 17.478632478632466
# 買了一張股票，股價為: 224.0
# 剩餘資金為: 813500.0
# 擁有1張股票
# 2018-06-04 00:00:00
# 98
# 229.0
# 2018-06-05 00:00:00
# 99
# 229.0
# 2018-06-04 00:00:00 K值為: 43.7062937062937 D值為: 26.06449106449105 2018-06-05 00:00:00 K值為: 64.5564961354435 D值為: 42.4978530241688
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 229.0
# 擁有資金: 1042500.0
# 獲利: 42500.0
# 報酬率: 4.25
# 2018-06-06 00:00:00
# 100
# 230.0
# 2018-06-07 00:00:00
# 101
# 230.0
# 2018-06-08 00:00:00
# 102
# 227.0
# 2018-06-11 00:00:00
# 103
# 226.0
# 2018-06-12 00:00:00
# 104
# 229.0
# 2018-06-13 00:00:00
# 105
# 232.0
# record: [229.0]
# 2018-06-12 00:00:00 K值為: 62.121212121212125 D值為: 69.6969696969697 2018-06-13 00:00:00 K值為: 75.75757575757576 D值為: 67.67676767676768
# 買了一張股票，股價為: 229.0
# 剩餘資金為: 813500.0
# 擁有1張股票
# 2018-06-14 00:00:00
# 106
# 226.5
# 2018-06-15 00:00:00
# 107
# 231.0
# 2018-06-19 00:00:00
# 108
# 225.0
# 2018-06-19 00:00:00 K值為: 72.91666666666667 D值為: 72.72727272727273 2018-06-19 00:00:00 K值為: 43.75 D值為: 62.05808080808081
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 231.0
# 擁有資金: 1044500.0
# 獲利: 44500.0
# 報酬率: 4.45
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45]
# 2018-06-20 00:00:00
# 109
# 226.0
# 2018-06-21 00:00:00
# 110
# 226.5
# 2018-06-22 00:00:00
# 111
# 227.5
# record: [226.5]
# 2018-06-21 00:00:00 K值為: 25.735294117647054 D值為: 37.540849673202615 2018-06-22 00:00:00 K值為: 37.25490196078431 D值為: 35.37581699346405
# 買了一張股票，股價為: 226.5
# 剩餘資金為: 818000.0
# 擁有1張股票
# 2018-06-25 00:00:00
# 112
# 218.0
# 2018-06-25 00:00:00 K值為: 37.25490196078431 D值為: 35.37581699346405 2018-06-25 00:00:00 K值為: 27.45098039215686 D值為: 30.14705882352941
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 227.5
# 擁有資金: 1045500.0
# 獲利: 45500.0
# 報酬率: 4.55
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45, 4.55]
# 2018-06-26 00:00:00
# 113
# 214.5
# 2018-06-27 00:00:00
# 114
# 213.0
# 2018-06-28 00:00:00
# 115
# 212.0
# 2018-06-29 00:00:00
# 116
# 216.5
# record: [212.0]
# 2018-06-28 00:00:00 K值為: 7.4943074943074945 D值為: 10.306363247539721 2018-06-29 00:00:00 K值為: 16.112541112541113 D值為: 9.308850975517645
# 買了一張股票，股價為: 212.0
# 剩餘資金為: 833500.0
# 擁有1張股票
# 2018-07-02 00:00:00
# 117
# 214.0
# 2018-07-03 00:00:00
# 118
# 214.5
# 2018-07-04 00:00:00
# 119
# 216.0
# 2018-07-05 00:00:00
# 120
# 214.5
# 2018-07-06 00:00:00
# 121
# 217.0
# 2018-07-09 00:00:00
# 122
# 221.5
# 2018-07-06 00:00:00 K值為: 51.640211640211646 D值為: 37.61904761904763 2018-07-09 00:00:00 K值為: 69.6988196988197 D值為: 51.79555012888347
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 217.0
# 擁有資金: 1050500.0
# 獲利: 50500.0
# 報酬率: 5.050000000000001
# 2018-07-10 00:00:00
# 123
# 222.0
# 2018-07-11 00:00:00
# 124
# 220.0
# 2018-07-12 00:00:00
# 125
# 220.5
# 2018-07-13 00:00:00
# 126
# 224.5
# record: [220.5]
# 2018-07-12 00:00:00 K值為: 73.52092352092353 D值為: 79.2620959287626 2018-07-13 00:00:00 K值為: 78.28282828282829 D值為: 77.36152736152738
# 買了一張股票，股價為: 220.5
# 剩餘資金為: 830000.0
# 擁有1張股票
# 2018-07-16 00:00:00
# 127
# 223.5
# 2018-07-17 00:00:00
# 128
# 221.5
# 2018-07-18 00:00:00
# 129
# 223.0
# 2018-07-18 00:00:00 K值為: 86.11111111111113 D值為: 83.20707070707073 2018-07-18 00:00:00 K值為: 79.44444444444446 D值為: 83.59427609427611
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 221.5
# 擁有資金: 1051500.0
# 獲利: 51500.0
# 報酬率: 5.15
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45, 4.55, 5.05, 5.15]
# 2018-07-19 00:00:00
# 130
# 224.5
# 2018-07-20 00:00:00
# 131
# 237.5
# record: [224.5]
# 2018-07-19 00:00:00 K值為: 74.35185185185186 D值為: 79.96913580246915 2018-07-20 00:00:00 K值為: 84.07407407407409 D值為: 79.29012345679013
# 買了一張股票，股價為: 224.5
# 剩餘資金為: 827000.0
# 擁有1張股票
# 2018-07-23 00:00:00
# 132
# 241.0
# 2018-07-20 00:00:00 K值為: 84.07407407407409 D值為: 79.29012345679013 2018-07-23 00:00:00 K值為: 85.80246913580248 D值為: 81.40946502057614
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 237.5
# 擁有資金: 1064500.0
# 獲利: 64500.0
# 報酬率: 6.45
# 2018-07-24 00:00:00
# 133
# 241.0
# 2018-07-25 00:00:00
# 134
# 240.5
# 2018-07-26 00:00:00
# 135
# 241.0
# 2018-07-27 00:00:00
# 136
# 244.5
# record: [241.0]
# 2018-07-26 00:00:00 K值為: 83.25617283950619 D值為: 85.75102880658436 2018-07-27 00:00:00 K值為: 87.50000000000001 D值為: 84.87654320987654
# 買了一張股票，股價為: 241.0
# 剩餘資金為: 823500.0
# 擁有1張股票
# 2018-07-30 00:00:00
# 137
# 245.5
# 2018-07-31 00:00:00
# 138
# 246.0
# 2018-08-01 00:00:00
# 139
# 248.0
# 2018-07-31 00:00:00 K值為: 99.30555555555559 D值為: 93.51851851851853 2018-08-01 00:00:00 K值為: 100.00000000000001 D值為: 97.6851851851852
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 246.0
# 擁有資金: 1069500.0
# 獲利: 69500.0
# 報酬率: 6.950000000000001
# 2018-08-02 00:00:00
# 140
# 244.5
# 2018-08-03 00:00:00
# 141
# 247.0
# 2018-08-06 00:00:00
# 142
# 245.5
# 2018-08-07 00:00:00
# 143
# 241.5
# 2018-08-08 00:00:00
# 144
# 247.5
# 2018-08-09 00:00:00
# 145
# 247.0
# record: [247.5]
# 2018-08-08 00:00:00 K值為: 52.79178338001869 D值為: 56.808420337832125 2018-08-09 00:00:00 K值為: 55.073529411764724 D值為: 53.641491950315505
# 買了一張股票，股價為: 247.5
# 剩餘資金為: 822000.0
# 擁有1張股票
# 2018-08-10 00:00:00
# 146
# 245.0
# 2018-08-13 00:00:00
# 147
# 240.5
# 2018-08-13 00:00:00 K值為: 62.99019607843139 D值為: 56.95183629007161 2018-08-13 00:00:00 K值為: 42.26190476190478 D值為: 53.44187675070031
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 245.0
# 擁有資金: 1067000.0
# 獲利: 67000.0
# 報酬率: 6.7
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45, 4.55, 5.05, 5.15, 6.45, 6.95, 6.7]
# 2018-08-14 00:00:00
# 148
# 243.5
# 2018-08-15 00:00:00
# 149
# 241.5
# 2018-08-16 00:00:00
# 150
# 239.0
# 2018-08-17 00:00:00
# 151
# 239.5
# 2018-08-20 00:00:00
# 152
# 239.5
# 2018-08-21 00:00:00
# 153
# 241.0
# record: [239.5]
# 2018-08-20 00:00:00 K值為: 13.333333333333355 D值為: 19.268077601410976 2018-08-21 00:00:00 K值為: 20.00000000000002 D值為: 16.97530864197535
# 買了一張股票，股價為: 239.5
# 剩餘資金為: 827500.0
# 擁有1張股票
# 2018-08-22 00:00:00
# 154
# 242.0
# 2018-08-23 00:00:00
# 155
# 244.5
# 2018-08-24 00:00:00
# 156
# 243.5
# 2018-08-23 00:00:00 K值為: 55.76719576719578 D值為: 35.194003527336896 2018-08-24 00:00:00 K值為: 68.68386243386244 D值為: 51.421957671957706
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 244.5
# 擁有資金: 1072000.0
# 獲利: 72000.0
# 報酬率: 7.199999999999999
# 2018-08-27 00:00:00
# 157
# 245.0
# 2018-08-28 00:00:00
# 158
# 249.5
# 2018-08-29 00:00:00
# 159
# 259.0
# 2018-08-30 00:00:00
# 160
# 263.5
# 2018-08-31 00:00:00
# 161
# 256.0
# 2018-09-03 00:00:00
# 162
# 257.0
# 2018-09-04 00:00:00
# 163
# 257.5
# 2018-09-05 00:00:00
# 164
# 264.0
# record: [257.5]
# 2018-09-04 00:00:00 K值為: 59.10734463276837 D值為: 69.55178907721283 2018-09-05 00:00:00 K值為: 67.33333333333334 D值為: 64.84934086629005
# 買了一張股票，股價為: 257.5
# 剩餘資金為: 814500.0
# 擁有1張股票
# 2018-09-06 00:00:00
# 165
# 261.0
# 2018-09-05 00:00:00 K值為: 67.33333333333334 D值為: 64.84934086629005 2018-09-06 00:00:00 K值為: 70.73758865248227 D值為: 65.72608887286135
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 264.0
# 擁有資金: 1078500.0
# 獲利: 78500.0
# 報酬率: 7.85
# 2018-09-07 00:00:00
# 166
# 264.0
# 2018-09-10 00:00:00
# 167
# 264.5
# 2018-09-11 00:00:00
# 168
# 260.0
# 2018-09-12 00:00:00
# 169
# 260.5
# 2018-09-13 00:00:00
# 170
# 255.0
# 2018-09-14 00:00:00
# 171
# 261.0
# 2018-09-17 00:00:00
# 172
# 258.0
# 2018-09-18 00:00:00
# 173
# 254.5
# 2018-09-19 00:00:00
# 174
# 258.0
# 2018-09-20 00:00:00
# 175
# 260.0
# record: [258.0]
# 2018-09-19 00:00:00 K值為: 24.1821396993811 D值為: 28.367226643088745 2018-09-20 00:00:00 K值為: 30.503978779840867 D值為: 28.190391983495463
# 買了一張股票，股價為: 258.0
# 剩餘資金為: 820500.0
# 擁有1張股票
# 2018-09-21 00:00:00
# 176
# 261.5
# 2018-09-25 00:00:00
# 177
# 263.5
# 2018-09-26 00:00:00
# 178
# 263.5
# 2018-09-25 00:00:00 K值為: 75.0793650793651 D值為: 53.485046243666964 2018-09-26 00:00:00 K值為: 90.15873015873018 D值為: 73.3699633699634
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 263.5
# 擁有資金: 1084000.0
# 獲利: 84000.0
# 報酬率: 8.4
# 2018-09-27 00:00:00
# 179
# 265.0
# 2018-09-28 00:00:00
# 180
# 262.5
# 2018-10-01 00:00:00
# 181
# 263.0
# 2018-10-02 00:00:00
# 182
# 257.5
# 2018-10-03 00:00:00
# 183
# 260.0
# 2018-10-04 00:00:00
# 184
# 254.0
# 2018-10-05 00:00:00
# 185
# 250.0
# 2018-10-08 00:00:00
# 186
# 243.5
# 2018-10-09 00:00:00
# 187
# 244.0
# record: [243.5]
# 2018-10-08 00:00:00 K值為: 6.190476190476197 D值為: 11.040564373897709 2018-10-09 00:00:00 K值為: 10.190476190476197 D值為: 10.116402116402119
# 買了一張股票，股價為: 243.5
# 剩餘資金為: 840500.0
# 擁有1張股票
# 2018-10-11 00:00:00
# 188
# 227.5
# 2018-10-11 00:00:00 K值為: 10.190476190476197 D值為: 10.116402116402119 2018-10-11 00:00:00 K值為: 7.760683760683768 D值為: 8.04721204721205
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 244.0
# 擁有資金: 1084500.0
# 獲利: 84500.0
# 報酬率: 8.45
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45, 4.55, 5.05, 5.15, 6.45, 6.95, 6.7, 7.2, 7.85, 8.4, 8.45]
# 2018-10-12 00:00:00
# 189
# 237.0
# record: [227.5]
# 2018-10-11 00:00:00 K值為: 7.760683760683768 D值為: 8.04721204721205 2018-10-12 00:00:00 K值為: 13.436359436359444 D值為: 10.462506462506466
# 買了一張股票，股價為: 227.5
# 剩餘資金為: 857000.0
# 擁有1張股票
# 2018-10-15 00:00:00
# 190
# 230.5
# 2018-10-12 00:00:00 K值為: 13.436359436359444 D值為: 10.462506462506466 2018-10-15 00:00:00 K值為: 12.677100177100185 D值為: 11.291381124714462
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 237.0
# 擁有資金: 1094000.0
# 獲利: 94000.0
# 報酬率: 9.4
# 2018-10-16 00:00:00
# 191
# 237.0
# 2018-10-17 00:00:00
# 192
# 238.5
# 2018-10-18 00:00:00
# 193
# 236.5
# 2018-10-19 00:00:00
# 194
# 236.0
# 2018-10-22 00:00:00
# 195
# 237.0
# 2018-10-23 00:00:00
# 196
# 230.0
# 2018-10-24 00:00:00
# 197
# 229.5
# 2018-10-25 00:00:00
# 198
# 219.5
# 2018-10-26 00:00:00
# 199
# 221.0
# 2018-10-29 00:00:00
# 200
# 222.5
# record: [221.0]
# 2018-10-26 00:00:00 K值為: 10.336538461538465 D值為: 17.257241215574556 2018-10-29 00:00:00 K值為: 12.179487179487182 D值為: 11.32478632478633
# 買了一張股票，股價為: 221.0
# 剩餘資金為: 873000.0
# 擁有1張股票
# 2018-10-30 00:00:00
# 201
# 223.0
# 2018-10-31 00:00:00
# 202
# 234.0
# 2018-11-01 00:00:00
# 203
# 235.5
# 2018-10-31 00:00:00 K值為: 43.12631812631813 D值為: 25.525400525400528 2018-11-01 00:00:00 K值為: 65.44011544011545 D值為: 43.27894327894328
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 234.0
# 擁有資金: 1107000.0
# 獲利: 107000.0
# 報酬率: 10.7
# 2018-11-02 00:00:00
# 204
# 236.5
# 2018-11-05 00:00:00
# 205
# 235.0
# 2018-11-06 00:00:00
# 206
# 234.5
# 2018-11-07 00:00:00
# 207
# 234.0
# 2018-11-08 00:00:00
# 208
# 236.5
# 2018-11-09 00:00:00
# 209
# 231.0
# 2018-11-12 00:00:00
# 210
# 231.5
# 2018-11-13 00:00:00
# 211
# 227.5
# 2018-11-14 00:00:00
# 212
# 228.5
# 2018-11-15 00:00:00
# 213
# 231.0
# 2018-11-16 00:00:00
# 214
# 226.0
# 2018-11-19 00:00:00
# 215
# 222.0
# 2018-11-20 00:00:00
# 216
# 218.0
# 2018-11-21 00:00:00
# 217
# 219.0
# 2018-11-22 00:00:00
# 218
# 219.0
# record: [219.0]
# 2018-11-21 00:00:00 K值為: 10.150283321015023 D值為: 12.849887240131155 2018-11-22 00:00:00 K值為: 16.26016260162601 D值為: 10.75893392966565
# 買了一張股票，股價為: 219.0
# 剩餘資金為: 888000.0
# 擁有1張股票
# 2018-11-23 00:00:00
# 219
# 218.5
# 2018-11-26 00:00:00
# 220
# 223.0
# 2018-11-27 00:00:00
# 221
# 224.0
# 2018-11-28 00:00:00
# 222
# 226.5
# 2018-11-27 00:00:00 K值為: 43.51851851851851 D值為: 33.747365251430296 2018-11-28 00:00:00 K值為: 62.96296296296296 D值為: 46.53718759409818
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 224.0
# 擁有資金: 1112000.0
# 獲利: 112000.0
# 報酬率: 11.200000000000001
# 2018-11-29 00:00:00
# 223
# 229.0
# 2018-11-30 00:00:00
# 224
# 225.5
# 2018-12-03 00:00:00
# 225
# 235.0
# 2018-12-04 00:00:00
# 226
# 234.0
# 2018-12-05 00:00:00
# 227
# 226.0
# 2018-12-06 00:00:00
# 228
# 220.0
# 2018-12-07 00:00:00
# 229
# 221.0
# 2018-12-10 00:00:00
# 230
# 219.0
# 2018-12-11 00:00:00
# 231
# 222.5
# 2018-12-12 00:00:00
# 232
# 226.5
# record: [222.5]
# 2018-12-11 00:00:00 K值為: 13.257575757575745 D值為: 15.109427609427613 2018-12-12 00:00:00 K值為: 25.252525252525242 D值為: 15.572390572390576
# 買了一張股票，股價為: 222.5
# 剩餘資金為: 889500.0
# 擁有1張股票
# 2018-12-13 00:00:00
# 233
# 226.0
# 2018-12-14 00:00:00
# 234
# 222.5
# 2018-12-17 00:00:00
# 235
# 223.5
# 2018-12-18 00:00:00
# 236
# 222.5
# 2018-12-19 00:00:00
# 237
# 225.5
# 2018-12-20 00:00:00
# 238
# 221.0
# 2018-12-20 00:00:00 K值為: 59.25925925925926 D值為: 47.643097643097654 2018-12-20 00:00:00 K值為: 50.0 D值為: 50.30864197530865
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 225.5
# 擁有資金: 1115000.0
# 獲利: 115000.0
# 報酬率: 11.5
# [-0.65, 0.35, 1.2, 1.95, 1.85, 2.5, 3.0, 3.75, 3.75, 4.25, 4.45, 4.55, 5.05, 5.15, 6.45, 6.95, 6.7, 7.2, 7.85, 8.4, 8.45, 9.4, 10.7, 11.2, 11.5]
# 2018-12-21 00:00:00
# 239
# 223.5
# 2018-12-24 00:00:00
# 240
# 220.0
# 2018-12-25 00:00:00
# 241
# 217.5
# 2018-12-26 00:00:00
# 242
# 216.5
# 2018-12-27 00:00:00
# 243
# 223.0
# record: [216.5]
# 2018-12-26 00:00:00 K值為: 15.350140056022404 D值為: 24.80444029463638 2018-12-27 00:00:00 K值為: 36.825396825396815 D值為: 26.803610333022107
# 買了一張股票，股價為: 216.5
# 剩餘資金為: 898500.0
# 擁有1張股票
# 2018-12-28 00:00:00
# 244
# 225.5
# 2018-12-27 00:00:00 K值為: 36.825396825396815 D值為: 26.803610333022107 2018-12-28 00:00:00 K值為: 63.49206349206349 D值為: 38.555866791160916
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 223.0
# 擁有資金: 1121500.0
# 獲利: 121500.0
# 報酬率: 12.15
# 2019-01-02 00:00:00
# 245
# 219.5
# 2019-01-03 00:00:00
# 246
# 215.5
# 2019-01-04 00:00:00
# 247
# 208.0
# 2019-01-07 00:00:00
# 248
# 213.0
# 2019-01-08 00:00:00
# 249
# 211.0
# record: [213.0]
# 2019-01-07 00:00:00 K值為: 17.333333333333332 D值為: 29.084541062801936 2019-01-08 00:00:00 K值為: 20.833333333333332 D值為: 19.236714975845416
# 買了一張股票，股價為: 213.0
# 剩餘資金為: 908500.0
# 擁有1張股票
# 2019-01-09 00:00:00
# 250
# 215.5
# 2019-01-10 00:00:00
# 251
# 216.0
# 2019-01-11 00:00:00
# 252
# 220.5
# 2019-01-14 00:00:00
# 253
# 218.5
# 2019-01-11 00:00:00 K值為: 54.166666666666664 D值為: 41.94444444444446 2019-01-14 00:00:00 K值為: 59.166666666666664 D值為: 50.555555555555564
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 220.5
# 擁有資金: 1129000.0
# 獲利: 129000.0
# 報酬率: 12.9
# 2019-01-15 00:00:00
# 254
# 221.0
# 2019-01-16 00:00:00
# 255
# 217.5
# 2019-01-17 00:00:00
# 256
# 220.5
# 2019-01-18 00:00:00
# 257
# 218.5
# 2019-01-21 00:00:00
# 258
# 221.0
# 2019-01-22 00:00:00
# 259
# 223.0
# record: [221.0]
# ...
# 529
# 237.0
# 2019-03-12 00:00:00 K值為: 32.36363636363633 D值為: 23.62289562289554 2019-03-13 00:00:00 K值為: 55.72222222222219 D值為: 35.260942760942676
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 235.5
# 擁有資金: 1236500.0
# 獲利: 236500.0
# 報酬率: 23.65
# 2019-03-14 00:00:00
# 530
# 234.5
# 2019-03-15 00:00:00
# 531
# 239.0
# 2019-03-18 00:00:00
# 532
# 241.0
# 2019-03-19 00:00:00
# 533
# 240.5
# 2019-03-20 00:00:00
# 534
# 242.0
# 2019-03-21 00:00:00
# 535
# 245.5
# 2019-03-22 00:00:00
# 536
# 248.5
# 2019-03-25 00:00:00
# 537
# 241.5
# 2019-03-26 00:00:00
# 538
# 244.0
# 2019-03-27 00:00:00
# 539
# 241.5
# 2019-03-28 00:00:00
# 540
# 242.0
# 2019-03-29 00:00:00
# 541
# 245.5
# 2019-04-01 00:00:00
# 542
# 245.5
# record: [245.5]
# 2019-03-29 00:00:00 K值為: 51.89255189255186 D值為: 52.85952872159759 2019-04-01 00:00:00 K值為: 53.89924085576255 D值為: 52.28777552615623
# 買了一張股票，股價為: 245.5
# 剩餘資金為: 991000.0
# 擁有1張股票
# 2019-04-02 00:00:00
# 543
# 246.0
# 2019-04-03 00:00:00
# 544
# 246.5
# 2019-04-03 00:00:00 K值為: 59.382646339168026 D值為: 55.05814636249408 2019-04-03 00:00:00 K值為: 55.27009222661392 D值為: 56.18399314051476
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 246.0
# 擁有資金: 1237000.0
# 獲利: 237000.0
# 報酬率: 23.7
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7]
# 2019-04-08 00:00:00
# 545
# 253.0
# record: [246.5]
# 2019-04-03 00:00:00 K值為: 55.27009222661392 D值為: 56.18399314051476 2019-04-08 00:00:00 K值為: 71.21212121212118 D值為: 61.954953259300964
# 買了一張股票，股價為: 246.5
# 剩餘資金為: 990500.0
# 擁有1張股票
# 2019-04-09 00:00:00
# 546
# 254.0
# 2019-04-08 00:00:00 K值為: 71.21212121212118 D值為: 61.954953259300964 2019-04-09 00:00:00 K值為: 86.36363636363632 D值為: 70.9486166007904
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 253.0
# 擁有資金: 1243500.0
# 獲利: 243500.0
# 報酬率: 24.349999999999998
# 2019-04-10 00:00:00
# 547
# 254.0
# 2019-04-11 00:00:00
# 548
# 252.0
# 2019-04-12 00:00:00
# 549
# 252.0
# 2019-04-15 00:00:00
# 550
# 255.5
# 2019-04-16 00:00:00
# 551
# 257.0
# record: [255.5]
# 2019-04-15 00:00:00 K值為: 86.7853410956859 D值為: 89.0132855650096 2019-04-16 00:00:00 K值為: 92.53246753246749 D值為: 88.82295865054475
# 買了一張股票，股價為: 255.5
# 剩餘資金為: 988000.0
# 擁有1張股票
# 2019-04-17 00:00:00
# 552
# 261.5
# 2019-04-18 00:00:00
# 553
# 264.5
# 2019-04-17 00:00:00 K值為: 95.45454545454542 D值為: 91.59078469423287 2019-04-18 00:00:00 K值為: 93.74389051808403 D值為: 93.91030116836556
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 261.5
# 擁有資金: 1249500.0
# 獲利: 249500.0
# 報酬率: 24.95
# 2019-04-19 00:00:00
# 554
# 264.5
# 2019-04-22 00:00:00
# 555
# 266.0
# 2019-04-23 00:00:00
# 556
# 268.0
# 2019-04-24 00:00:00
# 557
# 269.0
# record: [268.0]
# 2019-04-23 00:00:00 K值為: 81.98198198198195 D值為: 82.72524724137617 2019-04-24 00:00:00 K值為: 89.23660502607868 D值為: 84.22582174704405
# 買了一張股票，股價為: 268.0
# 剩餘資金為: 981500.0
# 擁有1張股票
# 2019-04-25 00:00:00
# 558
# 267.5
# 2019-04-26 00:00:00
# 559
# 260.0
# 2019-04-26 00:00:00 K值為: 90.33457799905165 D值為: 87.18438833570401 2019-04-26 00:00:00 K值為: 70.04877495462792 D值為: 83.20665265991933
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 267.5
# 擁有資金: 1249000.0
# 獲利: 249000.0
# 報酬率: 24.9
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7, 24.35, 24.95, 24.9]
# 2019-04-29 00:00:00
# 560
# 259.5
# 2019-04-30 00:00:00
# 561
# 259.0
# 2019-05-02 00:00:00
# 562
# 259.0
# 2019-05-03 00:00:00
# 563
# 265.0
# record: [259.0]
# 2019-05-02 00:00:00 K值為: 13.333333333333307 D值為: 25.604885057471154 2019-05-03 00:00:00 K值為: 27.99999999999997 D值為: 20.337164750957744
# 買了一張股票，股價為: 259.0
# 剩餘資金為: 990000.0
# 擁有1張股票
# 2019-05-06 00:00:00
# 564
# 259.0
# 2019-05-03 00:00:00 K值為: 27.99999999999997 D值為: 20.337164750957744 2019-05-06 00:00:00 K值為: 27.99999999999997 D值為: 23.111111111111
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 265.0
# 擁有資金: 1255000.0
# 獲利: 255000.0
# 報酬率: 25.5
# 2019-05-07 00:00:00
# 565
# 262.5
# 2019-05-08 00:00:00
# 566
# 260.0
# 2019-05-09 00:00:00
# 567
# 256.5
# 2019-05-10 00:00:00
# 568
# 256.0
# 2019-05-13 00:00:00
# 569
# 250.5
# 2019-05-14 00:00:00
# 570
# 248.5
# record: [250.5]
# 2019-05-13 00:00:00 K值為: 7.33572281959376 D值為: 14.066282271050746 2019-05-14 00:00:00 K值為: 11.317204301075241 D值為: 10.361496372482705
# 買了一張股票，股價為: 250.5
# 剩餘資金為: 1004500.0
# 擁有1張股票
# 2019-05-15 00:00:00
# 571
# 249.0
# 2019-05-16 00:00:00
# 572
# 247.0
# 2019-05-17 00:00:00
# 573
# 241.5
# 2019-05-17 00:00:00 K值為: 16.203703703703678 D值為: 14.05714854639575 2019-05-17 00:00:00 K值為: 10.370370370370344 D值為: 13.741537236160783
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 247.0
# 擁有資金: 1251500.0
# 獲利: 251500.0
# 報酬率: 25.15
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7, 24.35, 24.95, 24.9, 25.5, 25.15]
# 2019-05-20 00:00:00
# 574
# 238.0
# 2019-05-21 00:00:00
# 575
# 234.0
# 2019-05-22 00:00:00
# 576
# 238.0
# record: [234.0]
# 2019-05-21 00:00:00 K值為: 1.8518518518518245 D值為: 5.308641975308534 2019-05-22 00:00:00 K值為: 8.770090845562516 D值為: 4.775215467039258
# 買了一張股票，股價為: 234.0
# 剩餘資金為: 1017500.0
# 擁有1張股票
# 2019-05-23 00:00:00
# 577
# 230.0
# 2019-05-24 00:00:00
# 578
# 233.0
# 2019-05-27 00:00:00
# 579
# 231.0
# 2019-05-27 00:00:00 K值為: 11.463693539165211 D值為: 9.667958410096666 2019-05-27 00:00:00 K值為: 6.060606060606035 D值為: 8.764796815111174
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 233.0
# 擁有資金: 1250500.0
# 獲利: 250500.0
# 報酬率: 25.05
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7, 24.35, 24.95, 24.9, 25.5, 25.15, 25.05]
# 2019-05-28 00:00:00
# 580
# 230.5
# 2019-05-29 00:00:00
# 581
# 229.5
# 2019-05-30 00:00:00
# 582
# 231.0
# record: [229.5]
# 2019-05-29 00:00:00 K值為: 6.157731157731132 D值為: 6.377881377881272 2019-05-30 00:00:00 K值為: 12.97591297591295 D值為: 8.682983682983577
# 買了一張股票，股價為: 229.5
# 剩餘資金為: 1021000.0
# 擁有1張股票
# 2019-05-31 00:00:00
# 583
# 235.5
# 2019-06-03 00:00:00
# 584
# 238.0
# 2019-05-31 00:00:00 K值為: 33.10886644219975 D值為: 17.414170191947864 2019-06-03 00:00:00 K值為: 56.48148148148146 D值為: 34.18875363319797
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 235.5
# 擁有資金: 1256500.0
# 獲利: 256500.0
# 報酬率: 25.650000000000002
# 2019-06-04 00:00:00
# 585
# 233.0
# 2019-06-05 00:00:00
# 586
# 235.0
# 2019-06-06 00:00:00
# 587
# 232.0
# 2019-06-10 00:00:00
# 588
# 240.0
# record: [232.0]
# 2019-06-06 00:00:00 K值為: 55.07246376811592 D值為: 62.78404007872595 2019-06-10 00:00:00 K值為: 71.01449275362317 D值為: 64.60905349794227
# 買了一張股票，股價為: 232.0
# 剩餘資金為: 1024500.0
# 擁有1張股票
# 2019-06-11 00:00:00
# 589
# 244.5
# 2019-06-10 00:00:00 K值為: 71.01449275362317 D值為: 64.60905349794227 2019-06-11 00:00:00 K值為: 78.52784134248664 D值為: 68.20493262140849
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 240.0
# 擁有資金: 1264500.0
# 獲利: 264500.0
# 報酬率: 26.450000000000003
# 2019-06-12 00:00:00
# 590
# 246.0
# 2019-06-13 00:00:00
# 591
# 240.0
# 2019-06-14 00:00:00
# 592
# 236.0
# 2019-06-17 00:00:00
# 593
# 233.0
# 2019-06-18 00:00:00
# 594
# 235.5
# 2019-06-19 00:00:00
# 595
# 244.0
# record: [235.5]
# 2019-06-18 00:00:00 K值為: 29.62962962962961 D值為: 43.2349015682348 2019-06-19 00:00:00 K值為: 44.44444444444442 D值為: 37.34567901234558
# 買了一張股票，股價為: 235.5
# 剩餘資金為: 1029000.0
# 擁有1張股票
# 2019-06-20 00:00:00
# 596
# 245.0
# 2019-06-19 00:00:00 K值為: 44.44444444444442 D值為: 37.34567901234558 2019-06-20 00:00:00 K值為: 66.39433551198255 D值為: 46.822803195352115
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 244.0
# 擁有資金: 1273000.0
# 獲利: 273000.0
# 報酬率: 27.3
# 2019-06-21 00:00:00
# 597
# 248.5
# 2019-06-24 00:00:00
# 598
# 241.0
# 2019-06-25 00:00:00
# 599
# 238.5
# 2019-06-26 00:00:00
# 600
# 234.5
# 2019-06-27 00:00:00
# 601
# 240.5
# 2019-06-28 00:00:00
# 602
# 239.0
# 2019-07-01 00:00:00
# 603
# 248.5
# record: [239.0]
# 2019-06-28 00:00:00 K值為: 38.82915173237754 D值為: 40.41218637992823 2019-07-01 00:00:00 K值為: 61.63007765830346 D值為: 47.06665671047383
# 買了一張股票，股價為: 239.0
# 剩餘資金為: 1034000.0
# 擁有1張股票
# 2019-07-02 00:00:00
# 604
# 249.0
# 2019-07-01 00:00:00 K值為: 61.63007765830346 D值為: 47.06665671047383 2019-07-02 00:00:00 K值為: 74.36155913978494 D值為: 58.27359617682189
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 248.5
# 擁有資金: 1282500.0
# 獲利: 282500.0
# 報酬率: 28.249999999999996
# 2019-07-03 00:00:00
# 605
# 242.5
# 2019-07-04 00:00:00
# 606
# 244.0
# 2019-07-05 00:00:00
# 607
# 243.0
# 2019-07-08 00:00:00
# 608
# 242.5
# 2019-07-09 00:00:00
# 609
# 242.0
# 2019-07-10 00:00:00
# 610
# 247.0
# record: [242.0]
# 2019-07-09 00:00:00 K值為: 50.74404761904761 D值為: 55.10912698412688 2019-07-10 00:00:00 K值為: 56.99404761904761 D值為: 55.00992063492054
# 買了一張股票，股價為: 242.0
# 剩餘資金為: 1040500.0
# 擁有1張股票
# 2019-07-11 00:00:00
# 611
# 250.0
# 2019-07-10 00:00:00 K值為: 56.99404761904761 D值為: 55.00992063492054 2019-07-11 00:00:00 K值為: 72.6190476190476 D值為: 60.119047619047514
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 247.0
# 擁有資金: 1287500.0
# 獲利: 287500.0
# 報酬率: 28.749999999999996
# 2019-07-12 00:00:00
# 612
# 250.5
# 2019-07-15 00:00:00
# 613
# 254.5
# 2019-07-16 00:00:00
# 614
# 256.0
# 2019-07-17 00:00:00
# 615
# 252.0
# 2019-07-18 00:00:00
# 616
# 254.0
# 2019-07-19 00:00:00
# 617
# 259.0
# 2019-07-22 00:00:00
# 618
# 264.0
# record: [259.0]
# 2019-07-19 00:00:00 K值為: 82.60655333826067 D值為: 85.78467602857837 2019-07-22 00:00:00 K值為: 91.69746242916976 D值為: 86.38416687197167
# 買了一張股票，股價為: 259.0
# 剩餘資金為: 1028500.0
# 擁有1張股票
# 2019-07-23 00:00:00
# 619
# 264.0
# 2019-07-22 00:00:00 K值為: 91.69746242916976 D值為: 86.38416687197167 2019-07-23 00:00:00 K值為: 92.3620025673941 D值為: 88.88867277827474
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 264.0
# 擁有資金: 1292500.0
# 獲利: 292500.0
# 報酬率: 29.25
# 2019-07-24 00:00:00
# 620
# 265.0
# 2019-07-25 00:00:00
# 621
# 265.0
# 2019-07-26 00:00:00
# 622
# 261.0
# 2019-07-29 00:00:00
# 623
# 261.0
# 2019-07-30 00:00:00
# 624
# 260.0
# 2019-07-31 00:00:00
# 625
# 259.5
# 2019-08-01 00:00:00
# 626
# 256.5
# 2019-08-02 00:00:00
# 627
# 251.5
# 2019-08-05 00:00:00
# 628
# 246.5
# 2019-08-06 00:00:00
# 629
# 248.5
# record: [246.5]
# 2019-08-05 00:00:00 K值為: 6.700937950937965 D值為: 17.092541960962937 2019-08-06 00:00:00 K值為: 15.003968253968267 D值為: 11.863490797701246
# 買了一張股票，股價為: 246.5
# 剩餘資金為: 1046000.0
# 擁有1張股票
# 2019-08-07 00:00:00
# 630
# 248.0
# 2019-08-08 00:00:00
# 631
# 253.5
# 2019-08-12 00:00:00
# 632
# 251.0
# 2019-08-08 00:00:00 K值為: 42.49275362318841 D值為: 27.337186565447354 2019-08-12 00:00:00 K值為: 47.101449275362334 D值為: 38.03634690591204
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 253.5
# 擁有資金: 1299500.0
# 獲利: 299500.0
# 報酬率: 29.95
# 2019-08-13 00:00:00
# 633
# 246.5
# 2019-08-14 00:00:00
# 634
# 249.5
# 2019-08-15 00:00:00
# 635
# 248.0
# record: [249.5]
# 2019-08-14 00:00:00 K值為: 44.870600414078694 D值為: 46.1042097998619 2019-08-15 00:00:00 K值為: 47.3193760262726 D值為: 46.176852050165316
# 買了一張股票，股價為: 249.5
# 剩餘資金為: 1050000.0
# 擁有1張股票
# 2019-08-16 00:00:00
# 636
# 250.0
# 2019-08-19 00:00:00
# 637
# 252.0
# 2019-08-20 00:00:00
# 638
# 254.5
# 2019-08-21 00:00:00
# 639
# 254.5
# 2019-08-20 00:00:00 K值為: 83.90804597701151 D值為: 70.78270388615209 2019-08-21 00:00:00 K值為: 92.40102171136657 D值為: 81.7581949765857
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 254.5
# 擁有資金: 1304500.0
# 獲利: 304500.0
# 報酬率: 30.45
# 2019-08-22 00:00:00
# 640
# 254.0
# 2019-08-23 00:00:00
# 641
# 254.0
# 2019-08-26 00:00:00
# 642
# 248.5
# 2019-08-27 00:00:00
# 643
# 250.0
# 2019-08-28 00:00:00
# 644
# 252.0
# 2019-08-29 00:00:00
# 645
# 254.0
# record: [252.0]
# 2019-08-28 00:00:00 K值為: 32.8756674294432 D值為: 42.8426137808288 2019-08-29 00:00:00 K值為: 45.99966098821937 D值為: 40.30143797496955
# 買了一張股票，股價為: 252.0
# 剩餘資金為: 1052500.0
# 擁有1張股票
# 2019-08-30 00:00:00
# 646
# 259.0
# 2019-09-02 00:00:00
# 647
# 257.5
# 2019-08-30 00:00:00 K值為: 67.73879142300198 D值為: 48.871373280221405 2019-09-02 00:00:00 K值為: 82.27513227513231 D值為: 65.33786156211778
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 259.0
# 擁有資金: 1311500.0
# 獲利: 311500.0
# 報酬率: 31.15
# 2019-09-03 00:00:00
# 648
# 254.0
# 2019-09-04 00:00:00
# 649
# 257.5
# 2019-09-05 00:00:00
# 650
# 263.0
# record: [257.5]
# 2019-09-04 00:00:00 K值為: 74.60317460317464 D值為: 78.747795414462 2019-09-05 00:00:00 K值為: 79.3650793650794 D值為: 77.7777777777777
# 買了一張股票，股價為: 257.5
# 剩餘資金為: 1054000.0
# 擁有1張股票
# 2019-09-06 00:00:00
# 651
# 263.5
# 2019-09-05 00:00:00 K值為: 79.3650793650794 D值為: 77.7777777777777 2019-09-06 00:00:00 K值為: 92.20779220779224 D值為: 82.05868205868198
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 263.0
# 擁有資金: 1317000.0
# 獲利: 317000.0
# 報酬率: 31.7
# 2019-09-10 00:00:00
# 652
# 261.5
# 2019-09-11 00:00:00
# 653
# 263.0
# 2019-09-12 00:00:00
# 654
# 262.5
# 2019-09-16 00:00:00
# 655
# 265.5
# record: [262.5]
# 2019-09-12 00:00:00 K值為: 80.24767378215658 D值為: 84.44440297888566 2019-09-16 00:00:00 K值為: 88.29365079365083 D值為: 84.23437992403503
# 買了一張股票，股價為: 262.5
# 剩餘資金為: 1054500.0
# 擁有1張股票
# 2019-09-17 00:00:00
# 656
# 265.0
# 2019-09-18 00:00:00
# 657
# 267.0
# 2019-09-19 00:00:00
# 658
# 265.0
# 2019-09-19 00:00:00 K值為: 90.91995221027481 D值為: 89.52181828525907 2019-09-19 00:00:00 K值為: 74.25328554360816 D值為: 84.84169653524485
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 267.0
# 擁有資金: 1321500.0
# 獲利: 321500.0
# 報酬率: 32.15
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7, 24.35, 24.95, 24.9, 25.5, 25.15, 25.05, 25.65, 26.45, 27.3, 28.25, 28.75, 29.25, 29.95, 30.45, 31.15, 31.7, 32.15]
# 2019-09-20 00:00:00
# 659
# 264.0
# 2019-09-23 00:00:00
# 660
# 264.0
# 2019-09-24 00:00:00
# 661
# 265.0
# 2019-09-25 00:00:00
# 662
# 266.0
# record: [265.0]
# 2019-09-24 00:00:00 K值為: 42.59259259259262 D值為: 47.59060135404213 2019-09-25 00:00:00 K值為: 48.379629629629655 D值為: 44.521604938271516
# 買了一張股票，股價為: 265.0
# 剩餘資金為: 1056500.0
# 擁有1張股票
# 2019-09-26 00:00:00
# 663
# 268.0
# 2019-09-27 00:00:00
# 664
# 272.0
# 2019-10-01 00:00:00
# 665
# 280.0
# 2019-09-27 00:00:00 K值為: 77.5793650793651 D值為: 62.81966490299815 2019-10-01 00:00:00 K值為: 91.26179751179755 D值為: 77.11372086372079
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 272.0
# 擁有資金: 1328500.0
# 獲利: 328500.0
# 報酬率: 32.85
# 2019-10-02 00:00:00
# 666
# 279.5
# 2019-10-03 00:00:00
# 667
# 276.5
# 2019-10-04 00:00:00
# 668
# 276.5
# 2019-10-07 00:00:00
# 669
# 278.0
# 2019-10-08 00:00:00
# 670
# 286.5
# record: [278.0]
# 2019-10-07 00:00:00 K值為: 78.94736842105267 D值為: 83.03303303303294 2019-10-08 00:00:00 K值為: 86.84210526315793 D值為: 82.45614035087709
# 買了一張股票，股價為: 278.0
# 剩餘資金為: 1050500.0
# 擁有1張股票
# 2019-10-09 00:00:00
# 671
# 282.0
# 2019-10-08 00:00:00 K值為: 86.84210526315793 D值為: 82.45614035087709 2019-10-09 00:00:00 K值為: 87.2368421052632 D值為: 84.34210526315779
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 286.5
# 擁有資金: 1337000.0
# 獲利: 337000.0
# 報酬率: 33.7
# 2019-10-14 00:00:00
# 672
# 290.0
# 2019-10-15 00:00:00
# 673
# 293.5
# 2019-10-16 00:00:00
# 674
# 296.5
# record: [293.5]
# 2019-10-15 00:00:00 K值為: 86.43778720395903 D值為: 87.91186830632599 2019-10-16 00:00:00 K值為: 91.8544538706257 D值為: 89.4510722281135
# 買了一張股票，股價為: 293.5
# 剩餘資金為: 1043500.0
# 擁有1張股票
# 2019-10-17 00:00:00
# 675
# 293.5
# 2019-10-17 00:00:00 K值為: 91.8544538706257 D值為: 89.4510722281135 2019-10-17 00:00:00 K值為: 88.0434782608696 D值為: 88.77857311181799
# 手上有1張股票可賣
# 賣出1張股票
# 股價為: 296.5
# 擁有資金: 1340000.0
# 獲利: 340000.0
# 報酬率: 34.0
# [0.45, 0.55, 1.2, 1.35, 1.15, 0.95, 1.45, 1.9, 2.1, 2.25, 2.75, 3.35, 3.35, 3.5, 4.05, 3.9, 4.45, 4.4, 4.6, 4.65, 4.95, 5.6, 5.95, 6.1, 6.65, 7.15, 7.2, 7.3, 7.95, 8.8, 8.15, 9.15, 10.0, 10.75, 10.65, 11.3, 11.8, 12.55, 12.55, 13.05, 13.25, 13.35, 13.85, 13.95, 15.25, 15.75, 15.5, 16.0, 16.65, 17.2, 17.25, 18.2, 19.5, 20.0, 20.3, 20.95, 21.7, 21.9, 22.1, 22.4, 22.5, 23.15, 23.65, 23.7, 24.35, 24.95, 24.9, 25.5, 25.15, 25.05, 25.65, 26.45, 27.3, 28.25, 28.75, 29.25, 29.95, 30.45, 31.15, 31.7, 32.15, 32.85, 33.7, 34.0]
# 2019-10-18 00:00:00
# 676
# 293.0
# 2019-10-21 00:00:00
# 677
# 290.0
# 2019-10-22 00:00:00
# 678
# 294.0
# 2019-10-23 00:00:00
# 679
# 293.0
# 2019-10-24 00:00:00
# 680
# 293.0
# 2019-10-25 00:00:00
# 681
# 293.5
# 2019-10-28 00:00:00
# 682
# 294.5
# 2019-10-29 00:00:00
# 683
# 298.5
# record: [294.5]
# 2019-10-28 00:00:00 K值為: 54.385964912280734 D值為: 58.1140350877192 2019-10-29 00:00:00 K值為: 71.92982456140355 D值為: 60.85526315789465
# 買了一張股票，股價為: 294.5
# 剩餘資金為: 1045500.0
# 擁有1張股票
# 2019-10-30 00:00:00
# 684
# 298.0
# 第三個策略獲利最多
